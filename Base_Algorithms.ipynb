# %% [markdown]
# # Base Algorithms
#
# ###### First tests conducted
# ###### This tests should be considered "references"

# %% [markdown]
# ##### Imports

# %%
import gymnasium as gym
from matplotlib import pyplot as plt
import pprint
import gymnasium as gym
import highway_env
from stable_baselines3 import PPO
# %matplotlib inline

# %% [markdown]
# #### HighWay (Fast) Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- vehicle's count:** 20

# %%
env = gym.make("highway-fast-v0", render_mode='rgb_array')
pprint.pprint(env.config)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -1,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'type': 'Kinematics'},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 5,
#  'vehicles_count': 20,
#  'vehicles_density': 1}
# C:\Users\Caty\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.config to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.config` for environment variables or `env.get_wrapper_attr('config')` that will search the reminding wrappers.
#   logger.warn(

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="highway_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("highway_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to highway_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.4     |
# |    ep_rew_mean     | 8.48     |
# | time/              |          |
# |    fps             | 29       |
# |    iterations      | 1        |
# |    time_elapsed    | 69       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13          |
# |    ep_rew_mean          | 9.62        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 2           |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012132661 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | -0.0136     |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.295       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0237     |
# |    value_loss           | 0.951       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.3        |
# |    ep_rew_mean          | 12          |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 3           |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014241967 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.185       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.302       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0213     |
# |    value_loss           | 0.861       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.1        |
# |    ep_rew_mean          | 12.4        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 4           |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011689065 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.17        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.458       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 0.737       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.2        |
# |    ep_rew_mean          | 14.9        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 5           |
# |    time_elapsed         | 352         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013840919 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.18        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.218       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 0.703       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.9        |
# |    ep_rew_mean          | 16.1        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 6           |
# |    time_elapsed         | 425         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012772065 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.182       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.322       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 0.536       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.6        |
# |    ep_rew_mean          | 15.8        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 7           |
# |    time_elapsed         | 500         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013207326 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.143       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.239       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.463       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.5        |
# |    ep_rew_mean          | 15.9        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 8           |
# |    time_elapsed         | 574         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012675397 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.227       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.221       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.429       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.4        |
# |    ep_rew_mean          | 17.4        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 9           |
# |    time_elapsed         | 649         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.013627248 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.289       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.256       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.409       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.9         |
# |    ep_rew_mean          | 16.9         |
# | time/                   |              |
# |    fps                  | 28           |
# |    iterations           | 10           |
# |    time_elapsed         | 723          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0103590805 |
# |    clip_fraction        | 0.172        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.288        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.163        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00825     |
# |    value_loss           | 0.339        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.7        |
# |    ep_rew_mean          | 18.4        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 11          |
# |    time_elapsed         | 800         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010771954 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.292       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.057       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00954    |
# |    value_loss           | 0.373       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.1        |
# |    ep_rew_mean          | 20.2        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 12          |
# |    time_elapsed         | 873         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.025523266 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.152       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.271       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.5        |
# |    ep_rew_mean          | 20.2        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 13          |
# |    time_elapsed         | 947         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.032878075 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.277       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0304     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.181       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.9        |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 14          |
# |    time_elapsed         | 1018        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.018409964 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.37        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00804     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00451    |
# |    value_loss           | 0.238       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.4        |
# |    ep_rew_mean          | 18.8        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 15          |
# |    time_elapsed         | 1089        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.016421556 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.382       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.111       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0037     |
# |    value_loss           | 0.272       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.4        |
# |    ep_rew_mean          | 19.7        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 16          |
# |    time_elapsed         | 1159        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.020113606 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.349       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.12        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00971    |
# |    value_loss           | 0.315       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.1        |
# |    ep_rew_mean          | 18.9        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 17          |
# |    time_elapsed         | 1230        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.025910184 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.123       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00748    |
# |    value_loss           | 0.225       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.2        |
# |    ep_rew_mean          | 16.7        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 18          |
# |    time_elapsed         | 1302        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.022627704 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.421       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0657      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00677    |
# |    value_loss           | 0.267       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.7        |
# |    ep_rew_mean          | 17.2        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 19          |
# |    time_elapsed         | 1375        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.013747783 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.39        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.345       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00662    |
# |    value_loss           | 0.479       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.5        |
# |    ep_rew_mean          | 16.4        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 20          |
# |    time_elapsed         | 1448        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011886986 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.389       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.266       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00861    |
# |    value_loss           | 0.413       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 21.8       |
# |    ep_rew_mean          | 17.2       |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 21         |
# |    time_elapsed         | 1519       |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01775424 |
# |    clip_fraction        | 0.2        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | 0.421      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.173      |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0066    |
# |    value_loss           | 0.455      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.1        |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 22          |
# |    time_elapsed         | 1591        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.016935602 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.45        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0532      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0056     |
# |    value_loss           | 0.357       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.7        |
# |    ep_rew_mean          | 17          |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 23          |
# |    time_elapsed         | 1663        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.017522534 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.966      |
# |    explained_variance   | 0.515       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0805      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00219    |
# |    value_loss           | 0.272       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.2        |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 24          |
# |    time_elapsed         | 1738        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.017883664 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.963      |
# |    explained_variance   | 0.405       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.311       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00237    |
# |    value_loss           | 0.384       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.5        |
# |    ep_rew_mean          | 18.6        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 25          |
# |    time_elapsed         | 1812        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014238916 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.976      |
# |    explained_variance   | 0.502       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0738      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00326    |
# |    value_loss           | 0.244       |
# -----------------------------------------

# %%
env = gym.make("highway-fast-v0", render_mode='rgb_array')
pprint.pprint(env.config)

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="roundabout_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("roundabout_ppo/model")

# %%
env = gym.make("highway-fast-v0", render_mode='rgb_array')
pprint.pprint(env.config)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -1,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'type': 'Kinematics'},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 5,
#  'vehicles_count': 20,
#  'vehicles_density': 1}
# C:\Users\Caty\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.config to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.config` for environment variables or `env.get_wrapper_attr('config')` that will search the reminding wrappers.
#   logger.warn(

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="highway_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("highway_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to highway_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.4     |
# |    ep_rew_mean     | 8.48     |
# | time/              |          |
# |    fps             | 29       |
# |    iterations      | 1        |
# |    time_elapsed    | 69       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13          |
# |    ep_rew_mean          | 9.62        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 2           |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012132661 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | -0.0136     |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.295       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0237     |
# |    value_loss           | 0.951       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.3        |
# |    ep_rew_mean          | 12          |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 3           |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014241967 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.185       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.302       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0213     |
# |    value_loss           | 0.861       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.1        |
# |    ep_rew_mean          | 12.4        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 4           |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011689065 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.17        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.458       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 0.737       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.2        |
# |    ep_rew_mean          | 14.9        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 5           |
# |    time_elapsed         | 352         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013840919 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.18        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.218       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 0.703       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.9        |
# |    ep_rew_mean          | 16.1        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 6           |
# |    time_elapsed         | 425         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012772065 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.182       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.322       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 0.536       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.6        |
# |    ep_rew_mean          | 15.8        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 7           |
# |    time_elapsed         | 500         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013207326 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.143       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.239       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.463       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.5        |
# |    ep_rew_mean          | 15.9        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 8           |
# |    time_elapsed         | 574         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012675397 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.227       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.221       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.429       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.4        |
# |    ep_rew_mean          | 17.4        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 9           |
# |    time_elapsed         | 649         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.013627248 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.289       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.256       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.409       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.9         |
# |    ep_rew_mean          | 16.9         |
# | time/                   |              |
# |    fps                  | 28           |
# |    iterations           | 10           |
# |    time_elapsed         | 723          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0103590805 |
# |    clip_fraction        | 0.172        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.288        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.163        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00825     |
# |    value_loss           | 0.339        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.7        |
# |    ep_rew_mean          | 18.4        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 11          |
# |    time_elapsed         | 800         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010771954 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.292       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.057       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00954    |
# |    value_loss           | 0.373       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.1        |
# |    ep_rew_mean          | 20.2        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 12          |
# |    time_elapsed         | 873         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.025523266 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.152       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.271       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.5        |
# |    ep_rew_mean          | 20.2        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 13          |
# |    time_elapsed         | 947         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.032878075 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.277       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0304     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.181       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.9        |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 14          |
# |    time_elapsed         | 1018        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.018409964 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.37        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00804     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00451    |
# |    value_loss           | 0.238       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.4        |
# |    ep_rew_mean          | 18.8        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 15          |
# |    time_elapsed         | 1089        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.016421556 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.382       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.111       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0037     |
# |    value_loss           | 0.272       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.4        |
# |    ep_rew_mean          | 19.7        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 16          |
# |    time_elapsed         | 1159        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.020113606 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.349       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.12        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00971    |
# |    value_loss           | 0.315       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.1        |
# |    ep_rew_mean          | 18.9        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 17          |
# |    time_elapsed         | 1230        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.025910184 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.123       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00748    |
# |    value_loss           | 0.225       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.2        |
# |    ep_rew_mean          | 16.7        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 18          |
# |    time_elapsed         | 1302        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.022627704 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.421       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0657      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00677    |
# |    value_loss           | 0.267       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.7        |
# |    ep_rew_mean          | 17.2        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 19          |
# |    time_elapsed         | 1375        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.013747783 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.39        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.345       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00662    |
# |    value_loss           | 0.479       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.5        |
# |    ep_rew_mean          | 16.4        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 20          |
# |    time_elapsed         | 1448        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011886986 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.389       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.266       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00861    |
# |    value_loss           | 0.413       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 21.8       |
# |    ep_rew_mean          | 17.2       |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 21         |
# |    time_elapsed         | 1519       |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01775424 |
# |    clip_fraction        | 0.2        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | 0.421      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.173      |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0066    |
# |    value_loss           | 0.455      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.1        |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 22          |
# |    time_elapsed         | 1591        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.016935602 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.45        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0532      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0056     |
# |    value_loss           | 0.357       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.7        |
# |    ep_rew_mean          | 17          |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 23          |
# |    time_elapsed         | 1663        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.017522534 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.966      |
# |    explained_variance   | 0.515       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0805      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00219    |
# |    value_loss           | 0.272       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.2        |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 24          |
# |    time_elapsed         | 1738        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.017883664 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.963      |
# |    explained_variance   | 0.405       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.311       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00237    |
# |    value_loss           | 0.384       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.5        |
# |    ep_rew_mean          | 18.6        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 25          |
# |    time_elapsed         | 1812        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014238916 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.976      |
# |    explained_variance   | 0.502       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0738      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00326    |
# |    value_loss           | 0.244       |
# -----------------------------------------

# %% [markdown]
# #### Merge Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- vehicle's count:** 5

# %%
env = gym.make("merge-v0", render_mode='rgb_array')
pprint.pprint(env.config)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -1,
#  'high_speed_reward': 0.2,
#  'lane_change_reward': -0.05,
#  'manual_control': False,
#  'merging_speed_reward': -0.5,
#  'observation': {'type': 'Kinematics'},
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15}
# C:\Users\Caty\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.config to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.config` for environment variables or `env.get_wrapper_attr('config')` that will search the reminding wrappers.
#   logger.warn(

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="merge_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("merge_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to merge_ppo/PPO_1
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.95     |
# |    ep_rew_mean     | 7.43     |
# | time/              |          |
# |    fps             | 41       |
# |    iterations      | 1        |
# |    time_elapsed    | 49       |
# |    total_timesteps | 2048     |
# ---------------------------------
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# ...
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.7        |
# |    ep_rew_mean          | 13.3        |
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 25          |
# |    time_elapsed         | 1241        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.023726096 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.728      |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0319      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0064     |
# |    value_loss           | 0.103       |
# -----------------------------------------

# %% [markdown]
# #### Roundabout Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- vehicle's count:** 5

# %%
env = gym.make("roundabout-v0", render_mode='rgb_array')
pprint.pprint(env.config)
# Out:
# {'action': {'target_speeds': [0, 8, 16], 'type': 'DiscreteMetaAction'},
#  'centering_position': [0.5, 0.6],
#  'collision_reward': -1,
#  'duration': 11,
#  'high_speed_reward': 0.2,
#  'incoming_vehicle_destination': None,
#  'lane_change_reward': -0.05,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'absolute': True,
#                  'features_range': {'vx': [-15, 15],
#                                     'vy': [-15, 15],
#                                     'x': [-100, 100],
#                                     'y': [-100, 100]},
#                  'type': 'Kinematics'},
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'right_lane_reward': 0,
#  'scaling': 5.5,
#  'screen_height': 600,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15}
# C:\Users\Caty\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.config to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.config` for environment variables or `env.get_wrapper_attr('config')` that will search the reminding wrappers.
#   logger.warn(

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="roundabout_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("roundabout_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to roundabout_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.02     |
# |    ep_rew_mean     | 6.83     |
# | time/              |          |
# |    fps             | 24       |
# |    iterations      | 1        |
# |    time_elapsed    | 82       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.1         |
# |    ep_rew_mean          | 7.87        |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 2           |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014290617 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.0394      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.269       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0202     |
# |    value_loss           | 0.724       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.19        |
# |    ep_rew_mean          | 7.9         |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 3           |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015742956 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.16        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 0.608       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.98        |
# |    ep_rew_mean          | 8.72        |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 4           |
# |    time_elapsed         | 326         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018990232 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.115       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.139       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0219     |
# |    value_loss           | 0.572       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | 9.47        |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 5           |
# |    time_elapsed         | 409         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.022289004 |
# |    clip_fraction        | 0.346       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0557      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0258     |
# |    value_loss           | 0.399       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.5        |
# |    ep_rew_mean          | 9.23        |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 6           |
# |    time_elapsed         | 491         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.020619657 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.0381      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.261       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0192     |
# |    value_loss           | 0.436       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.6        |
# |    ep_rew_mean          | 9.4         |
# | time/                   |             |
# |    fps                  | 24          |
# |    iterations           | 7           |
# |    time_elapsed         | 573         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.018272359 |
# |    clip_fraction        | 0.281       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.0902      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.141       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 0.318       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.5        |
# |    ep_rew_mean          | 9.44        |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 8           |
# |    time_elapsed         | 654         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.030348048 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.053       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0788      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.205       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.6        |
# |    ep_rew_mean          | 9.58        |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 9           |
# |    time_elapsed         | 735         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.017850969 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.122       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.221       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00899    |
# |    value_loss           | 0.472       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.4        |
# |    ep_rew_mean          | 9.37        |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 10          |
# |    time_elapsed         | 817         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.017850226 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.0986      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.136       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00786    |
# |    value_loss           | 0.347       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.5        |
# |    ep_rew_mean          | 9.51        |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 11          |
# |    time_elapsed         | 899         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.022428395 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.134       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.282       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 0.433       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | 9.69        |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 12          |
# |    time_elapsed         | 982         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.018419873 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.157       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0146      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.317       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | 9.62        |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 13          |
# |    time_elapsed         | 1062        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.024006478 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.224       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.171       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00933    |
# |    value_loss           | 0.232       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 9.82        |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 14          |
# |    time_elapsed         | 1144        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.017425368 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0418      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00941    |
# |    value_loss           | 0.184       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11          |
# |    ep_rew_mean          | 9.88        |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 15          |
# |    time_elapsed         | 1223        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.020456586 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.181       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0623      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00665    |
# |    value_loss           | 0.207       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | 9.72        |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 16          |
# |    time_elapsed         | 1304        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.021464527 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.408       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0603      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00913    |
# |    value_loss           | 0.0864      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.8       |
# |    ep_rew_mean          | 9.76       |
# | time/                   |            |
# |    fps                  | 25         |
# |    iterations           | 17         |
# |    time_elapsed         | 1384       |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.02012828 |
# |    clip_fraction        | 0.253      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.999     |
# |    explained_variance   | 0.189      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.174      |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0112    |
# |    value_loss           | 0.23       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | 9.78        |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 18          |
# |    time_elapsed         | 1463        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.024221487 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.999      |
# |    explained_variance   | 0.199       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0433      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 0.22        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | 9.82        |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 19          |
# |    time_elapsed         | 1543        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.020817162 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.964      |
# |    explained_variance   | 0.246       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.144       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.197       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | 9.63        |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 20          |
# |    time_elapsed         | 1626        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.017469257 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.947      |
# |    explained_variance   | 0.157       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.126       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00834    |
# |    value_loss           | 0.337       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | 9.64        |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 21          |
# |    time_elapsed         | 1705        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.021581829 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.917      |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.166       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00716    |
# |    value_loss           | 0.336       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | 9.65        |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 22          |
# |    time_elapsed         | 1788        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.021957615 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | 0.259       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.082       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00756    |
# |    value_loss           | 0.262       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | 9.64        |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 23          |
# |    time_elapsed         | 1869        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.022265624 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.882      |
# |    explained_variance   | 0.273       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0877      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0088     |
# |    value_loss           | 0.208       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 9.8         |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 24          |
# |    time_elapsed         | 1949        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.019165762 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.86       |
# |    explained_variance   | 0.27        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.139       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0083     |
# |    value_loss           | 0.295       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 9.89        |
# | time/                   |             |
# |    fps                  | 25          |
# |    iterations           | 25          |
# |    time_elapsed         | 2028        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.018855596 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.768      |
# |    explained_variance   | 0.291       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0365      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.164       |
# -----------------------------------------

# %% [markdown]
# #### Parking Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- vehicle's count:** 0

# %%
env = gym.make("parking-v0", render_mode='rgb_array')
pprint.pprint(env.config)
# Out:
# {'action': {'type': 'ContinuousAction'},
#  'add_walls': True,
#  'centering_position': [0.5, 0.5],
#  'collision_reward': -5,
#  'controlled_vehicles': 1,
#  'duration': 100,
#  'manual_control': False,
#  'observation': {'features': ['x', 'y', 'vx', 'vy', 'cos_h', 'sin_h'],
#                  'normalize': False,
#                  'scales': [100, 100, 5, 5, 1, 1],
#                  'type': 'KinematicsGoal'},
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 5,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_weights': [1, 0.3, 0, 0, 0.02, 0.02],
#  'scaling': 7,
#  'screen_height': 300,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15,
#  'steering_range': 0.7853981633974483,
#  'success_goal_reward': 0.12,
#  'vehicles_count': 0}
# C:\Users\Caty\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.config to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.config` for environment variables or `env.get_wrapper_attr('config')` that will search the reminding wrappers.
#   logger.warn(

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MultiInputPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="parking_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("parking_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to parking_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.2     |
# |    ep_rew_mean     | -47.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 107      |
# |    iterations      | 1        |
# |    time_elapsed    | 19       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90          |
# |    ep_rew_mean          | -47.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 2           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006549937 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | -0.159      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.418       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00353    |
# |    std                  | 1           |
# |    value_loss           | 0.733       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 85.6         |
# |    ep_rew_mean          | -45          |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 3            |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0066531617 |
# |    clip_fraction        | 0.0525       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.0308       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0984       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00239     |
# |    std                  | 0.999        |
# |    value_loss           | 0.403        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89          |
# |    ep_rew_mean          | -48.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 4           |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008062451 |
# |    clip_fraction        | 0.0785      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | -0.693      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.192       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00648    |
# |    std                  | 1.02        |
# |    value_loss           | 0.383       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.7        |
# |    ep_rew_mean          | -47         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 5           |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008843554 |
# |    clip_fraction        | 0.0959      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.0229      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.131       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00719    |
# |    std                  | 1.02        |
# |    value_loss           | 0.33        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 87.4       |
# |    ep_rew_mean          | -48.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 6          |
# |    time_elapsed         | 124        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00824326 |
# |    clip_fraction        | 0.0892     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.88      |
# |    explained_variance   | -0.0885    |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.163      |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00449   |
# |    std                  | 1.03       |
# |    value_loss           | 0.261      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92.2         |
# |    ep_rew_mean          | -51.5        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 98           |
# |    iterations           | 7            |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0075985673 |
# |    clip_fraction        | 0.0843       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0.0767       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0647       |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00515     |
# |    std                  | 1.04         |
# |    value_loss           | 0.21         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.5        |
# |    ep_rew_mean          | -49.6       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 8           |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006034499 |
# |    clip_fraction        | 0.0638      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.92       |
# |    explained_variance   | 0.655       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0672      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00439    |
# |    std                  | 1.04        |
# |    value_loss           | 0.121       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 89.4       |
# |    ep_rew_mean          | -49.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 9          |
# |    time_elapsed         | 187        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00808694 |
# |    clip_fraction        | 0.0912     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.93      |
# |    explained_variance   | 0.481      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.162      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0061    |
# |    std                  | 1.05       |
# |    value_loss           | 0.169      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.5        |
# |    ep_rew_mean          | -52.8       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 10          |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008760512 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | 0.585       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0181      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00695    |
# |    std                  | 1.04        |
# |    value_loss           | 0.109       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 112         |
# |    ep_rew_mean          | -58.7       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 11          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008167287 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.91       |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00447     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00388    |
# |    std                  | 1.03        |
# |    value_loss           | 0.0652      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 120         |
# |    ep_rew_mean          | -61.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 12          |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013381605 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0608      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00947    |
# |    std                  | 0.991       |
# |    value_loss           | 0.0398      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 123         |
# |    ep_rew_mean          | -60.7       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 13          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008400462 |
# |    clip_fraction        | 0.085       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.709       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0149     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00535    |
# |    std                  | 0.991       |
# |    value_loss           | 0.0559      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 138         |
# |    ep_rew_mean          | -65.9       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 14          |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009138767 |
# |    clip_fraction        | 0.0581      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.479       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0371      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0039     |
# |    std                  | 0.972       |
# |    value_loss           | 0.0798      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 154         |
# |    ep_rew_mean          | -71.9       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 15          |
# |    time_elapsed         | 309         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009907661 |
# |    clip_fraction        | 0.0915      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.585       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0572      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00761    |
# |    std                  | 0.97        |
# |    value_loss           | 0.0587      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 166          |
# |    ep_rew_mean          | -75.5        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 16           |
# |    time_elapsed         | 330          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0124522755 |
# |    clip_fraction        | 0.167        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.838        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0399       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0147      |
# |    std                  | 0.978        |
# |    value_loss           | 0.026        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 179         |
# |    ep_rew_mean          | -79.1       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 17          |
# |    time_elapsed         | 351         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.006324066 |
# |    clip_fraction        | 0.0697      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.499       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.000177   |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00672    |
# |    std                  | 0.97        |
# |    value_loss           | 0.0229      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 195         |
# |    ep_rew_mean          | -84.4       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 18          |
# |    time_elapsed         | 370         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010424897 |
# |    clip_fraction        | 0.0984      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.622       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00468    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00798    |
# |    std                  | 0.935       |
# |    value_loss           | 0.0341      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 195         |
# |    ep_rew_mean          | -81.2       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 19          |
# |    time_elapsed         | 391         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.025818288 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.774       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0312     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0194     |
# |    std                  | 0.931       |
# |    value_loss           | 0.0301      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 184         |
# |    ep_rew_mean          | -75.2       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 20          |
# |    time_elapsed         | 411         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.012223441 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.68       |
# |    explained_variance   | 0.542       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0146      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00446    |
# |    std                  | 0.92        |
# |    value_loss           | 0.0696      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 189         |
# |    ep_rew_mean          | -76.3       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 21          |
# |    time_elapsed         | 431         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.013114435 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.64       |
# |    explained_variance   | 0.772       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0378      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00899    |
# |    std                  | 0.897       |
# |    value_loss           | 0.0862      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 193         |
# |    ep_rew_mean          | -75.5       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 22          |
# |    time_elapsed         | 453         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009490477 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.59       |
# |    explained_variance   | 0.401       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00517     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00593    |
# |    std                  | 0.879       |
# |    value_loss           | 0.0203      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 197         |
# |    ep_rew_mean          | -75.6       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 23          |
# |    time_elapsed         | 474         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.014025692 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.59       |
# |    explained_variance   | 0.73        |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0141     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.889       |
# |    value_loss           | 0.0462      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 212         |
# |    ep_rew_mean          | -79.8       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 24          |
# |    time_elapsed         | 496         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010512869 |
# |    clip_fraction        | 0.0925      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.641       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00371     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00221    |
# |    std                  | 0.861       |
# |    value_loss           | 0.00606     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 223        |
# |    ep_rew_mean          | -83.1      |
# |    success_rate         | 0.01       |
# | time/                   |            |
# |    fps                  | 99         |
# |    iterations           | 25         |
# |    time_elapsed         | 516        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.01540846 |
# |    clip_fraction        | 0.153      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.54      |
# |    explained_variance   | 0.682      |
# |    learning_rate        | 0.0005     |
# |    loss                 | -0.00513   |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.00695   |
# |    std                  | 0.866      |
# |    value_loss           | 0.00567    |
# ----------------------------------------

# %% [markdown]
# #### Intersection Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- vehicle's count:** 15

# %%
env = gym.make("intersection-v0", render_mode='rgb_array')
pprint.pprint(env.config)
# Out:
# {'action': {'lateral': False,
#             'longitudinal': True,
#             'target_speeds': [0, 4.5, 9],
#             'type': 'DiscreteMetaAction'},
#  'arrived_reward': 1,
#  'centering_position': [0.5, 0.6],
#  'collision_reward': -5,
#  'controlled_vehicles': 1,
#  'destination': 'o1',
#  'duration': 13,
#  'high_speed_reward': 1,
#  'initial_vehicle_count': 10,
#  'manual_control': False,
#  'normalize_reward': False,
#  'observation': {'absolute': True,
#                  'features': ['presence',
#                               'x',
#                               'y',
#                               'vx',
#                               'vy',
#                               'cos_h',
#                               'sin_h'],
#                  'features_range': {'vx': [-20, 20],
#                                     'vy': [-20, 20],
#                                     'x': [-100, 100],
#                                     'y': [-100, 100]},
#                  'flatten': False,
#                  'observe_intentions': False,
#                  'type': 'Kinematics',
#                  'vehicles_count': 15},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [7.0, 9.0],
#  'scaling': 7.15,
#  'screen_height': 600,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15,
#  'spawn_probability': 0.6}
# C:\Users\Caty\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gymnasium\envs\registration.py:513: DeprecationWarning: WARN: The environment intersection-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(
# C:\Users\Caty\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.config to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.config` for environment variables or `env.get_wrapper_attr('config')` that will search the reminding wrappers.
#   logger.warn(

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="intersection_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("intersection_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to intersection_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.2     |
# |    ep_rew_mean     | 1.87     |
# | time/              |          |
# |    fps             | 15       |
# |    iterations      | 1        |
# |    time_elapsed    | 128      |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.62        |
# |    ep_rew_mean          | 1.37        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 2           |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.027383491 |
# |    clip_fraction        | 0.386       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.0575     |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.2         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0379     |
# |    value_loss           | 2.63        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.38       |
# |    ep_rew_mean          | 3.28       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 3          |
# |    time_elapsed         | 380        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.05055406 |
# |    clip_fraction        | 0.273      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.997     |
# |    explained_variance   | 0.218      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 1.89       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0304    |
# |    value_loss           | 3.28       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.81        |
# |    ep_rew_mean          | 3.6         |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 4           |
# |    time_elapsed         | 505         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.021368934 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.907      |
# |    explained_variance   | 0.153       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.33        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0208     |
# |    value_loss           | 4.29        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.83        |
# |    ep_rew_mean          | 3.47        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 5           |
# |    time_elapsed         | 628         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013462823 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.847      |
# |    explained_variance   | 0.145       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.89        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 4.94        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.73        |
# |    ep_rew_mean          | 3.69        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 6           |
# |    time_elapsed         | 750         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.017955773 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.792      |
# |    explained_variance   | 0.138       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.6         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 4.79        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.67        |
# |    ep_rew_mean          | 5.03        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 7           |
# |    time_elapsed         | 872         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.015684964 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.722      |
# |    explained_variance   | 0.186       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.17        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00913    |
# |    value_loss           | 4.85        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.33        |
# |    ep_rew_mean          | 4           |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 8           |
# |    time_elapsed         | 997         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.018318824 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.694      |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.97        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 4.82        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.8         |
# |    ep_rew_mean          | 4.58        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 9           |
# |    time_elapsed         | 1124        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012731836 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | 0.198       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.57        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 5           |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.53        |
# |    ep_rew_mean          | 4.16        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 10          |
# |    time_elapsed         | 1248        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.018855358 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.655      |
# |    explained_variance   | 0.2         |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.77        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 4.26        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 7.79      |
# |    ep_rew_mean          | 4.96      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 11        |
# |    time_elapsed         | 1369      |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 0.0165778 |
# |    clip_fraction        | 0.132     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.622    |
# |    explained_variance   | 0.133     |
# |    learning_rate        | 0.0005    |
# |    loss                 | 2.61      |
# |    n_updates            | 100       |
# |    policy_gradient_loss | -0.0123   |
# |    value_loss           | 4.84      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.55        |
# |    ep_rew_mean          | 4.51        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 12          |
# |    time_elapsed         | 1491        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.016865594 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.603      |
# |    explained_variance   | 0.241       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.58        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 4.25        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.18        |
# |    ep_rew_mean          | 3.44        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 13          |
# |    time_elapsed         | 1612        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.014365779 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | 0.164       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.15        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0088     |
# |    value_loss           | 4.72        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.31        |
# |    ep_rew_mean          | 3.83        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 14          |
# |    time_elapsed         | 1735        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.018593099 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.593      |
# |    explained_variance   | 0.211       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.93        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00872    |
# |    value_loss           | 4.39        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.66        |
# |    ep_rew_mean          | 4.41        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 15          |
# |    time_elapsed         | 1855        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012084245 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.576      |
# |    explained_variance   | 0.175       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.96        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 4.45        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.98        |
# |    ep_rew_mean          | 3.52        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 16          |
# |    time_elapsed         | 1977        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.015563409 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.567      |
# |    explained_variance   | 0.172       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.1         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 4.85        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.68       |
# |    ep_rew_mean          | 4.64       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 17         |
# |    time_elapsed         | 2104       |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.01628358 |
# |    clip_fraction        | 0.124      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.566     |
# |    explained_variance   | 0.187      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 2.46       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0115    |
# |    value_loss           | 4.67       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.64       |
# |    ep_rew_mean          | 4.5        |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 18         |
# |    time_elapsed         | 2227       |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.02167255 |
# |    clip_fraction        | 0.149      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.564     |
# |    explained_variance   | 0.252      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 2.04       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0112    |
# |    value_loss           | 4.04       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.41        |
# |    ep_rew_mean          | 4.41        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 19          |
# |    time_elapsed         | 2352        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011048983 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.569      |
# |    explained_variance   | 0.214       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.59        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 4.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.76        |
# |    ep_rew_mean          | 4.98        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 20          |
# |    time_elapsed         | 2479        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.014031641 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.574      |
# |    explained_variance   | 0.199       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.96        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 4.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.15        |
# |    ep_rew_mean          | 3.69        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 21          |
# |    time_elapsed         | 2594        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.015073435 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.559      |
# |    explained_variance   | 0.214       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.81        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0162     |
# |    value_loss           | 3.98        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.35        |
# |    ep_rew_mean          | 3.53        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 22          |
# |    time_elapsed         | 2717        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010332905 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.573      |
# |    explained_variance   | 0.186       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.92        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 4.79        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.55        |
# |    ep_rew_mean          | 4.31        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 23          |
# |    time_elapsed         | 2839        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.012665506 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.576      |
# |    explained_variance   | 0.181       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.42        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 4.56        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.02        |
# |    ep_rew_mean          | 4.99        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 24          |
# |    time_elapsed         | 2963        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.017346513 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.564      |
# |    explained_variance   | 0.2         |
# |    learning_rate        | 0.0005      |
# |    loss                 | 3.03        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 4.42        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.39       |
# |    ep_rew_mean          | 4.11       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 25         |
# |    time_elapsed         | 3084       |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.01518292 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.553     |
# |    explained_variance   | 0.188      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 1.95       |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0171    |
# |    value_loss           | 4.04       |
# ----------------------------------------

# %% [markdown]
# #### Load and Test the models

# %%
path = "highway_ppo/model" # Path to the model you would like to test
model = PPO.load(path)
while True:
  done = truncated = False
  obs, info = env.reset()
  while not (done or truncated):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, truncated, info = env.step(action)
    env.render()
