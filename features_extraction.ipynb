# %% [markdown]
# # **Features and Metafeatures' Extraction**

# %%
import os
import json
import numpy as np
import pandas as pd
import gymnasium as gym
from sklearn.preprocessing import LabelEncoder
from stable_baselines3 import PPO, A2C, DQN
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %% [markdown]
# ## **Funções**

# %%
# Função para detectar o algoritmo com base no nome do arquivo
def detect_algorithm(folder, env_config_mapping):
    algorithm_name = env_config_mapping.get(folder, {}).get("model", None)
    
    algorithm_mapping = {
        "PPO": PPO,
        "A2C": A2C,
        "DQN": DQN
    }
    
    return algorithm_mapping.get(algorithm_name)

# %%
# Função para criar o ambiente e verificar o tipo de observação
def create_environment(folder, env_config_mapping, observation_type):
    env_config = env_config_mapping.get(folder, {})
    env = gym.make("highway-v0")
    env.unwrapped.configure(env_config)
    return env

# %%
def extract_features_from_model(model, env, n_episodes=100):
    # Listas para armazenar as métricas por episódio
    performance_data = []
    print("a")
    for episode in range(n_episodes):
        done = truncated = False
        print("b")
        obs, info = env.reset()
        episode_reward = 0
        time_steps = 0
        print("c")
        while not (done or truncated):
            print("d")
            print("Obs Shape na funcao extract: ", obs.shape)
            import inspect
            source_code = inspect.getsource(model.predict)
            print(source_code)
            action, _states = model.predict(obs, deterministic=True) # ERRO AQUI
            print("e")
            new_obs, reward, done, truncated, info = env.step(action)
            print("f")
            episode_reward += reward
            time_steps += 1
    
            # Armazenar informações de desempenho a cada passo
            performance_data.append({
                'Reward': reward,
                'Step': time_steps,
                'Speed': info.get('speed', np.nan),
                'Crashed': info.get('crashed', False),
                'Collision Reward': info.get('rewards', {}).get('collision_reward', 0),
                'Right Lane Reward': info.get('rewards', {}).get('right_lane_reward', 0),
                'High Speed Reward': info.get('rewards', {}).get('high_speed_reward', 0),
                'On Road Reward': info.get('rewards', {}).get('on_road_reward', 0),
            })

            obs = new_obs

    # Criação do DataFrame de desempenho
    performance_df = pd.DataFrame(performance_data)

    # Cálculo das métricas agregadas para o modelo
    average_reward = performance_df['Reward'].mean()
    reward_stddev = performance_df['Reward'].std()
    observation_variance = performance_df['Speed'].var()
    action_variance = performance_df['Reward'].var()
    total_transitions = len(performance_df)
    crash_rate = performance_df['Crashed'].mean()
    average_collision_reward = performance_df['Collision Reward'].mean()
    average_right_lane_reward = performance_df['Right Lane Reward'].mean()
    average_high_speed_reward = performance_df['High Speed Reward'].mean()
    average_on_road_reward = performance_df['On Road Reward'].mean()
    average_episode_length = performance_df['Step'].max()

    # Cálculo das novas métricas
    reward_sparsity = (performance_df['Reward'] != 0).mean()  # Proporção de recompensas não nulas
    transition_rewards_variance = performance_df['Reward'].var()

    # Obter o tipo de observação
    observation_type = env.unwrapped.config.get('observation', {}).get('type', 'Unknown')

    # Verificar se o tipo de observação é LidarObservation ou TimeToCollision e adicionar suas métricas
    max_range = None
    horizon = None
    if observation_type == "LidarObservation":
        max_range = env.unwrapped.config.get('observation', {}).get('max_range', 'N/A')
    elif observation_type == "TimeToCollision":
        horizon = env.unwrapped.config.get('observation', {}).get('horizon', 'N/A')

    # Obter Initial Lane Id e Ego Spacing
    initial_lane_id = env.unwrapped.config.get('initial_lane_id', 'N/A')
    ego_spacing = env.unwrapped.config.get('ego_spacing', 'N/A')

    # Obter o nome do algoritmo
    algorithm_name = model.__class__.__name__

    # Criar um dicionário com as informações do ambiente e as métricas agregadas
    env_config = {
        'Duration': env.unwrapped.config.get('duration', 'N/A'),
        'Number of Lanes': env.unwrapped.config.get('lanes_count', 'N/A'),
        'Number of Vehicles': env.unwrapped.config.get('vehicles_count', 'N/A'),
        'Vehicles Density': env.unwrapped.config.get('vehicles_density', 'N/A'),
        'Reward Speed Range': str(env.unwrapped.config.get('reward_speed_range', 'N/A')),
        'Scaling Factor': env.unwrapped.config.get('scaling', 'N/A'),
        'Algorithm': algorithm_name,
        'Average Reward': average_reward,
        'Reward Standard Deviation': reward_stddev,
        'Observation Variance': observation_variance,
        'Action Variance': action_variance,
        'Number of Transitions Observed': total_transitions,
        'Crash Rate': crash_rate,
        'Average Collision Reward': average_collision_reward,
        'Average Right Lane Reward': average_right_lane_reward,
        'Average High Speed Reward': average_high_speed_reward,
        'Average On Road Reward': average_on_road_reward,
        'Average Episode Length': average_episode_length,
        'Reward Sparsity': reward_sparsity,  # Sparsidade da recompensa
        'Transition Rewards Variance': transition_rewards_variance,  # Variância das recompensas
        'Observation Type': observation_type,  # Tipo de observação
        'Maximum Range (Lidar)': max_range,  # Alcance máximo (se for Lidar)
        'Horizon (TimeToCollision)': horizon,  # Horizonte (se for TimeToCollision)
        'Initial Lane Id': initial_lane_id,  # ID da faixa inicial
        'Ego Spacing': ego_spacing,  # Distância inicial do ego
    }

    # Transformar o dicionário em um DataFrame com uma única linha
    summary_df = pd.DataFrame([env_config])

    return {
        'summary_df': summary_df,
    }

# %% [markdown]
# ## **Com Lidar e TTC - DÁ ERRO OBS SHAPE**

# %%
# Caminho principal para os modelos
base_path = r'C:\Users\Caty\Documents\HighWay-Env\Highway-Env-Tests\HighWay'

# Carregar o mapeamento de ambientes e suas configurações
try:
    with open('environment_config.json', 'r') as f:
        env_config_mapping = json.load(f)
except FileNotFoundError:
    print("Arquivo 'environment_config.json' não encontrado.")
    env_config_mapping = {}

# Lista para armazenar dados de cada modelo
all_models_data = []

# Lista final de todos os DataFrames
all_summaries = []

# Caminho do arquivo txt onde serão salvos os caminhos dos modelos ignorados
ignored_models_file = 'ignored_models.txt'

# Carregar os caminhos dos modelos ignorados
try:
    with open(ignored_models_file, 'r') as f:
        ignored_model_paths = f.read().splitlines()  # Carregar cada linha (caminho) em uma lista
except FileNotFoundError:
    print(f"Arquivo '{ignored_models_file}' não encontrado.")
    ignored_model_paths = []

# Iterar sobre os caminhos dos modelos no arquivo 'ignored_models.txt'
for model_path in ignored_model_paths:
    try:
        # Extrair o nome da pasta a partir do caminho do modelo
        folder = os.path.basename(os.path.dirname(model_path))

        observation_type = env_config_mapping.get(folder, {}).get('observation', {}).get('type', 'Unknown')

        Algorithm = detect_algorithm(folder, env_config_mapping)
        
        if Algorithm is None:
            raise ValueError(f"Algoritmo não detectado para {folder}")
        
        model = Algorithm.load(model_path)
        
        # Criar o ambiente e verificar o tipo de observação
        env = create_environment(folder, env_config_mapping, observation_type)
        # print("wlwlwlekekjrkjhfe")
        
        model.set_env(env)


        # print("c")

        extracted_data = extract_features_from_model(model, env, n_episodes=100)
        print(extracted_data['summary_df'])

        if not extracted_data['summary_df'].empty:
            all_summaries.append(extracted_data['summary_df'])

    except Exception as e:
        print(f"Erro ao carregar modelo {model_path}: {e}")

# Concatenar os DataFrames de todos os modelos
if all_summaries:
    summary_df_combined = pd.concat(all_summaries, ignore_index=True)
    # Salvar ou processar o DataFrame combinado conforme necessário
    summary_df_combined.to_csv('summary_df_combined.csv', index=True)

# %% [markdown]
# ## **Sem Lidar e TTC - FUNCIONA DIREITO, COMENTADO PARA NÃO CORRER O RISCO DE CORRER DUAS VEZES**

# %%
# # Caminho principal para os modelos
# base_path = r'C:\Users\Caty\Documents\HighWay-Env\Highway-Env-Tests\HighWay'

# # Carregar o mapeamento de ambientes e suas configurações
# try:
#     with open('environment_config.json', 'r') as f:
#         env_config_mapping = json.load(f)
# except FileNotFoundError:
#     print("Arquivo 'environment_config.json' não encontrado.")
#     env_config_mapping = {}

# # Lista para armazenar dados de cada modelo
# all_models_data = []

# # Lista final de todos os DataFrames
# all_summaries = []

# # Caminho do arquivo txt onde serão salvos os caminhos dos modelos ignorados
# ignored_models_file = 'ignored_models.txt'

# # Limpar o arquivo txt antes de começar a adicionar os caminhos
# with open(ignored_models_file, 'w') as f:
#     f.write("Modelos ignorados (LidarObservation ou TimeToCollision):\n")

# # Iterar sobre todas as pastas
# for folder in os.listdir(base_path):
#     folder_path = os.path.join(base_path, folder)

#     if os.path.isdir(folder_path):
#         for model_file in os.listdir(folder_path):
#             if model_file.endswith('.zip'):
#                 model_path = os.path.join(folder_path, model_file)

#                 try:
#                     observation_type = env_config_mapping.get(folder, {}).get('observation', {}).get('type', 'Unknown')
#                     # print(f"Observation type: {observation_type}")  

#                     # Ignorar modelos com observação LidarObservation ou TimeToCollision
#                     if observation_type in ['LidarObservation', 'TimeToCollision']:
#                         with open(ignored_models_file, 'a') as f:
#                             f.write(f"{model_path}\n")  # Escrever o caminho do modelo ignorado
#                         continue  # Pular para o próximo modelo

#                     Algorithm = detect_algorithm(folder, env_config_mapping)
                    
#                     if Algorithm is None:
#                         raise ValueError(f"Algoritmo não detectado para {folder}")
                    
#                     model = Algorithm.load(model_path)

#                     # Criar o ambiente e verificar o tipo de observação
#                     env = create_environment(folder, env_config_mapping)

#                     model.set_env(env)

#                     extracted_data = extract_features_from_model(model, env, n_episodes=100)
#                     print(extracted_data['summary_df'])
                    
#                     if not extracted_data['summary_df'].empty:
#                         all_summaries.append(extracted_data['summary_df'])

#                 except Exception as e:
#                     print(f"Erro ao carregar modelo {model_path}: {e}")

# # Concatenar os DataFrames de todos os modelos
# if all_summaries:
#     summary_df_combined = pd.concat(all_summaries, ignore_index=True)
#     # Salvar ou processar o DataFrame combinado conforme necessário
#     summary_df_combined.to_csv('summary_df_combined.csv', index=True)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        60                4                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.754729
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.075884              6.111606  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.125825                     1.0                      60
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0              1.0                     0.005758        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  40                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.765053
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.089004              9.313594  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.171923                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.999175                     0.007922        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        38                4                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.760916
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.086899              7.936457  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.154855                     1.0                      38
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0              1.0                     0.007551        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  25                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.766873
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.094445             10.303575  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.196252                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.999732                      0.00892        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        45                4                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.762661
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.091617              9.970945  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.184761                     1.0                      45
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.999065                     0.008394        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  30                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.750377
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.083105              7.675548  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.143556                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.999476                     0.006906        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        53                4                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO           0.759
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.075456              7.161883  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.140153                     1.0                      53
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.999604                     0.005694        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  35                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.766752
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.080824              8.266295  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.171698                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.999209                     0.006533        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       A2C        0.787108
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.142239              9.616851  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.278131                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0              1.0                     0.020232        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        60                8                  30               1.5
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [40, 50]             5.5       DQN        0.697054
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.043973              0.924906  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                        0.0                     1.0                      60
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.999622                     0.001934        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0          2.0
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        60                7                  25               1.5
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [50, 60]             5.5       A2C          0.7253
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.059443              0.749042  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                        0.0                     1.0                      60
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0              1.0                     0.003533        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0          0.5
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        60                5                  30                 3
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [50, 60]             5.5       DQN        0.680694
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.129229              3.634517  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                        0.0                     1.0                      60
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.996053                       0.0167        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0          0.5
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        45                8                  40               1.5
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [30, 40]             5.5       DQN        0.712413
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.071892              2.586437  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                        0.0                     1.0                      45
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.999385                     0.005168        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0          2.5
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        53                8                  40               2.5
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [30, 40]             5.5       A2C        0.681003
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.141986              6.604188  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                        0.0                     1.0                      53
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.995906                      0.02016        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0          2.5
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        45                6                  25               1.5
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [60, 70]             5.5       PPO        0.706439
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.053405              0.554028  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                        0.0                     1.0                      45
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.997376                     0.002852        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0          2.0
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        53                8                  40                 2
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [30, 40]             5.5       A2C         0.69465
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.090599              1.200363  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                        0.0                     1.0                      53
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0          0.99901                     0.008208        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0          1.0
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        60                5                  30                 2
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [30, 40]             5.5       DQN        0.693543
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.074796              1.194107  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                        0.0                     1.0                      60
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.996256                     0.005594        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0          2.0
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        45                4                  25               1.5
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [40, 50]             5.5       DQN        0.704859
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.053101              3.650502  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                        0.0                     1.0                      45
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.999746                      0.00282        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0          1.0
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        60                4                  35                 3
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [40, 50]             5.5       A2C        0.553806
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.274377             10.871817  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                        0.0                     1.0                      60
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.910638                     0.075283        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0          0.5
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        45                4                  35                 2
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [40, 50]             5.5       A2C        0.659643
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.153323              4.042209  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                        0.0                     1.0                      45
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.985634                     0.023508        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0          0.5
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        45                7                  25               2.5
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [50, 60]             5.5       PPO        0.680788
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.102138              1.646896  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                        0.0                     1.0                      45
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0            0.997                     0.010432        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0          0.5
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       DQN        0.802811
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.128996             16.578497  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.417623                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.997972                      0.01664        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.750529
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.088792             10.676438  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.193113                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.999474                     0.007884        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None                0
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.758652
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.077287              7.612426  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                    0.16649                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.999747                     0.005973        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None                1
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.754504
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.083432              7.521677  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.136272                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0              1.0                     0.006961        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None                2
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.766871
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.088765              9.216558  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.178433                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.999179                     0.007879        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0          1.0
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.759588
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.091529              9.213586  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.186402                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.997785                     0.008378        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0          0.5
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  50               1.5
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.702205
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.107425              3.437137  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.046224                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.993121                      0.01154        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.753933
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                    0.08651              7.712639  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.154068                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.999735                     0.007484        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0          2.0
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  50               2.5
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.637844
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                    0.25739             15.522815  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.130943                     1.0                      29
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.951183                      0.06625        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  50                 2
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.664326
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.168668              4.507179  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.017959                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.990278                     0.028449        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.770862
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.098449             11.622767  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.217346                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.998634                     0.009692        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.761926
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.086398              8.569741  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.184668                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.999206                     0.007465        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0          2.5
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  50                 3
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.598077
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.291666             18.258117  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.137939                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0          0.92418                     0.085069        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                5                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.779357
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.106079              11.69447  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                    0.25242                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.999721                     0.011253        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                6                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO         0.78492
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.124905              14.85704  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.296311                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.997259                     0.015601        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                7                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.764076
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.132381             14.091488  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                    0.27758                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.993935                     0.017525        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                8                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.765413
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.101697              8.243527  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.233496                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.996928                     0.010342        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [20, 30]             5.5       PPO        0.759919
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.084344              8.344514  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                   0.156195                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.999469                     0.007114        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [30, 40]             5.5       PPO        0.729215
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.020332               0.59352  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                        0.0                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0              1.0                     0.000413        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [40, 50]             5.5       PPO        0.726283
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.027628              1.552794  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                        0.0                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0              1.0                     0.000763        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [50, 60]             5.5       PPO        0.729165
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                     0.0286              1.204433  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                        0.0                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.999486                     0.000818        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#    Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0        40                4                  50                 1
#
#   Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0           [60, 70]             5.5       PPO        0.724412
#
#    Reward Standard Deviation  Observation Variance  ...  \
# 0                   0.032119              1.523506  ...
#
#    Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                        0.0                     1.0                      40
#
#    Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0         0.998713                     0.001032        Kinematics
#
#    Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                   None                       None             None
#
#    Ego Spacing
# 0            2
#
# [1 rows x 25 columns]

# %%
summary_df_combined 
# DATASET VINDO DA EXTRAÇÃO SEM LIDAR E TTC
# Out:
#     Duration  Number of Lanes  Number of Vehicles  Vehicles Density  \
# 0         60                4                  50               1.0
# 1         40                4                  40               1.0
# 2         38                4                  50               1.0
# 3         40                4                  25               1.0
# 4         45                4                  50               1.0
# 5         40                4                  30               1.0
# 6         53                4                  50               1.0
# 7         40                4                  35               1.0
# 8         40                4                  50               1.0
# 9         60                8                  30               1.5
# 10        60                7                  25               1.5
# 11        60                5                  30               3.0
# 12        45                8                  40               1.5
# 13        53                8                  40               2.5
# 14        45                6                  25               1.5
# 15        53                8                  40               2.0
# 16        60                5                  30               2.0
# 17        45                4                  25               1.5
# 18        60                4                  35               3.0
# 19        45                4                  35               2.0
# 20        45                7                  25               2.5
# 21        40                4                  50               1.0
# 22        40                4                  50               1.0
# 23        40                4                  50               1.0
# 24        40                4                  50               1.0
# 25        40                4                  50               1.0
# 26        40                4                  50               1.0
# 27        40                4                  50               1.5
# 28        40                4                  50               1.0
# 29        40                4                  50               2.5
# 30        40                4                  50               2.0
# 31        40                4                  50               1.0
# 32        40                4                  50               1.0
# 33        40                4                  50               3.0
# 34        40                5                  50               1.0
# 35        40                6                  50               1.0
# 36        40                7                  50               1.0
# 37        40                8                  50               1.0
# 38        40                4                  50               1.0
# 39        40                4                  50               1.0
# 40        40                4                  50               1.0
# 41        40                4                  50               1.0
# 42        40                4                  50               1.0
#
#    Reward Speed Range  Scaling Factor Algorithm  Average Reward  \
# 0            [20, 30]             5.5       PPO        0.754729
# 1            [20, 30]             5.5       PPO        0.765053
# 2            [20, 30]             5.5       PPO        0.760916
# 3            [20, 30]             5.5       PPO        0.766873
# 4            [20, 30]             5.5       PPO        0.762661
# 5            [20, 30]             5.5       PPO        0.750377
# 6            [20, 30]             5.5       PPO        0.759000
# 7            [20, 30]             5.5       PPO        0.766752
# 8            [20, 30]             5.5       A2C        0.787108
# 9            [40, 50]             5.5       DQN        0.697054
# 10           [50, 60]             5.5       A2C        0.725300
# 11           [50, 60]             5.5       DQN        0.680694
# 12           [30, 40]             5.5       DQN        0.712413
# 13           [30, 40]             5.5       A2C        0.681003
# 14           [60, 70]             5.5       PPO        0.706439
# 15           [30, 40]             5.5       A2C        0.694650
# 16           [30, 40]             5.5       DQN        0.693543
# 17           [40, 50]             5.5       DQN        0.704859
# 18           [40, 50]             5.5       A2C        0.553806
# 19           [40, 50]             5.5       A2C        0.659643
# 20           [50, 60]             5.5       PPO        0.680788
# 21           [20, 30]             5.5       DQN        0.802811
# 22           [20, 30]             5.5       PPO        0.750529
# 23           [20, 30]             5.5       PPO        0.758652
# 24           [20, 30]             5.5       PPO        0.754504
# 25           [20, 30]             5.5       PPO        0.766871
# 26           [20, 30]             5.5       PPO        0.759588
# 27           [20, 30]             5.5       PPO        0.702205
# 28           [20, 30]             5.5       PPO        0.753933
# 29           [20, 30]             5.5       PPO        0.637844
# 30           [20, 30]             5.5       PPO        0.664326
# 31           [20, 30]             5.5       PPO        0.770862
# 32           [20, 30]             5.5       PPO        0.761926
# 33           [20, 30]             5.5       PPO        0.598077
# 34           [20, 30]             5.5       PPO        0.779357
# 35           [20, 30]             5.5       PPO        0.784920
# 36           [20, 30]             5.5       PPO        0.764076
# 37           [20, 30]             5.5       PPO        0.765413
# 38           [20, 30]             5.5       PPO        0.759919
# 39           [30, 40]             5.5       PPO        0.729215
# 40           [40, 50]             5.5       PPO        0.726283
# 41           [50, 60]             5.5       PPO        0.729165
# 42           [60, 70]             5.5       PPO        0.724412
#
#     Reward Standard Deviation  Observation Variance  ...  \
# 0                    0.075884              6.111606  ...
# 1                    0.089004              9.313594  ...
# 2                    0.086899              7.936457  ...
# 3                    0.094445             10.303575  ...
# 4                    0.091617              9.970945  ...
# 5                    0.083105              7.675548  ...
# 6                    0.075456              7.161883  ...
# 7                    0.080824              8.266295  ...
# 8                    0.142239              9.616851  ...
# 9                    0.043973              0.924906  ...
# 10                   0.059443              0.749042  ...
# 11                   0.129229              3.634517  ...
# 12                   0.071892              2.586437  ...
# 13                   0.141986              6.604188  ...
# 14                   0.053405              0.554028  ...
# 15                   0.090599              1.200363  ...
# 16                   0.074796              1.194107  ...
# 17                   0.053101              3.650502  ...
# 18                   0.274377             10.871817  ...
# 19                   0.153323              4.042209  ...
# 20                   0.102138              1.646896  ...
# 21                   0.128996             16.578497  ...
# 22                   0.088792             10.676438  ...
# 23                   0.077287              7.612426  ...
# 24                   0.083432              7.521677  ...
# 25                   0.088765              9.216558  ...
# 26                   0.091529              9.213586  ...
# 27                   0.107425              3.437137  ...
# 28                   0.086510              7.712639  ...
# 29                   0.257390             15.522815  ...
# 30                   0.168668              4.507179  ...
# 31                   0.098449             11.622767  ...
# 32                   0.086398              8.569741  ...
# 33                   0.291666             18.258117  ...
# 34                   0.106079             11.694470  ...
# 35                   0.124905             14.857040  ...
# 36                   0.132381             14.091488  ...
# 37                   0.101697              8.243527  ...
# 38                   0.084344              8.344514  ...
# 39                   0.020332              0.593520  ...
# 40                   0.027628              1.552794  ...
# 41                   0.028600              1.204433  ...
# 42                   0.032119              1.523506  ...
#
#     Average High Speed Reward  Average On Road Reward  Average Episode Length  \
# 0                    0.125825                     1.0                      60
# 1                    0.171923                     1.0                      40
# 2                    0.154855                     1.0                      38
# 3                    0.196252                     1.0                      40
# 4                    0.184761                     1.0                      45
# 5                    0.143556                     1.0                      40
# 6                    0.140153                     1.0                      53
# 7                    0.171698                     1.0                      40
# 8                    0.278131                     1.0                      40
# 9                    0.000000                     1.0                      60
# 10                   0.000000                     1.0                      60
# 11                   0.000000                     1.0                      60
# 12                   0.000000                     1.0                      45
# 13                   0.000000                     1.0                      53
# 14                   0.000000                     1.0                      45
# 15                   0.000000                     1.0                      53
# 16                   0.000000                     1.0                      60
# 17                   0.000000                     1.0                      45
# 18                   0.000000                     1.0                      60
# 19                   0.000000                     1.0                      45
# 20                   0.000000                     1.0                      45
# 21                   0.417623                     1.0                      40
# 22                   0.193113                     1.0                      40
# 23                   0.166490                     1.0                      40
# 24                   0.136272                     1.0                      40
# 25                   0.178433                     1.0                      40
# 26                   0.186402                     1.0                      40
# 27                   0.046224                     1.0                      40
# 28                   0.154068                     1.0                      40
# 29                   0.130943                     1.0                      29
# 30                   0.017959                     1.0                      40
# 31                   0.217346                     1.0                      40
# 32                   0.184668                     1.0                      40
# 33                   0.137939                     1.0                      40
# 34                   0.252420                     1.0                      40
# 35                   0.296311                     1.0                      40
# 36                   0.277580                     1.0                      40
# 37                   0.233496                     1.0                      40
# 38                   0.156195                     1.0                      40
# 39                   0.000000                     1.0                      40
# 40                   0.000000                     1.0                      40
# 41                   0.000000                     1.0                      40
# 42                   0.000000                     1.0                      40
#
#     Reward Sparsity  Transition Rewards Variance  Observation Type  \
# 0          1.000000                     0.005758        Kinematics
# 1          0.999175                     0.007922        Kinematics
# 2          1.000000                     0.007551        Kinematics
# 3          0.999732                     0.008920        Kinematics
# 4          0.999065                     0.008394        Kinematics
# 5          0.999476                     0.006906        Kinematics
# 6          0.999604                     0.005694        Kinematics
# 7          0.999209                     0.006533        Kinematics
# 8          1.000000                     0.020232        Kinematics
# 9          0.999622                     0.001934        Kinematics
# 10         1.000000                     0.003533        Kinematics
# 11         0.996053                     0.016700        Kinematics
# 12         0.999385                     0.005168        Kinematics
# 13         0.995906                     0.020160        Kinematics
# 14         0.997376                     0.002852        Kinematics
# 15         0.999010                     0.008208        Kinematics
# 16         0.996256                     0.005594        Kinematics
# 17         0.999746                     0.002820        Kinematics
# 18         0.910638                     0.075283        Kinematics
# 19         0.985634                     0.023508        Kinematics
# 20         0.997000                     0.010432        Kinematics
# 21         0.997972                     0.016640        Kinematics
# 22         0.999474                     0.007884        Kinematics
# 23         0.999747                     0.005973        Kinematics
# 24         1.000000                     0.006961        Kinematics
# 25         0.999179                     0.007879        Kinematics
# 26         0.997785                     0.008378        Kinematics
# 27         0.993121                     0.011540        Kinematics
# 28         0.999735                     0.007484        Kinematics
# 29         0.951183                     0.066250        Kinematics
# 30         0.990278                     0.028449        Kinematics
# 31         0.998634                     0.009692        Kinematics
# 32         0.999206                     0.007465        Kinematics
# 33         0.924180                     0.085069        Kinematics
# 34         0.999721                     0.011253        Kinematics
# 35         0.997259                     0.015601        Kinematics
# 36         0.993935                     0.017525        Kinematics
# 37         0.996928                     0.010342        Kinematics
# 38         0.999469                     0.007114        Kinematics
# 39         1.000000                     0.000413        Kinematics
# 40         1.000000                     0.000763        Kinematics
# 41         0.999486                     0.000818        Kinematics
# 42         0.998713                     0.001032        Kinematics
#
#     Maximum Range (Lidar)  Horizon (TimeToCollision)  Initial Lane Id  \
# 0                    None                       None             None
# 1                    None                       None             None
# 2                    None                       None             None
# 3                    None                       None             None
# 4                    None                       None             None
# 5                    None                       None             None
# 6                    None                       None             None
# 7                    None                       None             None
# 8                    None                       None             None
# 9                    None                       None             None
# 10                   None                       None             None
# 11                   None                       None             None
# 12                   None                       None             None
# 13                   None                       None             None
# 14                   None                       None             None
# 15                   None                       None             None
# 16                   None                       None             None
# 17                   None                       None             None
# 18                   None                       None             None
# 19                   None                       None             None
# 20                   None                       None             None
# 21                   None                       None             None
# 22                   None                       None                0
# 23                   None                       None                1
# 24                   None                       None                2
# 25                   None                       None             None
# 26                   None                       None             None
# 27                   None                       None             None
# 28                   None                       None             None
# 29                   None                       None             None
# 30                   None                       None             None
# 31                   None                       None             None
# 32                   None                       None             None
# 33                   None                       None             None
# 34                   None                       None             None
# 35                   None                       None             None
# 36                   None                       None             None
# 37                   None                       None             None
# 38                   None                       None             None
# 39                   None                       None             None
# 40                   None                       None             None
# 41                   None                       None             None
# 42                   None                       None             None
#
#     Ego Spacing
# 0           2.0
# 1           2.0
# 2           2.0
# 3           2.0
# 4           2.0
# 5           2.0
# 6           2.0
# 7           2.0
# 8           2.0
# 9           2.0
# 10          0.5
# 11          0.5
# 12          2.5
# 13          2.5
# 14          2.0
# 15          1.0
# 16          2.0
# 17          1.0
# 18          0.5
# 19          0.5
# 20          0.5
# 21          2.0
# 22          2.0
# 23          2.0
# 24          2.0
# 25          1.0
# 26          0.5
# 27          2.0
# 28          2.0
# 29          2.0
# 30          2.0
# 31          2.0
# 32          2.5
# 33          2.0
# 34          2.0
# 35          2.0
# 36          2.0
# 37          2.0
# 38          2.0
# 39          2.0
# 40          2.0
# 41          2.0
# 42          2.0
#
# [43 rows x 25 columns]

# %%
df = pd.read_csv('summary_df_combined.csv')

# %%
df.fillna("Not Applicable", inplace=True)

# %%
df = df.drop(df.columns[0], axis=1)

# %%
df.to_csv('summary_df_combined_1.csv', index=True)

# %%
df['Initial Lane Id'] = df['Initial Lane Id'].astype(str)

# %%
# PRE-PROCESSAMENTO SIMPLES - O ISA NÃO ACEITA VALORES NULOS NEM CATEGÓRICOS
colunas_nao_numericas = df.select_dtypes(include=['object', 'category']).columns


le = LabelEncoder()

for coluna in colunas_nao_numericas:
    df[coluna] = le.fit_transform(df[coluna])

df
# Out:
#     Number of Lanes  Number of Vehicles  Vehicles Density  Reward Speed Range  \
# 0                 4                  50               1.0                   0
# 1                 4                  40               1.0                   0
# 2                 4                  50               1.0                   0
# 3                 4                  25               1.0                   0
# 4                 4                  50               1.0                   0
# 5                 4                  30               1.0                   0
# 6                 4                  50               1.0                   0
# 7                 4                  35               1.0                   0
# 8                 4                  50               1.0                   0
# 9                 8                  30               1.5                   2
# 10                7                  25               1.5                   3
# 11                5                  30               3.0                   3
# 12                8                  40               1.5                   1
# 13                8                  40               2.5                   1
# 14                6                  25               1.5                   4
# 15                8                  40               2.0                   1
# 16                5                  30               2.0                   1
# 17                4                  25               1.5                   2
# 18                4                  35               3.0                   2
# 19                4                  35               2.0                   2
# 20                7                  25               2.5                   3
# 21                4                  50               1.0                   0
# 22                4                  50               1.0                   0
# 23                4                  50               1.0                   0
# 24                4                  50               1.0                   0
# 25                4                  50               1.0                   0
# 26                4                  50               1.0                   0
# 27                4                  50               1.5                   0
# 28                4                  50               1.0                   0
# 29                4                  50               2.5                   0
# 30                4                  50               2.0                   0
# 31                4                  50               1.0                   0
# 32                4                  50               1.0                   0
# 33                4                  50               3.0                   0
# 34                5                  50               1.0                   0
# 35                6                  50               1.0                   0
# 36                7                  50               1.0                   0
# 37                8                  50               1.0                   0
# 38                4                  50               1.0                   0
# 39                4                  50               1.0                   1
# 40                4                  50               1.0                   2
# 41                4                  50               1.0                   3
# 42                4                  50               1.0                   4
#
#     Scaling Factor  Algorithm  Average Reward  Reward Standard Deviation  \
# 0              5.5          2        0.754729                   0.075884
# 1              5.5          2        0.765053                   0.089004
# 2              5.5          2        0.760916                   0.086899
# 3              5.5          2        0.766873                   0.094445
# 4              5.5          2        0.762661                   0.091617
# 5              5.5          2        0.750377                   0.083105
# 6              5.5          2        0.759000                   0.075456
# 7              5.5          2        0.766752                   0.080824
# 8              5.5          0        0.787108                   0.142239
# 9              5.5          1        0.697054                   0.043973
# 10             5.5          0        0.725300                   0.059443
# 11             5.5          1        0.680694                   0.129229
# 12             5.5          1        0.712413                   0.071892
# 13             5.5          0        0.681003                   0.141986
# 14             5.5          2        0.706439                   0.053405
# 15             5.5          0        0.694650                   0.090599
# 16             5.5          1        0.693543                   0.074796
# 17             5.5          1        0.704859                   0.053101
# 18             5.5          0        0.553806                   0.274377
# 19             5.5          0        0.659643                   0.153323
# 20             5.5          2        0.680788                   0.102138
# 21             5.5          1        0.802811                   0.128996
# 22             5.5          2        0.750529                   0.088792
# 23             5.5          2        0.758652                   0.077287
# 24             5.5          2        0.754504                   0.083432
# 25             5.5          2        0.766871                   0.088765
# 26             5.5          2        0.759588                   0.091529
# 27             5.5          2        0.702205                   0.107425
# 28             5.5          2        0.753933                   0.086510
# 29             5.5          2        0.637844                   0.257390
# 30             5.5          2        0.664326                   0.168668
# 31             5.5          2        0.770862                   0.098449
# 32             5.5          2        0.761926                   0.086398
# 33             5.5          2        0.598077                   0.291666
# 34             5.5          2        0.779357                   0.106079
# 35             5.5          2        0.784920                   0.124905
# 36             5.5          2        0.764076                   0.132381
# 37             5.5          2        0.765413                   0.101697
# 38             5.5          2        0.759919                   0.084344
# 39             5.5          2        0.729215                   0.020332
# 40             5.5          2        0.726283                   0.027628
# 41             5.5          2        0.729165                   0.028600
# 42             5.5          2        0.724412                   0.032119
#
#     Observation Variance  Action Variance  ...  Average High Speed Reward  \
# 0               6.111606         0.005758  ...                   0.125825
# 1               9.313594         0.007922  ...                   0.171923
# 2               7.936457         0.007551  ...                   0.154855
# 3              10.303575         0.008920  ...                   0.196252
# 4               9.970945         0.008394  ...                   0.184761
# 5               7.675548         0.006906  ...                   0.143556
# 6               7.161883         0.005694  ...                   0.140153
# 7               8.266295         0.006533  ...                   0.171698
# 8               9.616851         0.020232  ...                   0.278131
# 9               0.924906         0.001934  ...                   0.000000
# 10              0.749042         0.003533  ...                   0.000000
# 11              3.634517         0.016700  ...                   0.000000
# 12              2.586437         0.005168  ...                   0.000000
# 13              6.604188         0.020160  ...                   0.000000
# 14              0.554028         0.002852  ...                   0.000000
# 15              1.200363         0.008208  ...                   0.000000
# 16              1.194107         0.005594  ...                   0.000000
# 17              3.650502         0.002820  ...                   0.000000
# 18             10.871817         0.075283  ...                   0.000000
# 19              4.042209         0.023508  ...                   0.000000
# 20              1.646896         0.010432  ...                   0.000000
# 21             16.578497         0.016640  ...                   0.417623
# 22             10.676438         0.007884  ...                   0.193113
# 23              7.612426         0.005973  ...                   0.166490
# 24              7.521677         0.006961  ...                   0.136272
# 25              9.216558         0.007879  ...                   0.178433
# 26              9.213586         0.008378  ...                   0.186402
# 27              3.437137         0.011540  ...                   0.046224
# 28              7.712639         0.007484  ...                   0.154068
# 29             15.522815         0.066250  ...                   0.130943
# 30              4.507179         0.028449  ...                   0.017959
# 31             11.622767         0.009692  ...                   0.217346
# 32              8.569741         0.007465  ...                   0.184668
# 33             18.258117         0.085069  ...                   0.137939
# 34             11.694470         0.011253  ...                   0.252420
# 35             14.857040         0.015601  ...                   0.296311
# 36             14.091488         0.017525  ...                   0.277580
# 37              8.243527         0.010342  ...                   0.233496
# 38              8.344514         0.007114  ...                   0.156195
# 39              0.593520         0.000413  ...                   0.000000
# 40              1.552794         0.000763  ...                   0.000000
# 41              1.204433         0.000818  ...                   0.000000
# 42              1.523506         0.001032  ...                   0.000000
#
#     Average On Road Reward  Average Episode Length  Reward Sparsity  \
# 0                      1.0                      60         1.000000
# 1                      1.0                      40         0.999175
# 2                      1.0                      38         1.000000
# 3                      1.0                      40         0.999732
# 4                      1.0                      45         0.999065
# 5                      1.0                      40         0.999476
# 6                      1.0                      53         0.999604
# 7                      1.0                      40         0.999209
# 8                      1.0                      40         1.000000
# 9                      1.0                      60         0.999622
# 10                     1.0                      60         1.000000
# 11                     1.0                      60         0.996053
# 12                     1.0                      45         0.999385
# 13                     1.0                      53         0.995906
# 14                     1.0                      45         0.997376
# 15                     1.0                      53         0.999010
# 16                     1.0                      60         0.996256
# 17                     1.0                      45         0.999746
# 18                     1.0                      60         0.910638
# 19                     1.0                      45         0.985634
# 20                     1.0                      45         0.997000
# 21                     1.0                      40         0.997972
# 22                     1.0                      40         0.999474
# 23                     1.0                      40         0.999747
# 24                     1.0                      40         1.000000
# 25                     1.0                      40         0.999179
# 26                     1.0                      40         0.997785
# 27                     1.0                      40         0.993121
# 28                     1.0                      40         0.999735
# 29                     1.0                      29         0.951183
# 30                     1.0                      40         0.990278
# 31                     1.0                      40         0.998634
# 32                     1.0                      40         0.999206
# 33                     1.0                      40         0.924180
# 34                     1.0                      40         0.999721
# 35                     1.0                      40         0.997259
# 36                     1.0                      40         0.993935
# 37                     1.0                      40         0.996928
# 38                     1.0                      40         0.999469
# 39                     1.0                      40         1.000000
# 40                     1.0                      40         1.000000
# 41                     1.0                      40         0.999486
# 42                     1.0                      40         0.998713
#
#     Transition Rewards Variance  Observation Type  Maximum Range (Lidar)  \
# 0                      0.005758                 0                      0
# 1                      0.007922                 0                      0
# 2                      0.007551                 0                      0
# 3                      0.008920                 0                      0
# 4                      0.008394                 0                      0
# 5                      0.006906                 0                      0
# 6                      0.005694                 0                      0
# 7                      0.006533                 0                      0
# 8                      0.020232                 0                      0
# 9                      0.001934                 0                      0
# 10                     0.003533                 0                      0
# 11                     0.016700                 0                      0
# 12                     0.005168                 0                      0
# 13                     0.020160                 0                      0
# 14                     0.002852                 0                      0
# 15                     0.008208                 0                      0
# 16                     0.005594                 0                      0
# 17                     0.002820                 0                      0
# 18                     0.075283                 0                      0
# 19                     0.023508                 0                      0
# 20                     0.010432                 0                      0
# 21                     0.016640                 0                      0
# 22                     0.007884                 0                      0
# 23                     0.005973                 0                      0
# 24                     0.006961                 0                      0
# 25                     0.007879                 0                      0
# 26                     0.008378                 0                      0
# 27                     0.011540                 0                      0
# 28                     0.007484                 0                      0
# 29                     0.066250                 0                      0
# 30                     0.028449                 0                      0
# 31                     0.009692                 0                      0
# 32                     0.007465                 0                      0
# 33                     0.085069                 0                      0
# 34                     0.011253                 0                      0
# 35                     0.015601                 0                      0
# 36                     0.017525                 0                      0
# 37                     0.010342                 0                      0
# 38                     0.007114                 0                      0
# 39                     0.000413                 0                      0
# 40                     0.000763                 0                      0
# 41                     0.000818                 0                      0
# 42                     0.001032                 0                      0
#
#     Horizon (TimeToCollision)  Initial Lane Id  Ego Spacing
# 0                           0                3          2.0
# 1                           0                3          2.0
# 2                           0                3          2.0
# 3                           0                3          2.0
# 4                           0                3          2.0
# 5                           0                3          2.0
# 6                           0                3          2.0
# 7                           0                3          2.0
# 8                           0                3          2.0
# 9                           0                3          2.0
# 10                          0                3          0.5
# 11                          0                3          0.5
# 12                          0                3          2.5
# 13                          0                3          2.5
# 14                          0                3          2.0
# 15                          0                3          1.0
# 16                          0                3          2.0
# 17                          0                3          1.0
# 18                          0                3          0.5
# 19                          0                3          0.5
# 20                          0                3          0.5
# 21                          0                3          2.0
# 22                          0                0          2.0
# 23                          0                1          2.0
# 24                          0                2          2.0
# 25                          0                3          1.0
# 26                          0                3          0.5
# 27                          0                3          2.0
# 28                          0                3          2.0
# 29                          0                3          2.0
# 30                          0                3          2.0
# 31                          0                3          2.0
# 32                          0                3          2.5
# 33                          0                3          2.0
# 34                          0                3          2.0
# 35                          0                3          2.0
# 36                          0                3          2.0
# 37                          0                3          2.0
# 38                          0                3          2.0
# 39                          0                3          2.0
# 40                          0                3          2.0
# 41                          0                3          2.0
# 42                          0                3          2.0
#
# [43 rows x 24 columns]

# %%
df.to_csv('summary_df_combined_1.csv', index=True)
