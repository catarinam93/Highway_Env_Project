# %% [markdown]
# # 25% increase in the original number of vehicles

# %% [markdown]
# ##### Imports

# %%
import gymnasium as gym
from matplotlib import pyplot as plt
import pprint
import gymnasium as gym
import highway_env
from stable_baselines3 import PPO
from highway_env.envs import MergeEnv, RoundaboutEnv, IntersectionEnv
from highway_env import utils
import numpy as np
# %matplotlib inline

# %% [markdown]
# #### HighWay (Fast) Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- original vehicle's count:** 20
# ###### **- vehicle's count:** 25

# %%
env = gym.make("highway-fast-v0", render_mode='rgb_array', config={"vehicles_count": 25})
pprint.pprint(env.config)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -1,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'type': 'Kinematics'},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 5,
#  'vehicles_count': 25,
#  'vehicles_density': 1}
# C:\Users\Caty\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.config to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.config` for environment variables or `env.get_wrapper_attr('config')` that will search the reminding wrappers.
#   logger.warn(

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="highway_25_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("highway_25_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to highway_25_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.6     |
# |    ep_rew_mean     | 7.79     |
# | time/              |          |
# |    fps             | 23       |
# |    iterations      | 1        |
# |    time_elapsed    | 89       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.8        |
# |    ep_rew_mean          | 8.78        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 2           |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014431233 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | -0.0272     |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.449       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0207     |
# |    value_loss           | 0.933       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.5        |
# |    ep_rew_mean          | 12.1        |
# | time/                   |             |
# |    fps                  | 23          |
# |    iterations           | 3           |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013408452 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.208       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.542       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0245     |
# |    value_loss           | 0.823       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.8        |
# |    ep_rew_mean          | 15.2        |
# | time/                   |             |
# |    fps                  | 23          |
# |    iterations           | 4           |
# |    time_elapsed         | 352         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013090221 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0.238       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.298       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.023      |
# |    value_loss           | 0.707       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 22.2      |
# |    ep_rew_mean          | 16.3      |
# | time/                   |           |
# |    fps                  | 23        |
# |    iterations           | 5         |
# |    time_elapsed         | 441       |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0117116 |
# |    clip_fraction        | 0.171     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.46     |
# |    explained_variance   | 0.169     |
# |    learning_rate        | 0.0005    |
# |    loss                 | 0.255     |
# |    n_updates            | 40        |
# |    policy_gradient_loss | -0.0093   |
# |    value_loss           | 0.541     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.3        |
# |    ep_rew_mean          | 17.8        |
# | time/                   |             |
# |    fps                  | 23          |
# |    iterations           | 6           |
# |    time_elapsed         | 529         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010158807 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.191       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.183       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00849    |
# |    value_loss           | 0.404       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.4        |
# |    ep_rew_mean          | 18.7        |
# | time/                   |             |
# |    fps                  | 23          |
# |    iterations           | 7           |
# |    time_elapsed         | 615         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012888393 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.188       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.118       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 0.29        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.8        |
# |    ep_rew_mean          | 19.9        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 8           |
# |    time_elapsed         | 719         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010870768 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.326       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00931    |
# |    value_loss           | 0.33        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.2        |
# |    ep_rew_mean          | 20.6        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 9           |
# |    time_elapsed         | 813         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.019759282 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.14        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.106       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0157     |
# |    value_loss           | 0.248       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.2        |
# |    ep_rew_mean          | 20          |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 10          |
# |    time_elapsed         | 908         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.028044777 |
# |    clip_fraction        | 0.301       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.235       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.000155   |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 0.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.7        |
# |    ep_rew_mean          | 17.4        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 11          |
# |    time_elapsed         | 1002        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014005389 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.185       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.229       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00366    |
# |    value_loss           | 0.314       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.2        |
# |    ep_rew_mean          | 16.6        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 12          |
# |    time_elapsed         | 1098        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.016600575 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.231       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.171       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 0.493       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.5        |
# |    ep_rew_mean          | 18.2        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 13          |
# |    time_elapsed         | 1192        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.020826325 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.327       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.111       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 0.518       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.6        |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 14          |
# |    time_elapsed         | 1286        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.017906431 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.36        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0714      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00267    |
# |    value_loss           | 0.302       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.8        |
# |    ep_rew_mean          | 18.4        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 15          |
# |    time_elapsed         | 1383        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.017500915 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.334       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.139       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0041     |
# |    value_loss           | 0.334       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.3        |
# |    ep_rew_mean          | 20.4        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 16          |
# |    time_elapsed         | 1473        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.021495722 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.42        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0576      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00084    |
# |    value_loss           | 0.291       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.8        |
# |    ep_rew_mean          | 18.6        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 17          |
# |    time_elapsed         | 1561        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.021455415 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.348       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0222      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00305    |
# |    value_loss           | 0.191       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.1        |
# |    ep_rew_mean          | 20.3        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 18          |
# |    time_elapsed         | 1647        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.022647299 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.403       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.109       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00608    |
# |    value_loss           | 0.37        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.9        |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 19          |
# |    time_elapsed         | 1734        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.020645013 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.433       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.167       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00429    |
# |    value_loss           | 0.203       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.4        |
# |    ep_rew_mean          | 19.9        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 20          |
# |    time_elapsed         | 1823        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.017000236 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.95       |
# |    explained_variance   | 0.466       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.116       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00391    |
# |    value_loss           | 0.174       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.2        |
# |    ep_rew_mean          | 19.7        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 21          |
# |    time_elapsed         | 1909        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.021680795 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.962      |
# |    explained_variance   | 0.477       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.297       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00252     |
# |    value_loss           | 0.286       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 23.1       |
# |    ep_rew_mean          | 18.2       |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 22         |
# |    time_elapsed         | 1996       |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.01711348 |
# |    clip_fraction        | 0.242      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.948     |
# |    explained_variance   | 0.467      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.123      |
# |    n_updates            | 210        |
# |    policy_gradient_loss | 0.00162    |
# |    value_loss           | 0.256      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 23.9       |
# |    ep_rew_mean          | 18.9       |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 23         |
# |    time_elapsed         | 2085       |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.02032305 |
# |    clip_fraction        | 0.207      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.906     |
# |    explained_variance   | 0.44       |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.144      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00274   |
# |    value_loss           | 0.4        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 24        |
# |    ep_rew_mean          | 18.9      |
# | time/                   |           |
# |    fps                  | 22        |
# |    iterations           | 24        |
# |    time_elapsed         | 2173      |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0154469 |
# |    clip_fraction        | 0.196     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.922    |
# |    explained_variance   | 0.399     |
# |    learning_rate        | 0.0005    |
# |    loss                 | 0.342     |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -0.0038   |
# |    value_loss           | 0.381     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26          |
# |    ep_rew_mean          | 20.6        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 25          |
# |    time_elapsed         | 2263        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.019515203 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.905      |
# |    explained_variance   | 0.412       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0868      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00709    |
# |    value_loss           | 0.324       |
# -----------------------------------------

# %% [markdown]
# #### Merge Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- vehicle's count:** 5

# %%
# Personalized environment
class CustomMergeEnv(MergeEnv):
    def _make_vehicles(self) -> None:
        """
        Create some new vehicles and add them to the road.
        """
        road = self.road
        ego_vehicle = self.action_type.vehicle_class(
            road, road.network.get_lane(("a", "b", 1)).position(30, 0), speed=30
        )
        road.vehicles.append(ego_vehicle)

        other_vehicles_type = utils.class_from_path(self.config["other_vehicles_type"])

        # Originally there was 3 vehicles, with a 25% increase now there is 4
        for position, speed in [(90, 29), (70, 31), (5, 31.5), (50, 30.5)]:
            lane = road.network.get_lane(("a", "b", self.np_random.integers(2)))
            position = lane.position(position + self.np_random.uniform(-5, 5), 0)
            speed += self.np_random.uniform(-1, 1)
            road.vehicles.append(other_vehicles_type(road, position, speed=speed))

        # Fusion vehicle
        merging_v = other_vehicles_type(
            road, road.network.get_lane(("j", "k", 0)).position(110, 0), speed=20
        )
        merging_v.target_speed = 30
        road.vehicles.append(merging_v)
        self.vehicle = ego_vehicle

# %%
env = CustomMergeEnv(render_mode='rgb_array')
pprint.pprint(env.config)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -1,
#  'high_speed_reward': 0.2,
#  'lane_change_reward': -0.05,
#  'manual_control': False,
#  'merging_speed_reward': -0.5,
#  'observation': {'type': 'Kinematics'},
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15}

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="merge_25_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("merge_25_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to merge_25_ppo/PPO_1
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.64     |
# |    ep_rew_mean     | 4.61     |
# | time/              |          |
# |    fps             | 36       |
# |    iterations      | 1        |
# |    time_elapsed    | 56       |
# |    total_timesteps | 2048     |
# ---------------------------------
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# ...
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.5        |
# |    ep_rew_mean          | 13.9        |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 25          |
# |    time_elapsed         | 1446        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008836163 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.722      |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0173      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.00418     |
# |    value_loss           | 0.121       |
# -----------------------------------------

# %% [markdown]
# #### Roundabout Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- vehicle's count:** 5

# %%
# Personalized environment
class CustomRoundaboutEnv(RoundaboutEnv):
    def _make_vehicles(self) -> None:
        """
        Create some new vehicles and add them to the road.
        """
        position_deviation = 2
        speed_deviation = 2

        # Ego-vehicle
        ego_lane = self.road.network.get_lane(("ser", "ses", 0))
        ego_vehicle = self.action_type.vehicle_class(
            self.road,
            ego_lane.position(125, 0),
            speed=8,
            heading=ego_lane.heading_at(140),
        )
        try:
            ego_vehicle.plan_route_to("nxs")
        except AttributeError:
            pass
        self.road.vehicles.append(ego_vehicle)
        self.vehicle = ego_vehicle

        # Incoming vehicle
        destinations = ["exr", "sxr", "nxr"]
        other_vehicles_type = utils.class_from_path(self.config["other_vehicles_type"])
        vehicle = other_vehicles_type.make_on_lane(
            self.road,
            ("we", "sx", 1),
            longitudinal=5 + self.np_random.normal() * position_deviation,
            speed=16 + self.np_random.normal() * speed_deviation,
        )

        if self.config["incoming_vehicle_destination"] is not None:
            destination = destinations[self.config["incoming_vehicle_destination"]]
        else:
            destination = self.np_random.choice(destinations)
        vehicle.plan_route_to(destination)
        vehicle.randomize_behavior()
        self.road.vehicles.append(vehicle)

        # Other vehicles (From 2 to 3 vehicles, 25% increase)
        for i in list(range(1, 2)) + list(range(-1, 0)) + [2]:  
            vehicle = other_vehicles_type.make_on_lane(
                self.road,
                ("we", "sx", 0),
                longitudinal=20 * i + self.np_random.normal() * position_deviation,
                speed=16 + self.np_random.normal() * speed_deviation,
            )
            vehicle.plan_route_to(self.np_random.choice(destinations))
            vehicle.randomize_behavior()
            self.road.vehicles.append(vehicle)

        # Entering vehicle
        vehicle = other_vehicles_type.make_on_lane(
            self.road,
            ("eer", "ees", 0),
            longitudinal=50 + self.np_random.normal() * position_deviation,
            speed=16 + self.np_random.normal() * speed_deviation,
        )
        vehicle.plan_route_to(self.np_random.choice(destinations))
        vehicle.randomize_behavior()
        self.road.vehicles.append(vehicle)

# %%
env = CustomRoundaboutEnv(render_mode='rgb_array')
pprint.pprint(env.config)
# Out:
# {'action': {'target_speeds': [0, 8, 16], 'type': 'DiscreteMetaAction'},
#  'centering_position': [0.5, 0.6],
#  'collision_reward': -1,
#  'duration': 11,
#  'high_speed_reward': 0.2,
#  'incoming_vehicle_destination': None,
#  'lane_change_reward': -0.05,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'absolute': True,
#                  'features_range': {'vx': [-15, 15],
#                                     'vy': [-15, 15],
#                                     'x': [-100, 100],
#                                     'y': [-100, 100]},
#                  'type': 'Kinematics'},
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'right_lane_reward': 0,
#  'scaling': 5.5,
#  'screen_height': 600,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15}

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="roundabout_25_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("roundabout_25_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to roundabout_25_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.27     |
# |    ep_rew_mean     | 8.05     |
# | time/              |          |
# |    fps             | 21       |
# |    iterations      | 1        |
# |    time_elapsed    | 94       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.61       |
# |    ep_rew_mean          | 8.33       |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 2          |
# |    time_elapsed         | 192        |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01441237 |
# |    clip_fraction        | 0.175      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.6       |
# |    explained_variance   | -0.052     |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.277      |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0172    |
# |    value_loss           | 0.695      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.93        |
# |    ep_rew_mean          | 8.68        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 3           |
# |    time_elapsed         | 286         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.024435584 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.336       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0225     |
# |    value_loss           | 0.624       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.83        |
# |    ep_rew_mean          | 8.62        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 4           |
# |    time_elapsed         | 380         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016758911 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.129       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.369       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 0.574       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 8.8         |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 5           |
# |    time_elapsed         | 475         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016822323 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0.0668      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.24        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0236     |
# |    value_loss           | 0.562       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.63        |
# |    ep_rew_mean          | 8.46        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 6           |
# |    time_elapsed         | 569         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.020551234 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.135       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.236       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0214     |
# |    value_loss           | 0.503       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.2        |
# |    ep_rew_mean          | 9.02        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 7           |
# |    time_elapsed         | 663         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.021824075 |
# |    clip_fraction        | 0.321       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.252       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 0.642       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.3        |
# |    ep_rew_mean          | 9.09        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 8           |
# |    time_elapsed         | 755         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.023692245 |
# |    clip_fraction        | 0.321       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.146       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.336       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0223     |
# |    value_loss           | 0.484       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | 9.61        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 9           |
# |    time_elapsed         | 849         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.025994705 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.124       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.17        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 0.327       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 9.8         |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 10          |
# |    time_elapsed         | 943         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.024913082 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0525      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 0.3         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | 9.67        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 11          |
# |    time_elapsed         | 1038        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.027751455 |
# |    clip_fraction        | 0.311       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.13        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 0.207       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11          |
# |    ep_rew_mean          | 9.74        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 12          |
# |    time_elapsed         | 1132        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.026696417 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.154       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.231       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00988    |
# |    value_loss           | 0.231       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 9.79        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 13          |
# |    time_elapsed         | 1226        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.020698063 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.238       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0954      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.203       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.5        |
# |    ep_rew_mean          | 9.42        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 14          |
# |    time_elapsed         | 1321        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.025805686 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.295       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0483      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 0.132       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | 9.7         |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 15          |
# |    time_elapsed         | 1416        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.019460665 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.975      |
# |    explained_variance   | 0.157       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0208      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0155     |
# |    value_loss           | 0.279       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.7       |
# |    ep_rew_mean          | 9.57       |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 16         |
# |    time_elapsed         | 1510       |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.02460266 |
# |    clip_fraction        | 0.231      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.979     |
# |    explained_variance   | 0.278      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.0849     |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.00776   |
# |    value_loss           | 0.197      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.9       |
# |    ep_rew_mean          | 9.82       |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 17         |
# |    time_elapsed         | 1605       |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.01594856 |
# |    clip_fraction        | 0.196      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.938     |
# |    explained_variance   | 0.269      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.0883     |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00831   |
# |    value_loss           | 0.252      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | 9.69        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 18          |
# |    time_elapsed         | 1699        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.025406772 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.921      |
# |    explained_variance   | 0.231       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.041       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.242       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.8       |
# |    ep_rew_mean          | 9.76       |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 19         |
# |    time_elapsed         | 1794       |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.02095564 |
# |    clip_fraction        | 0.229      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.842     |
# |    explained_variance   | 0.303      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.157      |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.00878   |
# |    value_loss           | 0.185      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.9       |
# |    ep_rew_mean          | 9.91       |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 20         |
# |    time_elapsed         | 1892       |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.02617916 |
# |    clip_fraction        | 0.196      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.836     |
# |    explained_variance   | 0.333      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.153      |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.00708   |
# |    value_loss           | 0.227      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 9.9         |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 21          |
# |    time_elapsed         | 1988        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.023815248 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.791      |
# |    explained_variance   | 0.306       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0514      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00675    |
# |    value_loss           | 0.164       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.9       |
# |    ep_rew_mean          | 9.94       |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 22         |
# |    time_elapsed         | 2079       |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.02701294 |
# |    clip_fraction        | 0.2        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.762     |
# |    explained_variance   | 0.431      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.00142    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00422   |
# |    value_loss           | 0.114      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.6        |
# |    ep_rew_mean          | 9.59        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 23          |
# |    time_elapsed         | 2174        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.023653556 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.761      |
# |    explained_variance   | 0.305       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.117       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00422    |
# |    value_loss           | 0.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 9.91        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 24          |
# |    time_elapsed         | 2270        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.017679645 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.739      |
# |    explained_variance   | 0.262       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0504      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.271       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | 9.79        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 25          |
# |    time_elapsed         | 2365        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.022007277 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.745      |
# |    explained_variance   | 0.301       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0566      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00751    |
# |    value_loss           | 0.164       |
# -----------------------------------------

# %% [markdown]
# #### Parking Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- vehicle's count:** 0

# %%
env = gym.make("parking-v0", render_mode='rgb_array', config={"vehicles_count": 1})
pprint.pprint(env.config)
# Out:
# {'action': {'type': 'ContinuousAction'},
#  'add_walls': True,
#  'centering_position': [0.5, 0.5],
#  'collision_reward': -5,
#  'controlled_vehicles': 1,
#  'duration': 100,
#  'manual_control': False,
#  'observation': {'features': ['x', 'y', 'vx', 'vy', 'cos_h', 'sin_h'],
#                  'normalize': False,
#                  'scales': [100, 100, 5, 5, 1, 1],
#                  'type': 'KinematicsGoal'},
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 5,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_weights': [1, 0.3, 0, 0, 0.02, 0.02],
#  'scaling': 7,
#  'screen_height': 300,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15,
#  'steering_range': 0.7853981633974483,
#  'success_goal_reward': 0.12,
#  'vehicles_count': 1}
# C:\Users\Caty\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.config to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.config` for environment variables or `env.get_wrapper_attr('config')` that will search the reminding wrappers.
#   logger.warn(

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MultiInputPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="parking_25_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("parking_25_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to parking_25_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.5     |
# |    ep_rew_mean     | -45.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 101      |
# |    iterations      | 1        |
# |    time_elapsed    | 20       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 77.8         |
# |    ep_rew_mean          | -41.9        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 96           |
# |    iterations           | 2            |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0037447505 |
# |    clip_fraction        | 0.0387       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.00178      |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.321        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00186     |
# |    std                  | 1.01         |
# |    value_loss           | 0.822        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 82.4         |
# |    ep_rew_mean          | -44.2        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 3            |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0041562477 |
# |    clip_fraction        | 0.05         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | -0.143       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.182        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00428     |
# |    std                  | 1.03         |
# |    value_loss           | 0.488        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 81.3         |
# |    ep_rew_mean          | -43.6        |
# |    success_rate         | 0.01         |
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 4            |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0058997925 |
# |    clip_fraction        | 0.0653       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | -0.051       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.173        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00368     |
# |    std                  | 1.05         |
# |    value_loss           | 0.35         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 75.9         |
# |    ep_rew_mean          | -40.7        |
# |    success_rate         | 0.02         |
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 5            |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0051881974 |
# |    clip_fraction        | 0.053        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.95        |
# |    explained_variance   | -0.195       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0707       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00103     |
# |    std                  | 1.06         |
# |    value_loss           | 0.339        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 68.9         |
# |    ep_rew_mean          | -37.8        |
# |    success_rate         | 0.02         |
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 6            |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0052644084 |
# |    clip_fraction        | 0.0465       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.96        |
# |    explained_variance   | -0.179       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.14         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00411     |
# |    std                  | 1.06         |
# |    value_loss           | 0.36         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 72.2       |
# |    ep_rew_mean          | -39.3      |
# |    success_rate         | 0.01       |
# | time/                   |            |
# |    fps                  | 90         |
# |    iterations           | 7          |
# |    time_elapsed         | 157        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.00424541 |
# |    clip_fraction        | 0.0526     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.96      |
# |    explained_variance   | 0.16       |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.0862     |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00291   |
# |    std                  | 1.06       |
# |    value_loss           | 0.245      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 68.2         |
# |    ep_rew_mean          | -38          |
# |    success_rate         | 0.01         |
# | time/                   |              |
# |    fps                  | 90           |
# |    iterations           | 8            |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0048367307 |
# |    clip_fraction        | 0.0828       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.96        |
# |    explained_variance   | 0.345        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0551       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00471     |
# |    std                  | 1.07         |
# |    value_loss           | 0.177        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.3        |
# |    ep_rew_mean          | -39         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 9           |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012705904 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.98       |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0586      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00948    |
# |    std                  | 1.08        |
# |    value_loss           | 0.147       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 72.5        |
# |    ep_rew_mean          | -39.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 10          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008451171 |
# |    clip_fraction        | 0.0908      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.97       |
# |    explained_variance   | 0.576       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00794     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0064     |
# |    std                  | 1.06        |
# |    value_loss           | 0.124       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 80          |
# |    ep_rew_mean          | -42.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 11          |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011344498 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | 0.649       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.12        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 1.05        |
# |    value_loss           | 0.144       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.7        |
# |    ep_rew_mean          | -45.9       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 12          |
# |    time_elapsed         | 272         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.011401547 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0433      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 1.04        |
# |    value_loss           | 0.0824      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.2        |
# |    ep_rew_mean          | -50.7       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 13          |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009750375 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.92       |
# |    explained_variance   | 0.649       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0301      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.009      |
# |    std                  | 1.04        |
# |    value_loss           | 0.0748      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 104          |
# |    ep_rew_mean          | -54.1        |
# |    success_rate         | 0.01         |
# | time/                   |              |
# |    fps                  | 90           |
# |    iterations           | 14           |
# |    time_elapsed         | 318          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0059006982 |
# |    clip_fraction        | 0.0808       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | 0.674        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.0106      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0062      |
# |    std                  | 1.05         |
# |    value_loss           | 0.0709       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 116         |
# |    ep_rew_mean          | -58.8       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 15          |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009272928 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.94       |
# |    explained_variance   | 0.738       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0105      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 1.05        |
# |    value_loss           | 0.0632      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 125         |
# |    ep_rew_mean          | -63.5       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 16          |
# |    time_elapsed         | 363         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010606308 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.94       |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0211     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00665    |
# |    std                  | 1.05        |
# |    value_loss           | 0.0415      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 140         |
# |    ep_rew_mean          | -71.9       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 17          |
# |    time_elapsed         | 387         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010292335 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | 0.756       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0202     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00716    |
# |    std                  | 1.06        |
# |    value_loss           | 0.0376      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | -75.3       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 18          |
# |    time_elapsed         | 411         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.016004967 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00848    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 1.05        |
# |    value_loss           | 0.0257      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 140         |
# |    ep_rew_mean          | -72.6       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 19          |
# |    time_elapsed         | 434         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009064078 |
# |    clip_fraction        | 0.0907      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.94       |
# |    explained_variance   | 0.765       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0175     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00745    |
# |    std                  | 1.05        |
# |    value_loss           | 0.0555      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 141         |
# |    ep_rew_mean          | -72.9       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 20          |
# |    time_elapsed         | 456         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011064436 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | 0.706       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0162      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 1.05        |
# |    value_loss           | 0.0646      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 161         |
# |    ep_rew_mean          | -81.7       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 21          |
# |    time_elapsed         | 479         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009228805 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.851       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0174      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00889    |
# |    std                  | 1.02        |
# |    value_loss           | 0.0396      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 176          |
# |    ep_rew_mean          | -88.5        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 89           |
# |    iterations           | 22           |
# |    time_elapsed         | 502          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0103306435 |
# |    clip_fraction        | 0.141        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.765        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0552       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00727     |
# |    std                  | 1.02         |
# |    value_loss           | 0.0268       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 181         |
# |    ep_rew_mean          | -88.7       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 23          |
# |    time_elapsed         | 524         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.012976164 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.741       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0152      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00504    |
# |    std                  | 1           |
# |    value_loss           | 0.0096      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 182         |
# |    ep_rew_mean          | -90.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 24          |
# |    time_elapsed         | 547         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008220261 |
# |    clip_fraction        | 0.0989      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0568      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00499    |
# |    std                  | 1           |
# |    value_loss           | 0.0198      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 184         |
# |    ep_rew_mean          | -88.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 25          |
# |    time_elapsed         | 570         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.012264783 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00376    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00878    |
# |    std                  | 0.986       |
# |    value_loss           | 0.0366      |
# -----------------------------------------

# %% [markdown]
# #### Intersection Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- vehicle's count:** 15

# %%
# Personalized environment
class CustomIntersectionEnv(IntersectionEnv):
    def _make_vehicles(self, n_vehicles: int = 10) -> None:
        """
        Create some new vehicles and add them to the road.
        """
        # Increase the number of vehicles by 25%
        n_vehicles = int(n_vehicles * 1.25)

        vehicle_type = utils.class_from_path(self.config["other_vehicles_type"])
        vehicle_type.DISTANCE_WANTED = 7  # Low jam distance
        vehicle_type.COMFORT_ACC_MAX = 6
        vehicle_type.COMFORT_ACC_MIN = -3

        # Random vehicles
        simulation_steps = 3
        for t in range(n_vehicles - 1):
            self._spawn_vehicle(np.linspace(0, 80, n_vehicles)[t])
        for _ in range(simulation_steps):
            [
                (
                    self.road.act(),
                    self.road.step(1 / self.config["simulation_frequency"]),
                )
                for _ in range(self.config["simulation_frequency"])
            ]

        # Ego-vehicle
        self._spawn_vehicle(
            60,
            spawn_probability=1,
            go_straight=True,
            position_deviation=0.1,
            speed_deviation=0,
        )

        # Incoming vehicle
        self.controlled_vehicles = []
        for ego_id in range(0, self.config["controlled_vehicles"]):
            ego_lane = self.road.network.get_lane(
                (f"o{ego_id % 4}", f"ir{ego_id % 4}", 0)
            )
            destination = self.config["destination"] or "o" + str(
                self.np_random.integers(1, 4)
            )
            ego_vehicle = self.action_type.vehicle_class(
                self.road,
                ego_lane.position(60 + 5 * self.np_random.normal(1), 0),
                speed=ego_lane.speed_limit,
                heading=ego_lane.heading_at(60),
            )
            try:
                ego_vehicle.plan_route_to(destination)
                ego_vehicle.speed_index = ego_vehicle.speed_to_index(
                    ego_lane.speed_limit
                )
                ego_vehicle.target_speed = ego_vehicle.index_to_speed(
                    ego_vehicle.speed_index
                )
            except AttributeError:
                pass

            self.road.vehicles.append(ego_vehicle)
            self.controlled_vehicles.append(ego_vehicle)
            for v in self.road.vehicles:  
                if (
                    v is not ego_vehicle
                    and np.linalg.norm(v.position - ego_vehicle.position) < 20
                ):
                    self.road.vehicles.remove(v)

# %%
env = CustomIntersectionEnv(render_mode='rgb_array')
pprint.pprint(env.config)
# Out:
# {'action': {'lateral': False,
#             'longitudinal': True,
#             'target_speeds': [0, 4.5, 9],
#             'type': 'DiscreteMetaAction'},
#  'arrived_reward': 1,
#  'centering_position': [0.5, 0.6],
#  'collision_reward': -5,
#  'controlled_vehicles': 1,
#  'destination': 'o1',
#  'duration': 13,
#  'high_speed_reward': 1,
#  'initial_vehicle_count': 10,
#  'manual_control': False,
#  'normalize_reward': False,
#  'observation': {'absolute': True,
#                  'features': ['presence',
#                               'x',
#                               'y',
#                               'vx',
#                               'vy',
#                               'cos_h',
#                               'sin_h'],
#                  'features_range': {'vx': [-20, 20],
#                                     'vy': [-20, 20],
#                                     'x': [-100, 100],
#                                     'y': [-100, 100]},
#                  'flatten': False,
#                  'observe_intentions': False,
#                  'type': 'Kinematics',
#                  'vehicles_count': 15},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [7.0, 9.0],
#  'scaling': 7.15,
#  'screen_height': 600,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15,
#  'spawn_probability': 0.6}

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="intersection_25_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("intersection_25_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to intersection_25_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.3     |
# |    ep_rew_mean     | 1.23     |
# | time/              |          |
# |    fps             | 15       |
# |    iterations      | 1        |
# |    time_elapsed    | 134      |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.61        |
# |    ep_rew_mean          | 1.93        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 2           |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.032603975 |
# |    clip_fraction        | 0.4         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.0285     |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.43        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0377     |
# |    value_loss           | 2.65        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.82       |
# |    ep_rew_mean          | 3.51       |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 3          |
# |    time_elapsed         | 402        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.03140118 |
# |    clip_fraction        | 0.255      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.179      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 1.73       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0228    |
# |    value_loss           | 3.6        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.56        |
# |    ep_rew_mean          | 2.42        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 4           |
# |    time_elapsed         | 540         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018900417 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.933      |
# |    explained_variance   | 0.192       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.93        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0282     |
# |    value_loss           | 4.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.04        |
# |    ep_rew_mean          | 3.51        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 5           |
# |    time_elapsed         | 674         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.020904876 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.854      |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.96        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.018      |
# |    value_loss           | 4.33        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.39        |
# |    ep_rew_mean          | 3.21        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 6           |
# |    time_elapsed         | 810         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015552831 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.794      |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.6         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 4.58        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.44        |
# |    ep_rew_mean          | 4.11        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 7           |
# |    time_elapsed         | 942         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.016218308 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.737      |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.37        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 4.68        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.37        |
# |    ep_rew_mean          | 3.95        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 8           |
# |    time_elapsed         | 1073        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010967619 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.65       |
# |    explained_variance   | 0.176       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.12        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 4.7         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.38        |
# |    ep_rew_mean          | 4.04        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 9           |
# |    time_elapsed         | 1206        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010706649 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.604      |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.92        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00967    |
# |    value_loss           | 4.89        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.69        |
# |    ep_rew_mean          | 4.41        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 10          |
# |    time_elapsed         | 1339        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012819694 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.576      |
# |    explained_variance   | 0.206       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.93        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 4.72        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.51        |
# |    ep_rew_mean          | 4.14        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 11          |
# |    time_elapsed         | 1475        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012539577 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.559      |
# |    explained_variance   | 0.186       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.36        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 4.73        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.31       |
# |    ep_rew_mean          | 3.9        |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 12         |
# |    time_elapsed         | 1611       |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01290811 |
# |    clip_fraction        | 0.116      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.575     |
# |    explained_variance   | 0.131      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 2.46       |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0105    |
# |    value_loss           | 4.95       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.08        |
# |    ep_rew_mean          | 3.88        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 13          |
# |    time_elapsed         | 1744        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.012049139 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.534      |
# |    explained_variance   | 0.205       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.57        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 4.72        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.08        |
# |    ep_rew_mean          | 3.85        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 14          |
# |    time_elapsed         | 1877        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007749888 |
# |    clip_fraction        | 0.0899      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.503      |
# |    explained_variance   | 0.199       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.65        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 5           |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.21        |
# |    ep_rew_mean          | 3.48        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 15          |
# |    time_elapsed         | 2011        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007836267 |
# |    clip_fraction        | 0.0957      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.515      |
# |    explained_variance   | 0.186       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.35        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00875    |
# |    value_loss           | 4.91        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.91        |
# |    ep_rew_mean          | 3.17        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 16          |
# |    time_elapsed         | 2147        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.015015322 |
# |    clip_fraction        | 0.0995      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.55       |
# |    explained_variance   | 0.193       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.9         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 4.83        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.13        |
# |    ep_rew_mean          | 3.64        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 17          |
# |    time_elapsed         | 2273        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.016961304 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.508      |
# |    explained_variance   | 0.204       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.28        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 4.85        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.45        |
# |    ep_rew_mean          | 4.56        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 18          |
# |    time_elapsed         | 2407        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010776007 |
# |    clip_fraction        | 0.0808      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.417      |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.59        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00982    |
# |    value_loss           | 4.84        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.99        |
# |    ep_rew_mean          | 3.38        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 19          |
# |    time_elapsed         | 2542        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.016965214 |
# |    clip_fraction        | 0.0996      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.406      |
# |    explained_variance   | 0.161       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.14        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 4.57        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.05        |
# |    ep_rew_mean          | 3.5         |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 20          |
# |    time_elapsed         | 2679        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.014451843 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.425      |
# |    explained_variance   | 0.167       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.86        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 4.8         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.02        |
# |    ep_rew_mean          | 3.49        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 21          |
# |    time_elapsed         | 2814        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.014395628 |
# |    clip_fraction        | 0.0955      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.394      |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.11        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 4.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.2         |
# |    ep_rew_mean          | 4.02        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 22          |
# |    time_elapsed         | 2945        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012400671 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.433      |
# |    explained_variance   | 0.166       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 3.36        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 5.02        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.33        |
# |    ep_rew_mean          | 4.17        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 23          |
# |    time_elapsed         | 3077        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.011402266 |
# |    clip_fraction        | 0.0847      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.416      |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.69        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00893    |
# |    value_loss           | 4.46        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.11        |
# |    ep_rew_mean          | 3.54        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 24          |
# |    time_elapsed         | 3211        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.014875736 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.409      |
# |    explained_variance   | 0.177       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.69        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 4.61        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.94        |
# |    ep_rew_mean          | 3.23        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 25          |
# |    time_elapsed         | 3342        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.018325496 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.39       |
# |    explained_variance   | 0.191       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.69        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 4.42        |
# -----------------------------------------
