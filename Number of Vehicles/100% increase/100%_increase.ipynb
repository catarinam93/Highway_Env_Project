# %% [markdown]
# # 100% increase in the original number of vehicles

# %% [markdown]
# ##### Imports

# %%
import gymnasium as gym
from matplotlib import pyplot as plt
import pprint
import gymnasium as gym
import highway_env
from stable_baselines3 import PPO
from highway_env.envs import MergeEnv, RoundaboutEnv, IntersectionEnv
from highway_env import utils
import numpy as np
# %matplotlib inline

# %% [markdown]
# #### HighWay (Fast) Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- original vehicle's count:** 20
# ###### **- vehicle's count:** 40

# %%
env = gym.make("highway-fast-v0", render_mode='rgb_array', config={"vehicles_count": 40})
pprint.pprint(env.config)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -1,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'type': 'Kinematics'},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 5,
#  'vehicles_count': 40,
#  'vehicles_density': 1}
# C:\Users\Caty\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.config to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.config` for environment variables or `env.get_wrapper_attr('config')` that will search the reminding wrappers.
#   logger.warn(

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="highway_100_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("highway_100_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to highway_100_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.3     |
# |    ep_rew_mean     | 7.67     |
# | time/              |          |
# |    fps             | 13       |
# |    iterations      | 1        |
# |    time_elapsed    | 153      |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.6        |
# |    ep_rew_mean          | 10.2        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 2           |
# |    time_elapsed         | 311         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016561715 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | -0.032      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.273       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0239     |
# |    value_loss           | 0.955       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.5       |
# |    ep_rew_mean          | 12.1       |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 3          |
# |    time_elapsed         | 466        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01638373 |
# |    clip_fraction        | 0.251      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.56      |
# |    explained_variance   | 0.136      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.334      |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0235    |
# |    value_loss           | 0.881      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.4        |
# |    ep_rew_mean          | 14.4        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 4           |
# |    time_elapsed         | 621         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015910089 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0.208       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.267       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0186     |
# |    value_loss           | 0.68        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.5        |
# |    ep_rew_mean          | 15.2        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 5           |
# |    time_elapsed         | 777         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013528369 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.217       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.268       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 0.58        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.6        |
# |    ep_rew_mean          | 18.3        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 6           |
# |    time_elapsed         | 934         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010871102 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.238       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.211       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0157     |
# |    value_loss           | 0.485       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.6        |
# |    ep_rew_mean          | 18.3        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 7           |
# |    time_elapsed         | 1090        |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.014648224 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.12        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.067       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00788    |
# |    value_loss           | 0.288       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.3        |
# |    ep_rew_mean          | 18.1        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 8           |
# |    time_elapsed         | 1245        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.015519538 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.237       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.108       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.321       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.8        |
# |    ep_rew_mean          | 18.5        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 9           |
# |    time_elapsed         | 1398        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010629798 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.2         |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.105       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00628    |
# |    value_loss           | 0.33        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 26.7       |
# |    ep_rew_mean          | 20.1       |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 10         |
# |    time_elapsed         | 1555       |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.01827094 |
# |    clip_fraction        | 0.255      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.215      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.193      |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0103    |
# |    value_loss           | 0.293      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.5        |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 11          |
# |    time_elapsed         | 1711        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.019674413 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0596      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00878    |
# |    value_loss           | 0.165       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23          |
# |    ep_rew_mean          | 17.8        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 12          |
# |    time_elapsed         | 1867        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.023727383 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.251       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0938      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00333    |
# |    value_loss           | 0.288       |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 24       |
# |    ep_rew_mean          | 18.7     |
# | time/                   |          |
# |    fps                  | 13       |
# |    iterations           | 13       |
# |    time_elapsed         | 2019     |
# |    total_timesteps      | 26624    |
# | train/                  |          |
# |    approx_kl            | 0.01052  |
# |    clip_fraction        | 0.172    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.16    |
# |    explained_variance   | 0.229    |
# |    learning_rate        | 0.0005   |
# |    loss                 | 0.122    |
# |    n_updates            | 120      |
# |    policy_gradient_loss | -0.00286 |
# |    value_loss           | 0.464    |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.1        |
# |    ep_rew_mean          | 20.2        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 14          |
# |    time_elapsed         | 2175        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009814777 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.314       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.124       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00768    |
# |    value_loss           | 0.315       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.3        |
# |    ep_rew_mean          | 18.9        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 15          |
# |    time_elapsed         | 2332        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.013407698 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.37        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0941      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00161    |
# |    value_loss           | 0.246       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.4        |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 16          |
# |    time_elapsed         | 2487        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.029354442 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.454       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.197       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00709    |
# |    value_loss           | 0.242       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.2        |
# |    ep_rew_mean          | 18.7        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 17          |
# |    time_elapsed         | 2646        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.018163119 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.413       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.228       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00375    |
# |    value_loss           | 0.295       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.9        |
# |    ep_rew_mean          | 17.9        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 18          |
# |    time_elapsed         | 2805        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.016088717 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.284       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.000803   |
# |    value_loss           | 0.329       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.7        |
# |    ep_rew_mean          | 17.7        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 19          |
# |    time_elapsed         | 2964        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.015928395 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | 0.389       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.123       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00286    |
# |    value_loss           | 0.334       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.1        |
# |    ep_rew_mean          | 19.6        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 20          |
# |    time_elapsed         | 3122        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.013503671 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.966      |
# |    explained_variance   | 0.45        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.271       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00371    |
# |    value_loss           | 0.387       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.2        |
# |    ep_rew_mean          | 20.3        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 21          |
# |    time_elapsed         | 3279        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.014328539 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.937      |
# |    explained_variance   | 0.377       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0912      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00171     |
# |    value_loss           | 0.231       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 23.9      |
# |    ep_rew_mean          | 18.7      |
# | time/                   |           |
# |    fps                  | 13        |
# |    iterations           | 22        |
# |    time_elapsed         | 3438      |
# |    total_timesteps      | 45056     |
# | train/                  |           |
# |    approx_kl            | 0.0175501 |
# |    clip_fraction        | 0.259     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.953    |
# |    explained_variance   | 0.479     |
# |    learning_rate        | 0.0005    |
# |    loss                 | 0.157     |
# |    n_updates            | 210       |
# |    policy_gradient_loss | -0.00332  |
# |    value_loss           | 0.192     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.7        |
# |    ep_rew_mean          | 19.5        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 23          |
# |    time_elapsed         | 3595        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.015486835 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.899      |
# |    explained_variance   | 0.476       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0776      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00276    |
# |    value_loss           | 0.292       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 19.7        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 24          |
# |    time_elapsed         | 3750        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.027522191 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.854      |
# |    explained_variance   | 0.502       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0598      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.000286    |
# |    value_loss           | 0.219       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 24.3       |
# |    ep_rew_mean          | 19.2       |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 25         |
# |    time_elapsed         | 3905       |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.02992893 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.835     |
# |    explained_variance   | 0.496      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.141      |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.00327   |
# |    value_loss           | 0.221      |
# ----------------------------------------

# %% [markdown]
# #### Merge Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- original vehicle's count:** 5
# ###### **- vehicle's count:** 8

# %%
# Personalized environment with a 100% increase in the number of vehicles
class CustomMergeEnv(MergeEnv):
    def _make_vehicles(self) -> None:
        """
        Create some new vehicles and add them to the road.
        """
        road = self.road
        ego_vehicle = self.action_type.vehicle_class(
            road, road.network.get_lane(("a", "b", 1)).position(30, 0), speed=30
        )
        road.vehicles.append(ego_vehicle)

        other_vehicles_type = utils.class_from_path(self.config["other_vehicles_type"])

        # Originally there were 3 vehicles; with a 100% increase, now there are 6
        for position, speed in [(90, 29), (70, 31), (5, 31.5), (50, 30.5), (30, 32), (10, 28)]:
            lane = road.network.get_lane(("a", "b", self.np_random.integers(2)))
            position = lane.position(position + self.np_random.uniform(-5, 5), 0)
            speed += self.np_random.uniform(-1, 1)
            road.vehicles.append(other_vehicles_type(road, position, speed=speed))

        # Fusion vehicle
        merging_v = other_vehicles_type(
            road, road.network.get_lane(("j", "k", 0)).position(110, 0), speed=20
        )
        merging_v.target_speed = 30
        road.vehicles.append(merging_v)
        self.vehicle = ego_vehicle

# %%
env = CustomMergeEnv(render_mode='rgb_array')
pprint.pprint(env.config)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -1,
#  'high_speed_reward': 0.2,
#  'lane_change_reward': -0.05,
#  'manual_control': False,
#  'merging_speed_reward': -0.5,
#  'observation': {'type': 'Kinematics'},
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15}

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="merge_100_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("merge_100_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to merge_100_ppo/PPO_1
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.17     |
# |    ep_rew_mean     | 1.34     |
# | time/              |          |
# |    fps             | 26       |
# |    iterations      | 1        |
# |    time_elapsed    | 77       |
# |    total_timesteps | 2048     |
# ---------------------------------
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# ...
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.73        |
# |    ep_rew_mean          | 6.03        |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 25          |
# |    time_elapsed         | 1891        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.007484067 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.674      |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0484      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.00152     |
# |    value_loss           | 0.121       |
# -----------------------------------------

# %% [markdown]
# #### Roundabout Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- original vehicle's count:** 5
# ###### **- vehicle's count:** 7

# %%
# Personalized environment with a 75% increase in the number of vehicles
class CustomRoundaboutEnv(RoundaboutEnv):
    def _make_vehicles(self) -> None:
        """
        Create some new vehicles and add them to the road.
        """
        position_deviation = 2
        speed_deviation = 2

        # Ego-vehicle
        ego_lane = self.road.network.get_lane(("ser", "ses", 0))
        ego_vehicle = self.action_type.vehicle_class(
            self.road,
            ego_lane.position(125, 0),
            speed=8,
            heading=ego_lane.heading_at(140),
        )
        try:
            ego_vehicle.plan_route_to("nxs")
        except AttributeError:
            pass
        self.road.vehicles.append(ego_vehicle)
        self.vehicle = ego_vehicle

        # Incoming vehicle
        destinations = ["exr", "sxr", "nxr"]
        other_vehicles_type = utils.class_from_path(self.config["other_vehicles_type"])
        vehicle = other_vehicles_type.make_on_lane(
            self.road,
            ("we", "sx", 1),
            longitudinal=5 + self.np_random.normal() * position_deviation,
            speed=16 + self.np_random.normal() * speed_deviation,
        )

        if self.config["incoming_vehicle_destination"] is not None:
            destination = destinations[self.config["incoming_vehicle_destination"]]
        else:
            destination = self.np_random.choice(destinations)
        vehicle.plan_route_to(destination)
        vehicle.randomize_behavior()
        self.road.vehicles.append(vehicle)

        # Other vehicles (From 2 to 4 vehicles, 75% increase)
        for i in list(range(1, 2)) + list(range(-1, 0)) + [2, -2]:  
            vehicle = other_vehicles_type.make_on_lane(
                self.road,
                ("we", "sx", 0),
                longitudinal=20 * i + self.np_random.normal() * position_deviation,
                speed=16 + self.np_random.normal() * speed_deviation,
            )
            vehicle.plan_route_to(self.np_random.choice(destinations))
            vehicle.randomize_behavior()
            self.road.vehicles.append(vehicle)

        # Entering vehicle
        vehicle = other_vehicles_type.make_on_lane(
            self.road,
            ("eer", "ees", 0),
            longitudinal=50 + self.np_random.normal() * position_deviation,
            speed=16 + self.np_random.normal() * speed_deviation,
        )
        vehicle.plan_route_to(self.np_random.choice(destinations))
        vehicle.randomize_behavior()
        self.road.vehicles.append(vehicle)

# %%
env = CustomRoundaboutEnv(render_mode='rgb_array')
pprint.pprint(env.config)
# Out:
# {'action': {'target_speeds': [0, 8, 16], 'type': 'DiscreteMetaAction'},
#  'centering_position': [0.5, 0.6],
#  'collision_reward': -1,
#  'duration': 11,
#  'high_speed_reward': 0.2,
#  'incoming_vehicle_destination': None,
#  'lane_change_reward': -0.05,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'absolute': True,
#                  'features_range': {'vx': [-15, 15],
#                                     'vy': [-15, 15],
#                                     'x': [-100, 100],
#                                     'y': [-100, 100]},
#                  'type': 'Kinematics'},
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'right_lane_reward': 0,
#  'scaling': 5.5,
#  'screen_height': 600,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15}

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="roundabout_100_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("roundabout_100_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to roundabout_100_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.36     |
# |    ep_rew_mean     | 8.1      |
# | time/              |          |
# |    fps             | 19       |
# |    iterations      | 1        |
# |    time_elapsed    | 107      |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.97       |
# |    ep_rew_mean          | 7.68       |
# | time/                   |            |
# |    fps                  | 19         |
# |    iterations           | 2          |
# |    time_elapsed         | 213        |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01929413 |
# |    clip_fraction        | 0.181      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.6       |
# |    explained_variance   | -0.115     |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.269      |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0177    |
# |    value_loss           | 0.75       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.75       |
# |    ep_rew_mean          | 8.43       |
# | time/                   |            |
# |    fps                  | 19         |
# |    iterations           | 3          |
# |    time_elapsed         | 319        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01307006 |
# |    clip_fraction        | 0.194      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.58      |
# |    explained_variance   | 0.162      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.224      |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0145    |
# |    value_loss           | 0.751      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.63       |
# |    ep_rew_mean          | 8.32       |
# | time/                   |            |
# |    fps                  | 19         |
# |    iterations           | 4          |
# |    time_elapsed         | 426        |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.02629593 |
# |    clip_fraction        | 0.306      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.53      |
# |    explained_variance   | 0.143      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.223      |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0196    |
# |    value_loss           | 0.64       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.3        |
# |    ep_rew_mean          | 8.89        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 5           |
# |    time_elapsed         | 533         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.019169921 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.127       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.342       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 0.614       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.1        |
# |    ep_rew_mean          | 8.58        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 6           |
# |    time_elapsed         | 640         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.019026592 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.183       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.174       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 0.365       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.6        |
# |    ep_rew_mean          | 9.24        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 7           |
# |    time_elapsed         | 748         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.018879047 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.148       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.145       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 0.403       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | 9.37        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 8           |
# |    time_elapsed         | 858         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.025990106 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.0786      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.215       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 0.285       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.3        |
# |    ep_rew_mean          | 8.93        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 9           |
# |    time_elapsed         | 966         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.018450234 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.115       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.299       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 0.205       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | 9.48        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 10          |
# |    time_elapsed         | 1073        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.021141272 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.0744      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.175       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 0.295       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.4        |
# |    ep_rew_mean          | 9.11        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 11          |
# |    time_elapsed         | 1182        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.027318206 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.107       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.124       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0196     |
# |    value_loss           | 0.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | 9.5         |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 12          |
# |    time_elapsed         | 1291        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.024032574 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.157       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.163       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 0.328       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.8       |
# |    ep_rew_mean          | 9.45       |
# | time/                   |            |
# |    fps                  | 19         |
# |    iterations           | 13         |
# |    time_elapsed         | 1398       |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.02554439 |
# |    clip_fraction        | 0.259      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | 0.199      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.142      |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0117    |
# |    value_loss           | 0.251      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11          |
# |    ep_rew_mean          | 9.66        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 14          |
# |    time_elapsed         | 1508        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.017744604 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.996      |
# |    explained_variance   | 0.132       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.138       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00684    |
# |    value_loss           | 0.241       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.6       |
# |    ep_rew_mean          | 9.4        |
# | time/                   |            |
# |    fps                  | 19         |
# |    iterations           | 15         |
# |    time_elapsed         | 1615       |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.03370564 |
# |    clip_fraction        | 0.254      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.978     |
# |    explained_variance   | 0.0949     |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.0125     |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0135    |
# |    value_loss           | 0.0638     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | 9.37        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 16          |
# |    time_elapsed         | 1724        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.015245369 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.957      |
# |    explained_variance   | 0.0937      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0487      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 0.329       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | 9.45        |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 17          |
# |    time_elapsed         | 1833        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.023191206 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.896      |
# |    explained_variance   | 0.0741      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.128       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00491    |
# |    value_loss           | 0.202       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11          |
# |    ep_rew_mean          | 9.79        |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 18          |
# |    time_elapsed         | 1943        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.032945395 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.834      |
# |    explained_variance   | 0.122       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0293      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 0.186       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | 9.57        |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 19          |
# |    time_elapsed         | 2053        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.024826009 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.829      |
# |    explained_variance   | 0.123       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0148     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00902    |
# |    value_loss           | 0.234       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.5        |
# |    ep_rew_mean          | 9.3         |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 20          |
# |    time_elapsed         | 2162        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.022452714 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.852      |
# |    explained_variance   | 0.167       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0041     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00982    |
# |    value_loss           | 0.157       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.6        |
# |    ep_rew_mean          | 9.37        |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 21          |
# |    time_elapsed         | 2269        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.023316847 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.847      |
# |    explained_variance   | 0.184       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.236       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.255       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 9.67        |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 22          |
# |    time_elapsed         | 2378        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.021865819 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.865      |
# |    explained_variance   | 0.267       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.123       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 0.309       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.7       |
# |    ep_rew_mean          | 9.46       |
# | time/                   |            |
# |    fps                  | 18         |
# |    iterations           | 23         |
# |    time_elapsed         | 2483       |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01593663 |
# |    clip_fraction        | 0.19       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.83      |
# |    explained_variance   | 0.15       |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.247      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0135    |
# |    value_loss           | 0.201      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11          |
# |    ep_rew_mean          | 9.8         |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 24          |
# |    time_elapsed         | 2590        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.023806443 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.774      |
# |    explained_variance   | 0.26        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0928      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 0.241       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11          |
# |    ep_rew_mean          | 9.74        |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 25          |
# |    time_elapsed         | 2696        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.024078563 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.755      |
# |    explained_variance   | 0.197       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0165      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 0.141       |
# -----------------------------------------

# %% [markdown]
# #### Parking Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- original vehicle's count:** 0
# ###### **- vehicle's count:** 4

# %%
env = gym.make("parking-v0", render_mode='rgb_array', config={"vehicles_count": 4})
pprint.pprint(env.config)
# Out:
# {'action': {'type': 'ContinuousAction'},
#  'add_walls': True,
#  'centering_position': [0.5, 0.5],
#  'collision_reward': -5,
#  'controlled_vehicles': 1,
#  'duration': 100,
#  'manual_control': False,
#  'observation': {'features': ['x', 'y', 'vx', 'vy', 'cos_h', 'sin_h'],
#                  'normalize': False,
#                  'scales': [100, 100, 5, 5, 1, 1],
#                  'type': 'KinematicsGoal'},
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 5,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_weights': [1, 0.3, 0, 0, 0.02, 0.02],
#  'scaling': 7,
#  'screen_height': 300,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15,
#  'steering_range': 0.7853981633974483,
#  'success_goal_reward': 0.12,
#  'vehicles_count': 4}
# C:\Users\Caty\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.config to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.config` for environment variables or `env.get_wrapper_attr('config')` that will search the reminding wrappers.
#   logger.warn(

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MultiInputPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="parking_100_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("parking_100_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to parking_100_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 62.6     |
# |    ep_rew_mean     | -34.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 74       |
# |    iterations      | 1        |
# |    time_elapsed    | 27       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 65.9        |
# |    ep_rew_mean          | -36.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 2           |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006655637 |
# |    clip_fraction        | 0.0707      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | -0.104      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.256       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00416    |
# |    std                  | 1.01        |
# |    value_loss           | 0.991       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 72.3         |
# |    ep_rew_mean          | -39.4        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 3            |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0052573197 |
# |    clip_fraction        | 0.0542       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | -0.206       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.303        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00287     |
# |    std                  | 1.03         |
# |    value_loss           | 0.461        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.5        |
# |    ep_rew_mean          | -38.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 4           |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.005257437 |
# |    clip_fraction        | 0.039       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | -0.0971     |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0984      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00233    |
# |    std                  | 1.01        |
# |    value_loss           | 0.431       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 75.7         |
# |    ep_rew_mean          | -39.7        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 68           |
# |    iterations           | 5            |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0077247308 |
# |    clip_fraction        | 0.078        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.00436      |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.272        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00592     |
# |    std                  | 1.01         |
# |    value_loss           | 0.43         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 80.5         |
# |    ep_rew_mean          | -40.4        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 68           |
# |    iterations           | 6            |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0064166132 |
# |    clip_fraction        | 0.0663       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.117        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.19         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00331     |
# |    std                  | 1.01         |
# |    value_loss           | 0.361        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 82.2         |
# |    ep_rew_mean          | -41.7        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 68           |
# |    iterations           | 7            |
# |    time_elapsed         | 209          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0044254838 |
# |    clip_fraction        | 0.0455       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0.258        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0567       |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00348     |
# |    std                  | 1            |
# |    value_loss           | 0.242        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 89.3         |
# |    ep_rew_mean          | -44.5        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 68           |
# |    iterations           | 8            |
# |    time_elapsed         | 239          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0068594897 |
# |    clip_fraction        | 0.0745       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.231        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0359       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00418     |
# |    std                  | 0.998        |
# |    value_loss           | 0.18         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.7        |
# |    ep_rew_mean          | -48.6       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 9           |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.006402705 |
# |    clip_fraction        | 0.0691      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0521      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00417    |
# |    std                  | 0.999       |
# |    value_loss           | 0.152       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 113         |
# |    ep_rew_mean          | -56.2       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 10          |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010320948 |
# |    clip_fraction        | 0.0932      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.531       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00357    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00511    |
# |    std                  | 0.989       |
# |    value_loss           | 0.101       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 126         |
# |    ep_rew_mean          | -63.2       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 11          |
# |    time_elapsed         | 332         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006047137 |
# |    clip_fraction        | 0.0576      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.631       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00672     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00292    |
# |    std                  | 0.977       |
# |    value_loss           | 0.0254      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 140         |
# |    ep_rew_mean          | -70.2       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 12          |
# |    time_elapsed         | 364         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008327156 |
# |    clip_fraction        | 0.0877      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.691       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0112     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00708    |
# |    std                  | 0.968       |
# |    value_loss           | 0.0415      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 156          |
# |    ep_rew_mean          | -77          |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 67           |
# |    iterations           | 13           |
# |    time_elapsed         | 394          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0074062194 |
# |    clip_fraction        | 0.0822       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.778        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.00895     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00658     |
# |    std                  | 0.98         |
# |    value_loss           | 0.0108       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 170         |
# |    ep_rew_mean          | -83.9       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 14          |
# |    time_elapsed         | 424         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008235442 |
# |    clip_fraction        | 0.0858      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0133     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00181    |
# |    std                  | 0.963       |
# |    value_loss           | 0.00801     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 183          |
# |    ep_rew_mean          | -88.6        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 67           |
# |    iterations           | 15           |
# |    time_elapsed         | 454          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0070360145 |
# |    clip_fraction        | 0.0489       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.182        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.00796      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.002       |
# |    std                  | 0.956        |
# |    value_loss           | 0.0562       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | -97.2       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 16          |
# |    time_elapsed         | 486         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009377385 |
# |    clip_fraction        | 0.0905      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.412       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00851    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0028     |
# |    std                  | 0.963       |
# |    value_loss           | 0.0691      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 218          |
# |    ep_rew_mean          | -107         |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 67           |
# |    iterations           | 17           |
# |    time_elapsed         | 515          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0087123625 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.825        |
# |    learning_rate        | 0.0005       |
# |    loss                 | -0.0164      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00501     |
# |    std                  | 0.953        |
# |    value_loss           | 0.00321      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 228         |
# |    ep_rew_mean          | -112        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 18          |
# |    time_elapsed         | 545         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010412854 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.801       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.000911    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0086     |
# |    std                  | 0.961       |
# |    value_loss           | 0.0362      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 245          |
# |    ep_rew_mean          | -120         |
# |    success_rate         | 0.01         |
# | time/                   |              |
# |    fps                  | 67           |
# |    iterations           | 19           |
# |    time_elapsed         | 575          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0077036144 |
# |    clip_fraction        | 0.0991       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.809        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0213       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00494     |
# |    std                  | 0.974        |
# |    value_loss           | 0.0177       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 262         |
# |    ep_rew_mean          | -128        |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 20          |
# |    time_elapsed         | 606         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008908462 |
# |    clip_fraction        | 0.0768      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0232      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00312    |
# |    std                  | 0.978       |
# |    value_loss           | 0.0123      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 278         |
# |    ep_rew_mean          | -134        |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 21          |
# |    time_elapsed         | 635         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008317751 |
# |    clip_fraction        | 0.0754      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00949    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00237    |
# |    std                  | 0.976       |
# |    value_loss           | 0.00266     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 288         |
# |    ep_rew_mean          | -139        |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 22          |
# |    time_elapsed         | 664         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009711547 |
# |    clip_fraction        | 0.0704      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0177      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00411    |
# |    std                  | 0.988       |
# |    value_loss           | 0.0312      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 304         |
# |    ep_rew_mean          | -145        |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 23          |
# |    time_elapsed         | 696         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.005039165 |
# |    clip_fraction        | 0.0603      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.353       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0218     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00114    |
# |    std                  | 0.992       |
# |    value_loss           | 0.0168      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 322          |
# |    ep_rew_mean          | -153         |
# |    success_rate         | 0.01         |
# | time/                   |              |
# |    fps                  | 67           |
# |    iterations           | 24           |
# |    time_elapsed         | 727          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0066522593 |
# |    clip_fraction        | 0.0563       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.829        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0219       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00264     |
# |    std                  | 0.992        |
# |    value_loss           | 0.0109       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 336         |
# |    ep_rew_mean          | -159        |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 25          |
# |    time_elapsed         | 758         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011867661 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00354    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00758    |
# |    std                  | 0.978       |
# |    value_loss           | 0.00211     |
# -----------------------------------------

# %% [markdown]
# #### Intersection Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- original vehicle's count:** 10
# ###### **- vehicle's count:** 20

# %%
# Personalized environment with a 100% increase in the number of vehicles
class CustomIntersectionEnv(IntersectionEnv):
    def _make_vehicles(self, n_vehicles: int = 10) -> None:
        """
        Create some new vehicles and add them to the road.
        """
        # Increase the number of vehicles by 100%
        n_vehicles = int(n_vehicles * 2)

        vehicle_type = utils.class_from_path(self.config["other_vehicles_type"])
        vehicle_type.DISTANCE_WANTED = 7  # Low jam distance
        vehicle_type.COMFORT_ACC_MAX = 6
        vehicle_type.COMFORT_ACC_MIN = -3

        # Random vehicles
        simulation_steps = 3
        for t in range(n_vehicles - 1):
            self._spawn_vehicle(np.linspace(0, 80, n_vehicles)[t])
        for _ in range(simulation_steps):
            [
                (
                    self.road.act(),
                    self.road.step(1 / self.config["simulation_frequency"]),
                )
                for _ in range(self.config["simulation_frequency"])
            ]

        # Ego-vehicle
        self._spawn_vehicle(
            60,
            spawn_probability=1,
            go_straight=True,
            position_deviation=0.1,
            speed_deviation=0,
        )

        # Incoming vehicle
        self.controlled_vehicles = []
        for ego_id in range(0, self.config["controlled_vehicles"]):
            ego_lane = self.road.network.get_lane(
                (f"o{ego_id % 4}", f"ir{ego_id % 4}", 0)
            )
            destination = self.config["destination"] or "o" + str(
                self.np_random.integers(1, 4)
            )
            ego_vehicle = self.action_type.vehicle_class(
                self.road,
                ego_lane.position(60 + 5 * self.np_random.normal(1), 0),
                speed=ego_lane.speed_limit,
                heading=ego_lane.heading_at(60),
            )
            try:
                ego_vehicle.plan_route_to(destination)
                ego_vehicle.speed_index = ego_vehicle.speed_to_index(
                    ego_lane.speed_limit
                )
                ego_vehicle.target_speed = ego_vehicle.index_to_speed(
                    ego_vehicle.speed_index
                )
            except AttributeError:
                pass

            self.road.vehicles.append(ego_vehicle)
            self.controlled_vehicles.append(ego_vehicle)
            for v in self.road.vehicles:  
                if (
                    v is not ego_vehicle
                    and np.linalg.norm(v.position - ego_vehicle.position) < 20
                ):
                    self.road.vehicles.remove(v)

# %%
env = CustomIntersectionEnv(render_mode='rgb_array')
pprint.pprint(env.config)
# Out:
# {'action': {'lateral': False,
#             'longitudinal': True,
#             'target_speeds': [0, 4.5, 9],
#             'type': 'DiscreteMetaAction'},
#  'arrived_reward': 1,
#  'centering_position': [0.5, 0.6],
#  'collision_reward': -5,
#  'controlled_vehicles': 1,
#  'destination': 'o1',
#  'duration': 13,
#  'high_speed_reward': 1,
#  'initial_vehicle_count': 10,
#  'manual_control': False,
#  'normalize_reward': False,
#  'observation': {'absolute': True,
#                  'features': ['presence',
#                               'x',
#                               'y',
#                               'vx',
#                               'vy',
#                               'cos_h',
#                               'sin_h'],
#                  'features_range': {'vx': [-20, 20],
#                                     'vy': [-20, 20],
#                                     'x': [-100, 100],
#                                     'y': [-100, 100]},
#                  'flatten': False,
#                  'observe_intentions': False,
#                  'type': 'Kinematics',
#                  'vehicles_count': 15},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [7.0, 9.0],
#  'scaling': 7.15,
#  'screen_height': 600,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15,
#  'spawn_probability': 0.6}

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="intersection_100_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("intersection_100_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to intersection_100_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.7      |
# |    ep_rew_mean     | -0.0467  |
# | time/              |          |
# |    fps             | 11       |
# |    iterations      | 1        |
# |    time_elapsed    | 186      |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.72       |
# |    ep_rew_mean          | 0.675      |
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 2          |
# |    time_elapsed         | 372        |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01972039 |
# |    clip_fraction        | 0.262      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | -0.0714    |
# |    learning_rate        | 0.0005     |
# |    loss                 | 1.22       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0209    |
# |    value_loss           | 2.76       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.52        |
# |    ep_rew_mean          | 1.13        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 3           |
# |    time_elapsed         | 556         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.022745335 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.229       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.28        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.028      |
# |    value_loss           | 2.97        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.33        |
# |    ep_rew_mean          | 1.15        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 4           |
# |    time_elapsed         | 744         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.020116534 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.996      |
# |    explained_variance   | 0.292       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.59        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0254     |
# |    value_loss           | 3.45        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.26        |
# |    ep_rew_mean          | 1.61        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 5           |
# |    time_elapsed         | 931         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016854296 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.951      |
# |    explained_variance   | 0.324       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.11        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 3.39        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.34        |
# |    ep_rew_mean          | 1.36        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 6           |
# |    time_elapsed         | 1118        |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012739802 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.914      |
# |    explained_variance   | 0.276       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.73        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 4.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.51        |
# |    ep_rew_mean          | 2.52        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 7           |
# |    time_elapsed         | 1302        |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.018319692 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.858      |
# |    explained_variance   | 0.282       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.35        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0187     |
# |    value_loss           | 4.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.6         |
# |    ep_rew_mean          | 1.77        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 8           |
# |    time_elapsed         | 1488        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.018844917 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.785      |
# |    explained_variance   | 0.257       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.23        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 4.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.05        |
# |    ep_rew_mean          | 2.97        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 9           |
# |    time_elapsed         | 1668        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.017853256 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.715      |
# |    explained_variance   | 0.26        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.62        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 4.77        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.63        |
# |    ep_rew_mean          | 1.79        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 10          |
# |    time_elapsed         | 1853        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.015583296 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.256       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.34        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00964    |
# |    value_loss           | 4.69        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.74        |
# |    ep_rew_mean          | 2.51        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 11          |
# |    time_elapsed         | 2036        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012464645 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | 0.295       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.17        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 4.75        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.56        |
# |    ep_rew_mean          | 1.74        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 12          |
# |    time_elapsed         | 2222        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013342459 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.65       |
# |    explained_variance   | 0.296       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.05        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 4.65        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.69        |
# |    ep_rew_mean          | 1.71        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 13          |
# |    time_elapsed         | 2409        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.015274497 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.65       |
# |    explained_variance   | 0.235       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.88        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 4.84        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.56       |
# |    ep_rew_mean          | 2.35       |
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 14         |
# |    time_elapsed         | 2593       |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01628815 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.636     |
# |    explained_variance   | 0.247      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 1.8        |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0147    |
# |    value_loss           | 4.85       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.59        |
# |    ep_rew_mean          | 1.94        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 15          |
# |    time_elapsed         | 2776        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.019978873 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.617      |
# |    explained_variance   | 0.234       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.53        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 4.66        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57        |
# |    ep_rew_mean          | 1.65        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 16          |
# |    time_elapsed         | 2962        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.021511976 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.614      |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.75        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 4.33        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.25         |
# |    ep_rew_mean          | 2.42         |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 17           |
# |    time_elapsed         | 3149         |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0145014115 |
# |    clip_fraction        | 0.156        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.58        |
# |    explained_variance   | 0.254        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 2.03         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0123      |
# |    value_loss           | 4.33         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.86        |
# |    ep_rew_mean          | 2.24        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 18          |
# |    time_elapsed         | 3338        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.023315482 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.543      |
# |    explained_variance   | 0.187       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.96        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 4.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.01        |
# |    ep_rew_mean          | 1.75        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 19          |
# |    time_elapsed         | 3520        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.025953554 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.53       |
# |    explained_variance   | 0.27        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.64        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 3.92        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.13       |
# |    ep_rew_mean          | 2.94       |
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 20         |
# |    time_elapsed         | 3698       |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.02117917 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.493     |
# |    explained_variance   | 0.236      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 1.34       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.00911   |
# |    value_loss           | 3.91       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.02        |
# |    ep_rew_mean          | 2.41        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 21          |
# |    time_elapsed         | 3882        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.016527833 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.494      |
# |    explained_variance   | 0.217       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.02        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00531    |
# |    value_loss           | 4.56        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.68        |
# |    ep_rew_mean          | 2.28        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 22          |
# |    time_elapsed         | 4066        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.021747844 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.475      |
# |    explained_variance   | 0.287       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.66        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 4.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.52        |
# |    ep_rew_mean          | 2.82        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 23          |
# |    time_elapsed         | 4253        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.022765625 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.483      |
# |    explained_variance   | 0.258       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.17        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 4.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.97        |
# |    ep_rew_mean          | 1.93        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 24          |
# |    time_elapsed         | 4444        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.025134407 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.453      |
# |    explained_variance   | 0.214       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.67        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 3.69        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.33       |
# |    ep_rew_mean          | 2.91       |
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 25         |
# |    time_elapsed         | 4628       |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.02097562 |
# |    clip_fraction        | 0.139      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.458     |
# |    explained_variance   | 0.253      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 1.94       |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0126    |
# |    value_loss           | 3.7        |
# ----------------------------------------
