# %% [markdown]
# # 75% increase in the original number of vehicles

# %% [markdown]
# ##### Imports

# %%
import gymnasium as gym
from matplotlib import pyplot as plt
import pprint
import gymnasium as gym
import highway_env
from stable_baselines3 import PPO
from highway_env.envs import MergeEnv, RoundaboutEnv, IntersectionEnv
from highway_env import utils
import numpy as np
# %matplotlib inline

# %% [markdown]
# #### HighWay (Fast) Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- original vehicle's count:** 20
# ###### **- vehicle's count:** 35

# %%
env = gym.make("highway-fast-v0", render_mode='rgb_array', config={"vehicles_count": 35})
pprint.pprint(env.config)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -1,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'type': 'Kinematics'},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 5,
#  'vehicles_count': 35,
#  'vehicles_density': 1}
# C:\Users\Caty\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.config to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.config` for environment variables or `env.get_wrapper_attr('config')` that will search the reminding wrappers.
#   logger.warn(

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="highway_75_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("highway_75_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to highway_75_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.6     |
# |    ep_rew_mean     | 8.65     |
# | time/              |          |
# |    fps             | 16       |
# |    iterations      | 1        |
# |    time_elapsed    | 126      |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.5        |
# |    ep_rew_mean          | 10.8        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 2           |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015890345 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | -0.0162     |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.554       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0236     |
# |    value_loss           | 0.95        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.2        |
# |    ep_rew_mean          | 12.1        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 3           |
# |    time_elapsed         | 381         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012945905 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.154       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.396       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0186     |
# |    value_loss           | 0.872       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.9        |
# |    ep_rew_mean          | 14.1        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 4           |
# |    time_elapsed         | 509         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.017713854 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0.181       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.389       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 0.823       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 23.1       |
# |    ep_rew_mean          | 17         |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 5          |
# |    time_elapsed         | 635        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01411108 |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.43      |
# |    explained_variance   | 0.212      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.256      |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0128    |
# |    value_loss           | 0.567      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.2        |
# |    ep_rew_mean          | 17          |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 6           |
# |    time_elapsed         | 761         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011483954 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.216       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.239       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.392       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.3        |
# |    ep_rew_mean          | 17.7        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 7           |
# |    time_elapsed         | 889         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011900217 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.163       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.159       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00825    |
# |    value_loss           | 0.377       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 24.6       |
# |    ep_rew_mean          | 18.2       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 8          |
# |    time_elapsed         | 1017       |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01845928 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.28      |
# |    explained_variance   | 0.195      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.0907     |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00985   |
# |    value_loss           | 0.309      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.6        |
# |    ep_rew_mean          | 18.9        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 9           |
# |    time_elapsed         | 1143        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012843138 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.13        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.111       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00788    |
# |    value_loss           | 0.367       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.9        |
# |    ep_rew_mean          | 17.8        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 10          |
# |    time_elapsed         | 1274        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.015619213 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0264      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00957    |
# |    value_loss           | 0.216       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.9        |
# |    ep_rew_mean          | 19.6        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 11          |
# |    time_elapsed         | 1403        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.013662554 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.201       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.273       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00795    |
# |    value_loss           | 0.356       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.7        |
# |    ep_rew_mean          | 16.7        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 12          |
# |    time_elapsed         | 1532        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.018850902 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.119       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.169       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.303       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.8        |
# |    ep_rew_mean          | 17.5        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 13          |
# |    time_elapsed         | 1660        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.011771422 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.289       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.321       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.453       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.2        |
# |    ep_rew_mean          | 18.8        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 14          |
# |    time_elapsed         | 1788        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.017020214 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.338       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.193       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00615    |
# |    value_loss           | 0.366       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.8        |
# |    ep_rew_mean          | 17.8        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 15          |
# |    time_elapsed         | 1914        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.017154686 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.13        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00884    |
# |    value_loss           | 0.334       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.8        |
# |    ep_rew_mean          | 18.5        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 16          |
# |    time_elapsed         | 2043        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.017685877 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.374       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.1         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00486    |
# |    value_loss           | 0.398       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.1        |
# |    ep_rew_mean          | 18.8        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 17          |
# |    time_elapsed         | 2168        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.014807062 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.423       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.303       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00376    |
# |    value_loss           | 0.354       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.8        |
# |    ep_rew_mean          | 19.3        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 18          |
# |    time_elapsed         | 2296        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.015002814 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.426       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0746      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00919    |
# |    value_loss           | 0.306       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25.3       |
# |    ep_rew_mean          | 19.9       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 19         |
# |    time_elapsed         | 2424       |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.01996142 |
# |    clip_fraction        | 0.244      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | 0.302      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.187      |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.00395   |
# |    value_loss           | 0.245      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.9        |
# |    ep_rew_mean          | 18.6        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 20          |
# |    time_elapsed         | 2551        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.022261119 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.389       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.183       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00231    |
# |    value_loss           | 0.24        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 23.6       |
# |    ep_rew_mean          | 18.5       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 21         |
# |    time_elapsed         | 2679       |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01765249 |
# |    clip_fraction        | 0.236      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.05      |
# |    explained_variance   | 0.449      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.0992     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00179   |
# |    value_loss           | 0.274      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 24.6       |
# |    ep_rew_mean          | 19.2       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 22         |
# |    time_elapsed         | 2806       |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.02016724 |
# |    clip_fraction        | 0.213      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.05      |
# |    explained_variance   | 0.49       |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.108      |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00624   |
# |    value_loss           | 0.27       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.4        |
# |    ep_rew_mean          | 18.9        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 23          |
# |    time_elapsed         | 2936        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.020139977 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.572       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0664      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00213    |
# |    value_loss           | 0.198       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 19.7        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 24          |
# |    time_elapsed         | 3065        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.023482699 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.996      |
# |    explained_variance   | 0.34        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0558      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00199    |
# |    value_loss           | 0.212       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.9        |
# |    ep_rew_mean          | 19.4        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 25          |
# |    time_elapsed         | 3194        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.027574938 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.98       |
# |    explained_variance   | 0.499       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.132       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00208    |
# |    value_loss           | 0.25        |
# -----------------------------------------

# %% [markdown]
# #### Merge Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- original vehicle's count:** 5
# ###### **- vehicle's count:** 7

# %%
# Personalized environment with a 75% increase in the number of vehicles
class CustomMergeEnv(MergeEnv):
    def _make_vehicles(self) -> None:
        """
        Create some new vehicles and add them to the road.
        """
        road = self.road
        ego_vehicle = self.action_type.vehicle_class(
            road, road.network.get_lane(("a", "b", 1)).position(30, 0), speed=30
        )
        road.vehicles.append(ego_vehicle)

        other_vehicles_type = utils.class_from_path(self.config["other_vehicles_type"])

        # Originally there were 3 vehicles; with a 75% increase, now there are 5
        for position, speed in [(90, 29), (70, 31), (5, 31.5), (50, 30.5), (30, 32)]:
            lane = road.network.get_lane(("a", "b", self.np_random.integers(2)))
            position = lane.position(position + self.np_random.uniform(-5, 5), 0)
            speed += self.np_random.uniform(-1, 1)
            road.vehicles.append(other_vehicles_type(road, position, speed=speed))

        # Fusion vehicle
        merging_v = other_vehicles_type(
            road, road.network.get_lane(("j", "k", 0)).position(110, 0), speed=20
        )
        merging_v.target_speed = 30
        road.vehicles.append(merging_v)
        self.vehicle = ego_vehicle

# %%
env = CustomMergeEnv(render_mode='rgb_array')
pprint.pprint(env.config)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -1,
#  'high_speed_reward': 0.2,
#  'lane_change_reward': -0.05,
#  'manual_control': False,
#  'merging_speed_reward': -0.5,
#  'observation': {'type': 'Kinematics'},
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15}

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="merge_75_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("merge_75_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to merge_75_ppo/PPO_1
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.54     |
# |    ep_rew_mean     | 1.71     |
# | time/              |          |
# |    fps             | 30       |
# |    iterations      | 1        |
# |    time_elapsed    | 66       |
# |    total_timesteps | 2048     |
# ---------------------------------
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# ...
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.02        |
# |    ep_rew_mean          | 5.28        |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 25          |
# |    time_elapsed         | 1652        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011749688 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.505      |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.013       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00199    |
# |    value_loss           | 0.104       |
# -----------------------------------------

# %% [markdown]
# #### Roundabout Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- original vehicle's count:** 5
# ###### **- vehicle's count:** 7

# %%
# Personalized environment with a 75% increase in the number of vehicles
class CustomRoundaboutEnv(RoundaboutEnv):
    def _make_vehicles(self) -> None:
        """
        Create some new vehicles and add them to the road.
        """
        position_deviation = 2
        speed_deviation = 2

        # Ego-vehicle
        ego_lane = self.road.network.get_lane(("ser", "ses", 0))
        ego_vehicle = self.action_type.vehicle_class(
            self.road,
            ego_lane.position(125, 0),
            speed=8,
            heading=ego_lane.heading_at(140),
        )
        try:
            ego_vehicle.plan_route_to("nxs")
        except AttributeError:
            pass
        self.road.vehicles.append(ego_vehicle)
        self.vehicle = ego_vehicle

        # Incoming vehicle
        destinations = ["exr", "sxr", "nxr"]
        other_vehicles_type = utils.class_from_path(self.config["other_vehicles_type"])
        vehicle = other_vehicles_type.make_on_lane(
            self.road,
            ("we", "sx", 1),
            longitudinal=5 + self.np_random.normal() * position_deviation,
            speed=16 + self.np_random.normal() * speed_deviation,
        )

        if self.config["incoming_vehicle_destination"] is not None:
            destination = destinations[self.config["incoming_vehicle_destination"]]
        else:
            destination = self.np_random.choice(destinations)
        vehicle.plan_route_to(destination)
        vehicle.randomize_behavior()
        self.road.vehicles.append(vehicle)

        # Other vehicles (From 2 to 4 vehicles, 75% increase)
        for i in list(range(1, 2)) + list(range(-1, 0)) + [2, -2]:  
            vehicle = other_vehicles_type.make_on_lane(
                self.road,
                ("we", "sx", 0),
                longitudinal=20 * i + self.np_random.normal() * position_deviation,
                speed=16 + self.np_random.normal() * speed_deviation,
            )
            vehicle.plan_route_to(self.np_random.choice(destinations))
            vehicle.randomize_behavior()
            self.road.vehicles.append(vehicle)

        # Entering vehicle
        vehicle = other_vehicles_type.make_on_lane(
            self.road,
            ("eer", "ees", 0),
            longitudinal=50 + self.np_random.normal() * position_deviation,
            speed=16 + self.np_random.normal() * speed_deviation,
        )
        vehicle.plan_route_to(self.np_random.choice(destinations))
        vehicle.randomize_behavior()
        self.road.vehicles.append(vehicle)

# %%
env = CustomRoundaboutEnv(render_mode='rgb_array')
pprint.pprint(env.config)
# Out:
# {'action': {'target_speeds': [0, 8, 16], 'type': 'DiscreteMetaAction'},
#  'centering_position': [0.5, 0.6],
#  'collision_reward': -1,
#  'duration': 11,
#  'high_speed_reward': 0.2,
#  'incoming_vehicle_destination': None,
#  'lane_change_reward': -0.05,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'absolute': True,
#                  'features_range': {'vx': [-15, 15],
#                                     'vy': [-15, 15],
#                                     'x': [-100, 100],
#                                     'y': [-100, 100]},
#                  'type': 'Kinematics'},
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'right_lane_reward': 0,
#  'scaling': 5.5,
#  'screen_height': 600,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15}

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="roundabout_75_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("roundabout_75_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to roundabout_75_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.44     |
# |    ep_rew_mean     | 7.21     |
# | time/              |          |
# |    fps             | 19       |
# |    iterations      | 1        |
# |    time_elapsed    | 104      |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.06        |
# |    ep_rew_mean          | 7.79        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 2           |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014313297 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | -0.0248     |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.294       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0186     |
# |    value_loss           | 0.817       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.22        |
# |    ep_rew_mean          | 7.93        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 3           |
# |    time_elapsed         | 317         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015313024 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.141       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.346       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0197     |
# |    value_loss           | 0.769       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.44        |
# |    ep_rew_mean          | 8.12        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 4           |
# |    time_elapsed         | 423         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018352482 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.357       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.022      |
# |    value_loss           | 0.734       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.3       |
# |    ep_rew_mean          | 8.93       |
# | time/                   |            |
# |    fps                  | 19         |
# |    iterations           | 5          |
# |    time_elapsed         | 527        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01670127 |
# |    clip_fraction        | 0.262      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.52      |
# |    explained_variance   | 0.111      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.392      |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0206    |
# |    value_loss           | 0.63       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.1        |
# |    ep_rew_mean          | 8.66        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 6           |
# |    time_elapsed         | 632         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.023491561 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.121       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.368       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0192     |
# |    value_loss           | 0.537       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.2        |
# |    ep_rew_mean          | 8.82        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 7           |
# |    time_elapsed         | 739         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.019376451 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.151       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0224     |
# |    value_loss           | 0.436       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.4        |
# |    ep_rew_mean          | 9           |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 8           |
# |    time_elapsed         | 844         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.021282889 |
# |    clip_fraction        | 0.311       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.232       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0221     |
# |    value_loss           | 0.499       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | 9.41        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 9           |
# |    time_elapsed         | 950         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.019622264 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.205       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.171       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 0.296       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | 9.34        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 10          |
# |    time_elapsed         | 1053        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.023120183 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.157       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.155       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0177     |
# |    value_loss           | 0.318       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 9.51        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 11          |
# |    time_elapsed         | 1160        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.020825561 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.122       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0605      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 0.245       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | 9.52        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 12          |
# |    time_elapsed         | 1263        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.021784432 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.157       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0514      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 0.336       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 9.52        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 13          |
# |    time_elapsed         | 1370        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.019876588 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.192       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0994      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 0.259       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.9       |
# |    ep_rew_mean          | 9.61       |
# | time/                   |            |
# |    fps                  | 19         |
# |    iterations           | 14         |
# |    time_elapsed         | 1478       |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.02029525 |
# |    clip_fraction        | 0.209      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.985     |
# |    explained_variance   | 0.146      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.0767     |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0106    |
# |    value_loss           | 0.159      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | 9.5         |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 15          |
# |    time_elapsed         | 1586        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.022366155 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.967      |
# |    explained_variance   | 0.122       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00488    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 0.134       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 9.64        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 16          |
# |    time_elapsed         | 1693        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.026170291 |
# |    clip_fraction        | 0.271       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | 0.15        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0505      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0177     |
# |    value_loss           | 0.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | 9.59        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 17          |
# |    time_elapsed         | 1800        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.031021325 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | 0.121       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0105      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 0.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 9.67        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 18          |
# |    time_elapsed         | 1906        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.020835737 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.865      |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.079       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 0.158       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.9       |
# |    ep_rew_mean          | 9.74       |
# | time/                   |            |
# |    fps                  | 19         |
# |    iterations           | 19         |
# |    time_elapsed         | 2012       |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.02566877 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.849     |
# |    explained_variance   | 0.146      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.121      |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0134    |
# |    value_loss           | 0.224      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | 9.65        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 20          |
# |    time_elapsed         | 2119        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.021583892 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.812      |
# |    explained_variance   | 0.0969      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0595      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00499    |
# |    value_loss           | 0.213       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 9.75        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 21          |
# |    time_elapsed         | 2225        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.026066847 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.848      |
# |    explained_variance   | 0.175       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.101       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.188       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | 9.59        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 22          |
# |    time_elapsed         | 2331        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.019970734 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.862      |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0348      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00587    |
# |    value_loss           | 0.222       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | 9.65        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 23          |
# |    time_elapsed         | 2437        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.021441128 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.845      |
# |    explained_variance   | 0.211       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.086       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00934    |
# |    value_loss           | 0.244       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | 9.63        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 24          |
# |    time_elapsed         | 2545        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.024877157 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.835      |
# |    explained_variance   | 0.114       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0145      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00394    |
# |    value_loss           | 0.225       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.6        |
# |    ep_rew_mean          | 9.53        |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 25          |
# |    time_elapsed         | 2654        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.025440164 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.808      |
# |    explained_variance   | 0.148       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0289      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0073     |
# |    value_loss           | 0.251       |
# -----------------------------------------

# %% [markdown]
# #### Parking Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- original vehicle's count:** 0
# ###### **- vehicle's count:** 3

# %%
env = gym.make("parking-v0", render_mode='rgb_array', config={"vehicles_count": 3})
pprint.pprint(env.config)
# Out:
# {'action': {'type': 'ContinuousAction'},
#  'add_walls': True,
#  'centering_position': [0.5, 0.5],
#  'collision_reward': -5,
#  'controlled_vehicles': 1,
#  'duration': 100,
#  'manual_control': False,
#  'observation': {'features': ['x', 'y', 'vx', 'vy', 'cos_h', 'sin_h'],
#                  'normalize': False,
#                  'scales': [100, 100, 5, 5, 1, 1],
#                  'type': 'KinematicsGoal'},
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 5,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_weights': [1, 0.3, 0, 0, 0.02, 0.02],
#  'scaling': 7,
#  'screen_height': 300,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15,
#  'steering_range': 0.7853981633974483,
#  'success_goal_reward': 0.12,
#  'vehicles_count': 3}
# C:\Users\Caty\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.config to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.config` for environment variables or `env.get_wrapper_attr('config')` that will search the reminding wrappers.
#   logger.warn(

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MultiInputPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="parking_75_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("parking_75_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to parking_75_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 61.8     |
# |    ep_rew_mean     | -33.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 79       |
# |    iterations      | 1        |
# |    time_elapsed    | 25       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 64.9        |
# |    ep_rew_mean          | -36         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 2           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006545234 |
# |    clip_fraction        | 0.0635      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | -0.108      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.179       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00407    |
# |    std                  | 1.02        |
# |    value_loss           | 1.06        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 65.9         |
# |    ep_rew_mean          | -36.3        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 3            |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0048012547 |
# |    clip_fraction        | 0.0564       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | -0.207       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.231        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00375     |
# |    std                  | 1.01         |
# |    value_loss           | 0.563        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 64.7         |
# |    ep_rew_mean          | -35.1        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 77           |
# |    iterations           | 4            |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0064206277 |
# |    clip_fraction        | 0.0766       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | -0.0328      |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0892       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00731     |
# |    std                  | 1            |
# |    value_loss           | 0.375        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 66.8         |
# |    ep_rew_mean          | -35.1        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 76           |
# |    iterations           | 5            |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0073575517 |
# |    clip_fraction        | 0.0717       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | -0.272       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.059        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00605     |
# |    std                  | 1.02         |
# |    value_loss           | 0.369        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 74.6         |
# |    ep_rew_mean          | -39          |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 76           |
# |    iterations           | 6            |
# |    time_elapsed         | 160          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0044292603 |
# |    clip_fraction        | 0.0385       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | -0.551       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.198        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0025      |
# |    std                  | 1.02         |
# |    value_loss           | 0.28         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74.7        |
# |    ep_rew_mean          | -39.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 7           |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006945088 |
# |    clip_fraction        | 0.0681      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0281      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00478    |
# |    std                  | 1.01        |
# |    value_loss           | 0.204       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 80.2         |
# |    ep_rew_mean          | -42.6        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 76           |
# |    iterations           | 8            |
# |    time_elapsed         | 215          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0077594616 |
# |    clip_fraction        | 0.094        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0.523        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0838       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00659     |
# |    std                  | 1.02         |
# |    value_loss           | 0.174        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.9        |
# |    ep_rew_mean          | -46.2       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 9           |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007679984 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0318      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0073     |
# |    std                  | 1.02        |
# |    value_loss           | 0.123       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.9        |
# |    ep_rew_mean          | -47.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 10          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012001546 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.617       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.017       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0084     |
# |    std                  | 1.01        |
# |    value_loss           | 0.0921      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 101        |
# |    ep_rew_mean          | -51.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 75         |
# |    iterations           | 11         |
# |    time_elapsed         | 298        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01127073 |
# |    clip_fraction        | 0.0966     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.88      |
# |    explained_variance   | 0.615      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.0481     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00708   |
# |    std                  | 1.02       |
# |    value_loss           | 0.111      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 116         |
# |    ep_rew_mean          | -57.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 12          |
# |    time_elapsed         | 326         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008026027 |
# |    clip_fraction        | 0.0851      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.707       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0191      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00821    |
# |    std                  | 1.01        |
# |    value_loss           | 0.0495      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 127         |
# |    ep_rew_mean          | -60.6       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 13          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.014425536 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.722       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0547      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00967    |
# |    std                  | 0.998       |
# |    value_loss           | 0.0487      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | -67.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 14          |
# |    time_elapsed         | 382         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011138918 |
# |    clip_fraction        | 0.0961      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.59        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00206     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00525    |
# |    std                  | 0.991       |
# |    value_loss           | 0.0325      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 154         |
# |    ep_rew_mean          | -69.6       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 15          |
# |    time_elapsed         | 409         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009268384 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.656       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00799     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 1           |
# |    value_loss           | 0.028       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 165         |
# |    ep_rew_mean          | -73.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 16          |
# |    time_elapsed         | 436         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.013641154 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.711       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0153     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00575    |
# |    std                  | 0.978       |
# |    value_loss           | 0.0291      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 157         |
# |    ep_rew_mean          | -69.1       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 17          |
# |    time_elapsed         | 464         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009524253 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.66        |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.0118     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00602    |
# |    std                  | 0.973       |
# |    value_loss           | 0.0318      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 170         |
# |    ep_rew_mean          | -72.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 18          |
# |    time_elapsed         | 493         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.012986865 |
# |    clip_fraction        | 0.0925      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.789       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0356      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.965       |
# |    value_loss           | 0.0602      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 184         |
# |    ep_rew_mean          | -77.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 19          |
# |    time_elapsed         | 521         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011984518 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.742       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00497     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00702    |
# |    std                  | 0.96        |
# |    value_loss           | 0.0233      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | -83.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 20          |
# |    time_elapsed         | 548         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010201425 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0217      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00776    |
# |    std                  | 0.949       |
# |    value_loss           | 0.0122      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 193         |
# |    ep_rew_mean          | -80.8       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 21          |
# |    time_elapsed         | 575         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.022688879 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0236      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.014      |
# |    std                  | 0.953       |
# |    value_loss           | 0.0131      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | -80.1       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 22          |
# |    time_elapsed         | 604         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.014835305 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0334      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00954    |
# |    std                  | 0.938       |
# |    value_loss           | 0.0456      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 201        |
# |    ep_rew_mean          | -82.6      |
# |    success_rate         | 0.01       |
# | time/                   |            |
# |    fps                  | 74         |
# |    iterations           | 23         |
# |    time_elapsed         | 633        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01454676 |
# |    clip_fraction        | 0.172      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.68      |
# |    explained_variance   | 0.782      |
# |    learning_rate        | 0.0005     |
# |    loss                 | -0.0217    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0119    |
# |    std                  | 0.921      |
# |    value_loss           | 0.0192     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 193         |
# |    ep_rew_mean          | -79.2       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 24          |
# |    time_elapsed         | 660         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012600921 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.68       |
# |    explained_variance   | 0.732       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0221      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.926       |
# |    value_loss           | 0.0317      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 195         |
# |    ep_rew_mean          | -80         |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 25          |
# |    time_elapsed         | 687         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011371008 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.0374      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0833      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0054     |
# |    std                  | 0.932       |
# |    value_loss           | 0.052       |
# -----------------------------------------

# %% [markdown]
# #### Intersection Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- original vehicle's count:** 10
# ###### **- vehicle's count:** 17

# %%
# Personalized environment with a 75% increase in the number of vehicles
class CustomIntersectionEnv(IntersectionEnv):
    def _make_vehicles(self, n_vehicles: int = 10) -> None:
        """
        Create some new vehicles and add them to the road.
        """
        # Increase the number of vehicles by 75%
        n_vehicles = int(n_vehicles * 1.75)

        vehicle_type = utils.class_from_path(self.config["other_vehicles_type"])
        vehicle_type.DISTANCE_WANTED = 7  # Low jam distance
        vehicle_type.COMFORT_ACC_MAX = 6
        vehicle_type.COMFORT_ACC_MIN = -3

        # Random vehicles
        simulation_steps = 3
        for t in range(n_vehicles - 1):
            self._spawn_vehicle(np.linspace(0, 80, n_vehicles)[t])
        for _ in range(simulation_steps):
            [
                (
                    self.road.act(),
                    self.road.step(1 / self.config["simulation_frequency"]),
                )
                for _ in range(self.config["simulation_frequency"])
            ]

        # Ego-vehicle
        self._spawn_vehicle(
            60,
            spawn_probability=1,
            go_straight=True,
            position_deviation=0.1,
            speed_deviation=0,
        )

        # Incoming vehicle
        self.controlled_vehicles = []
        for ego_id in range(0, self.config["controlled_vehicles"]):
            ego_lane = self.road.network.get_lane(
                (f"o{ego_id % 4}", f"ir{ego_id % 4}", 0)
            )
            destination = self.config["destination"] or "o" + str(
                self.np_random.integers(1, 4)
            )
            ego_vehicle = self.action_type.vehicle_class(
                self.road,
                ego_lane.position(60 + 5 * self.np_random.normal(1), 0),
                speed=ego_lane.speed_limit,
                heading=ego_lane.heading_at(60),
            )
            try:
                ego_vehicle.plan_route_to(destination)
                ego_vehicle.speed_index = ego_vehicle.speed_to_index(
                    ego_lane.speed_limit
                )
                ego_vehicle.target_speed = ego_vehicle.index_to_speed(
                    ego_vehicle.speed_index
                )
            except AttributeError:
                pass

            self.road.vehicles.append(ego_vehicle)
            self.controlled_vehicles.append(ego_vehicle)
            for v in self.road.vehicles:  
                if (
                    v is not ego_vehicle
                    and np.linalg.norm(v.position - ego_vehicle.position) < 20
                ):
                    self.road.vehicles.remove(v)

# %%
env = CustomIntersectionEnv(render_mode='rgb_array')
pprint.pprint(env.config)
# Out:
# {'action': {'lateral': False,
#             'longitudinal': True,
#             'target_speeds': [0, 4.5, 9],
#             'type': 'DiscreteMetaAction'},
#  'arrived_reward': 1,
#  'centering_position': [0.5, 0.6],
#  'collision_reward': -5,
#  'controlled_vehicles': 1,
#  'destination': 'o1',
#  'duration': 13,
#  'high_speed_reward': 1,
#  'initial_vehicle_count': 10,
#  'manual_control': False,
#  'normalize_reward': False,
#  'observation': {'absolute': True,
#                  'features': ['presence',
#                               'x',
#                               'y',
#                               'vx',
#                               'vy',
#                               'cos_h',
#                               'sin_h'],
#                  'features_range': {'vx': [-20, 20],
#                                     'vy': [-20, 20],
#                                     'x': [-100, 100],
#                                     'y': [-100, 100]},
#                  'flatten': False,
#                  'observe_intentions': False,
#                  'type': 'Kinematics',
#                  'vehicles_count': 15},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [7.0, 9.0],
#  'scaling': 7.15,
#  'screen_height': 600,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15,
#  'spawn_probability': 0.6}

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="intersection_75_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("intersection_75_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to intersection_75_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.4      |
# |    ep_rew_mean     | 0.465    |
# | time/              |          |
# |    fps             | 12       |
# |    iterations      | 1        |
# |    time_elapsed    | 165      |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.48        |
# |    ep_rew_mean          | 0.844       |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 2           |
# |    time_elapsed         | 331         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.023502745 |
# |    clip_fraction        | 0.311       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.00556     |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.14        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0258     |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.95        |
# |    ep_rew_mean          | 1.61        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 3           |
# |    time_elapsed         | 493         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.028756492 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.206       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.32        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0226     |
# |    value_loss           | 3.21        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.38        |
# |    ep_rew_mean          | 2.53        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 4           |
# |    time_elapsed         | 655         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016147036 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.966      |
# |    explained_variance   | 0.256       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.82        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0206     |
# |    value_loss           | 4.09        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.41        |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 5           |
# |    time_elapsed         | 820         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016430637 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.933      |
# |    explained_variance   | 0.283       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.5         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 3.77        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.85        |
# |    ep_rew_mean          | 2.87        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 6           |
# |    time_elapsed         | 981         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015530539 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.873      |
# |    explained_variance   | 0.244       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.62        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.019      |
# |    value_loss           | 4.49        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.96        |
# |    ep_rew_mean          | 3.5         |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 7           |
# |    time_elapsed         | 1144        |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.017436134 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.837      |
# |    explained_variance   | 0.266       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.64        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0145     |
# |    value_loss           | 4.39        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.34       |
# |    ep_rew_mean          | 2.8        |
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 8          |
# |    time_elapsed         | 1305       |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01578512 |
# |    clip_fraction        | 0.17       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.789     |
# |    explained_variance   | 0.236      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 1.61       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0153    |
# |    value_loss           | 4.2        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.97        |
# |    ep_rew_mean          | 2.21        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 9           |
# |    time_elapsed         | 1472        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012846367 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.745      |
# |    explained_variance   | 0.251       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.83        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 4.61        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.38        |
# |    ep_rew_mean          | 3.07        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 10          |
# |    time_elapsed         | 1633        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.019838734 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.701      |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 3.37        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0155     |
# |    value_loss           | 4.6         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.36       |
# |    ep_rew_mean          | 3.54       |
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 11         |
# |    time_elapsed         | 1797       |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01750201 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.671     |
# |    explained_variance   | 0.212      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 2.01       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0101    |
# |    value_loss           | 4.63       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.8        |
# |    ep_rew_mean          | 2.75       |
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 12         |
# |    time_elapsed         | 1965       |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01981174 |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.636     |
# |    explained_variance   | 0.165      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 1.72       |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0139    |
# |    value_loss           | 4.52       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.25        |
# |    ep_rew_mean          | 3.52        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 13          |
# |    time_elapsed         | 2130        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.017819412 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.628      |
# |    explained_variance   | 0.208       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.94        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 4.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.93        |
# |    ep_rew_mean          | 2.74        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 14          |
# |    time_elapsed         | 2291        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015587337 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.625      |
# |    explained_variance   | 0.227       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.77        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 4.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.01        |
# |    ep_rew_mean          | 3.31        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 15          |
# |    time_elapsed         | 2449        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012961446 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.624      |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.08        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 4.95        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.51        |
# |    ep_rew_mean          | 3.55        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 16          |
# |    time_elapsed         | 2615        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.018949237 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.619      |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.33        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 4.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.91        |
# |    ep_rew_mean          | 2.87        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 17          |
# |    time_elapsed         | 2779        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.023657106 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.605      |
# |    explained_variance   | 0.199       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.5         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 4.78        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.11        |
# |    ep_rew_mean          | 2.73        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 18          |
# |    time_elapsed         | 2941        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.014917096 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.578      |
# |    explained_variance   | 0.26        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.8         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 4.53        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.52        |
# |    ep_rew_mean          | 1.92        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 19          |
# |    time_elapsed         | 3103        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011595357 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.556      |
# |    explained_variance   | 0.234       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.69        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 4.49        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7           |
# |    ep_rew_mean          | 3.44        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 20          |
# |    time_elapsed         | 3269        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.021346208 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.542      |
# |    explained_variance   | 0.234       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.81        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0201     |
# |    value_loss           | 4.61        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.21        |
# |    ep_rew_mean          | 3.91        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 21          |
# |    time_elapsed         | 3430        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.022273775 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.518      |
# |    explained_variance   | 0.248       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.79        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0168     |
# |    value_loss           | 4.52        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.61       |
# |    ep_rew_mean          | 2.88       |
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 22         |
# |    time_elapsed         | 3596       |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.02143544 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.519     |
# |    explained_variance   | 0.211      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 1.88       |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0162    |
# |    value_loss           | 4.57       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.8         |
# |    ep_rew_mean          | 2.75        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 23          |
# |    time_elapsed         | 3765        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.014021048 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.512      |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.65        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 4.95        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.17        |
# |    ep_rew_mean          | 3.12        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 24          |
# |    time_elapsed         | 3926        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.025981128 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.509      |
# |    explained_variance   | 0.2         |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.11        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0187     |
# |    value_loss           | 4.62        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 7.07      |
# |    ep_rew_mean          | 3.02      |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 25        |
# |    time_elapsed         | 4094      |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0207008 |
# |    clip_fraction        | 0.154     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.489    |
# |    explained_variance   | 0.268     |
# |    learning_rate        | 0.0005    |
# |    loss                 | 1.82      |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -0.0181   |
# |    value_loss           | 4.13      |
# ---------------------------------------
