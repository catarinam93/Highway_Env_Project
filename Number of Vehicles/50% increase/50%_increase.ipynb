# %% [markdown]
# # 50% increase in the original number of vehicles

# %% [markdown]
# ##### Imports

# %%
import gymnasium as gym
from matplotlib import pyplot as plt
import pprint
import gymnasium as gym
import highway_env
from stable_baselines3 import PPO
from highway_env.envs import MergeEnv, RoundaboutEnv, IntersectionEnv
from highway_env import utils
import numpy as np
# %matplotlib inline

# %% [markdown]
# #### HighWay (Fast) Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- original vehicle's count:** 20
# ###### **- vehicle's count:** 30

# %%
env = gym.make("highway-fast-v0", render_mode='rgb_array', config={"vehicles_count": 20})
pprint.pprint(env.config)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -1,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'type': 'Kinematics'},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 5,
#  'vehicles_count': 20,
#  'vehicles_density': 1}
# C:\Users\Caty\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.config to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.config` for environment variables or `env.get_wrapper_attr('config')` that will search the reminding wrappers.
#   logger.warn(

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="highway_50_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("highway_50_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to highway_50_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.9     |
# |    ep_rew_mean     | 8.85     |
# | time/              |          |
# |    fps             | 28       |
# |    iterations      | 1        |
# |    time_elapsed    | 70       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11.9       |
# |    ep_rew_mean          | 8.91       |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 2          |
# |    time_elapsed         | 146        |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01654928 |
# |    clip_fraction        | 0.236      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.59      |
# |    explained_variance   | 0.00947    |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.375      |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0232    |
# |    value_loss           | 0.886      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15          |
# |    ep_rew_mean          | 11.1        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 3           |
# |    time_elapsed         | 218         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015458749 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.208       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.45        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0197     |
# |    value_loss           | 0.87        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.1        |
# |    ep_rew_mean          | 14.8        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 4           |
# |    time_elapsed         | 291         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.017624352 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.172       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.432       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0218     |
# |    value_loss           | 0.745       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.7         |
# |    ep_rew_mean          | 15.2         |
# | time/                   |              |
# |    fps                  | 28           |
# |    iterations           | 5            |
# |    time_elapsed         | 363          |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0152857015 |
# |    clip_fraction        | 0.244        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.243        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.231        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0204      |
# |    value_loss           | 0.546        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.3        |
# |    ep_rew_mean          | 16.3        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 6           |
# |    time_elapsed         | 434         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010463605 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.244       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.177       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00998    |
# |    value_loss           | 0.542       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.4        |
# |    ep_rew_mean          | 18.1        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 7           |
# |    time_elapsed         | 507         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.014781384 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.236       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.177       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 0.429       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.3        |
# |    ep_rew_mean          | 17.1        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 8           |
# |    time_elapsed         | 579         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014189055 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.163       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.218       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 0.394       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.6        |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 9           |
# |    time_elapsed         | 648         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.014985647 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.174       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.179       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00846    |
# |    value_loss           | 0.377       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.7        |
# |    ep_rew_mean          | 18.4        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 10          |
# |    time_elapsed         | 716         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.027487531 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.162       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.114       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.198       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 24.9       |
# |    ep_rew_mean          | 18.9       |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 11         |
# |    time_elapsed         | 783        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.02184153 |
# |    clip_fraction        | 0.237      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.248      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.175      |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00935   |
# |    value_loss           | 0.294      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.8        |
# |    ep_rew_mean          | 17.6        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 12          |
# |    time_elapsed         | 852         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.029521553 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.254       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.226       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00656    |
# |    value_loss           | 0.28        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.2        |
# |    ep_rew_mean          | 18.1        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 13          |
# |    time_elapsed         | 926         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010599274 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.236       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.445       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0019     |
# |    value_loss           | 0.514       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.8        |
# |    ep_rew_mean          | 18.5        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 14          |
# |    time_elapsed         | 994         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.021977678 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.339       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.319       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00229    |
# |    value_loss           | 0.328       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.7        |
# |    ep_rew_mean          | 19.9        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 15          |
# |    time_elapsed         | 1060        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012520233 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.248       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0903      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.000548   |
# |    value_loss           | 0.4         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 26.1       |
# |    ep_rew_mean          | 20.1       |
# | time/                   |            |
# |    fps                  | 29         |
# |    iterations           | 16         |
# |    time_elapsed         | 1127       |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.02077846 |
# |    clip_fraction        | 0.211      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | 0.322      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.103      |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.00157   |
# |    value_loss           | 0.265      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.6        |
# |    ep_rew_mean          | 19          |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 17          |
# |    time_elapsed         | 1196        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.024459252 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.923      |
# |    explained_variance   | 0.339       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0864      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00259    |
# |    value_loss           | 0.245       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.8        |
# |    ep_rew_mean          | 18.5        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 18          |
# |    time_elapsed         | 1264        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.018229185 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.901      |
# |    explained_variance   | 0.378       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.137       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00448    |
# |    value_loss           | 0.302       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.1        |
# |    ep_rew_mean          | 18.9        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 19          |
# |    time_elapsed         | 1331        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.024770627 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.852      |
# |    explained_variance   | 0.486       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.157       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00266    |
# |    value_loss           | 0.276       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.6        |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 20          |
# |    time_elapsed         | 1398        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.020991907 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.804      |
# |    explained_variance   | 0.291       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.251       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00316    |
# |    value_loss           | 0.314       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 24         |
# |    ep_rew_mean          | 18.8       |
# | time/                   |            |
# |    fps                  | 29         |
# |    iterations           | 21         |
# |    time_elapsed         | 1465       |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.02351467 |
# |    clip_fraction        | 0.209      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.799     |
# |    explained_variance   | 0.385      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.207      |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00368   |
# |    value_loss           | 0.316      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.6        |
# |    ep_rew_mean          | 19.3        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 22          |
# |    time_elapsed         | 1532        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.019070238 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.719      |
# |    explained_variance   | 0.433       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.179       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00372    |
# |    value_loss           | 0.328       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.9        |
# |    ep_rew_mean          | 19.5        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 23          |
# |    time_elapsed         | 1601        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.012668639 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.71       |
# |    explained_variance   | 0.521       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0358      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00243    |
# |    value_loss           | 0.244       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.1        |
# |    ep_rew_mean          | 18.9        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 24          |
# |    time_elapsed         | 1669        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.021279098 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.73       |
# |    explained_variance   | 0.397       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0568      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00548    |
# |    value_loss           | 0.29        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.1        |
# |    ep_rew_mean          | 18.1        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 25          |
# |    time_elapsed         | 1737        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.017393399 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.624      |
# |    explained_variance   | 0.475       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.206       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0014     |
# |    value_loss           | 0.298       |
# -----------------------------------------

# %% [markdown]
# #### Merge Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- original vehicle's count:** 5
# ###### **- vehicle's count:** 7

# %%
# Personalized environment with a 50% increase in the number of vehicles
class CustomMergeEnv(MergeEnv):
    def _make_vehicles(self) -> None:
        """
        Create some new vehicles and add them to the road.
        """
        road = self.road
        ego_vehicle = self.action_type.vehicle_class(
            road, road.network.get_lane(("a", "b", 1)).position(30, 0), speed=30
        )
        road.vehicles.append(ego_vehicle)

        other_vehicles_type = utils.class_from_path(self.config["other_vehicles_type"])

        # Originally there were 3 vehicles; with a 50% increase, now there are 5
        for position, speed in [(90, 29), (70, 31), (5, 31.5), (50, 30.5), (30, 32)]:
            lane = road.network.get_lane(("a", "b", self.np_random.integers(2)))
            position = lane.position(position + self.np_random.uniform(-5, 5), 0)
            speed += self.np_random.uniform(-1, 1)
            road.vehicles.append(other_vehicles_type(road, position, speed=speed))

        # Fusion vehicle
        merging_v = other_vehicles_type(
            road, road.network.get_lane(("j", "k", 0)).position(110, 0), speed=20
        )
        merging_v.target_speed = 30
        road.vehicles.append(merging_v)
        self.vehicle = ego_vehicle

# %%
env = CustomMergeEnv(render_mode='rgb_array')
pprint.pprint(env.config)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -1,
#  'high_speed_reward': 0.2,
#  'lane_change_reward': -0.05,
#  'manual_control': False,
#  'merging_speed_reward': -0.5,
#  'observation': {'type': 'Kinematics'},
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15}

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="merge_50_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("merge_50_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to merge_50_ppo/PPO_1
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overTrue
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.87     |
# |    ep_rew_mean     | 1.96     |
# | time/              |          |
# |    fps             | 30       |
# |    iterations      | 1        |
# |    time_elapsed    | 66       |
# |    total_timesteps | 2048     |
# ---------------------------------
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# ...
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# crashFalse
# overTrue
# crashTrue
# overFalse
# crashFalse
# overFalse
# crashFalse
# overFalse
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.26        |
# |    ep_rew_mean          | 5.63        |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 25          |
# |    time_elapsed         | 1653        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.013386657 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.675      |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0977      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00583    |
# |    value_loss           | 0.155       |
# -----------------------------------------

# %% [markdown]
# #### Roundabout Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- original vehicle's count:** 5
# ###### **- vehicle's count:** 8

# %%
# Personalized environment with a 50% increase in the number of vehicles
class CustomRoundaboutEnv(RoundaboutEnv):
    def _make_vehicles(self) -> None:
        """
        Create some new vehicles and add them to the road.
        """
        position_deviation = 2
        speed_deviation = 2

        # Ego-vehicle
        ego_lane = self.road.network.get_lane(("ser", "ses", 0))
        ego_vehicle = self.action_type.vehicle_class(
            self.road,
            ego_lane.position(125, 0),
            speed=8,
            heading=ego_lane.heading_at(140),
        )
        try:
            ego_vehicle.plan_route_to("nxs")
        except AttributeError:
            pass
        self.road.vehicles.append(ego_vehicle)
        self.vehicle = ego_vehicle

        # Incoming vehicle
        destinations = ["exr", "sxr", "nxr"]
        other_vehicles_type = utils.class_from_path(self.config["other_vehicles_type"])
        vehicle = other_vehicles_type.make_on_lane(
            self.road,
            ("we", "sx", 1),
            longitudinal=5 + self.np_random.normal() * position_deviation,
            speed=16 + self.np_random.normal() * speed_deviation,
        )

        if self.config["incoming_vehicle_destination"] is not None:
            destination = destinations[self.config["incoming_vehicle_destination"]]
        else:
            destination = self.np_random.choice(destinations)
        vehicle.plan_route_to(destination)
        vehicle.randomize_behavior()
        self.road.vehicles.append(vehicle)

        # Other vehicles (From 2 to 5 vehicles, 50% increase from original 2)
        for i in list(range(1, 2)) + list(range(-1, 0)) + [2, -2, 3]:
            vehicle = other_vehicles_type.make_on_lane(
                self.road,
                ("we", "sx", 0),
                longitudinal=20 * i + self.np_random.normal() * position_deviation,
                speed=16 + self.np_random.normal() * speed_deviation,
            )
            vehicle.plan_route_to(self.np_random.choice(destinations))
            vehicle.randomize_behavior()
            self.road.vehicles.append(vehicle)

        # Entering vehicle
        vehicle = other_vehicles_type.make_on_lane(
            self.road,
            ("eer", "ees", 0),
            longitudinal=50 + self.np_random.normal() * position_deviation,
            speed=16 + self.np_random.normal() * speed_deviation,
        )
        vehicle.plan_route_to(self.np_random.choice(destinations))
        vehicle.randomize_behavior()
        self.road.vehicles.append(vehicle)

# %%
env = CustomRoundaboutEnv(render_mode='rgb_array')
pprint.pprint(env.config)
# Out:
# {'action': {'target_speeds': [0, 8, 16], 'type': 'DiscreteMetaAction'},
#  'centering_position': [0.5, 0.6],
#  'collision_reward': -1,
#  'duration': 11,
#  'high_speed_reward': 0.2,
#  'incoming_vehicle_destination': None,
#  'lane_change_reward': -0.05,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'absolute': True,
#                  'features_range': {'vx': [-15, 15],
#                                     'vy': [-15, 15],
#                                     'x': [-100, 100],
#                                     'y': [-100, 100]},
#                  'type': 'Kinematics'},
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'right_lane_reward': 0,
#  'scaling': 5.5,
#  'screen_height': 600,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15}

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="roundabout_50_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("roundabout_50_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to roundabout_50_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.33     |
# |    ep_rew_mean     | 7.11     |
# | time/              |          |
# |    fps             | 17       |
# |    iterations      | 1        |
# |    time_elapsed    | 120      |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.95        |
# |    ep_rew_mean          | 7.74        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 2           |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013692176 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | -0.125      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.392       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.018      |
# |    value_loss           | 0.932       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.21        |
# |    ep_rew_mean          | 7.9         |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 3           |
# |    time_elapsed         | 360         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015721995 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.0928      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.383       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 0.828       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.82        |
# |    ep_rew_mean          | 8.49        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 4           |
# |    time_elapsed         | 477         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.019071834 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.046       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.452       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0211     |
# |    value_loss           | 0.814       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.1        |
# |    ep_rew_mean          | 8.79        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 5           |
# |    time_elapsed         | 595         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016729988 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.0683      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.301       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 0.709       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.3        |
# |    ep_rew_mean          | 8.78        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 6           |
# |    time_elapsed         | 713         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.019089185 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.0812      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.307       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 0.531       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.2        |
# |    ep_rew_mean          | 8.8         |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 7           |
# |    time_elapsed         | 834         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.016403222 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.0941      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.408       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 0.426       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.3        |
# |    ep_rew_mean          | 8.87        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 8           |
# |    time_elapsed         | 955         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.024127748 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.134       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.151       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.385       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | 9.17        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 9           |
# |    time_elapsed         | 1075        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.018597052 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.156       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.171       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0166     |
# |    value_loss           | 0.414       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | 9.23        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 10          |
# |    time_elapsed         | 1192        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.021152552 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.0989      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.103       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0148     |
# |    value_loss           | 0.217       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11          |
# |    ep_rew_mean          | 9.47        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 11          |
# |    time_elapsed         | 1309        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.019074775 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.149       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.136       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 0.289       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | 9.3         |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 12          |
# |    time_elapsed         | 1430        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.030695582 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.14       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00561    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0222     |
# |    value_loss           | 0.102       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.6       |
# |    ep_rew_mean          | 9.16       |
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 13         |
# |    time_elapsed         | 1548       |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.02348438 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.11      |
# |    explained_variance   | 0.0782     |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.0313     |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.00759   |
# |    value_loss           | 0.309      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.6        |
# |    ep_rew_mean          | 9.14        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 14          |
# |    time_elapsed         | 1667        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.028447637 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.983      |
# |    explained_variance   | 0.215       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.111       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.227       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11          |
# |    ep_rew_mean          | 9.58        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 15          |
# |    time_elapsed         | 1784        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.017033152 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.956      |
# |    explained_variance   | 0.114       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0274      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 0.156       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 9.6         |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 16          |
# |    time_elapsed         | 1903        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.022364376 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.93       |
# |    explained_variance   | 0.183       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0232      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 0.192       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.4        |
# |    ep_rew_mean          | 9.06        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 17          |
# |    time_elapsed         | 2022        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.016320068 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.916      |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0348      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.121       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | 9.51        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 18          |
# |    time_elapsed         | 2141        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.014385587 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.923      |
# |    explained_variance   | 0.139       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.301       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00783    |
# |    value_loss           | 0.34        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 9.63        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 19          |
# |    time_elapsed         | 2259        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.023326613 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.93       |
# |    explained_variance   | 0.241       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0765      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 0.283       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.6        |
# |    ep_rew_mean          | 9.33        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 20          |
# |    time_elapsed         | 2379        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.017311301 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.868      |
# |    explained_variance   | 0.238       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0282      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00924    |
# |    value_loss           | 0.105       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | 9.42        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 21          |
# |    time_elapsed         | 2500        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.021499997 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.861      |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.127       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 0.303       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 9.57        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 22          |
# |    time_elapsed         | 2618        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.016193954 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.839      |
# |    explained_variance   | 0.197       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0725      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00851    |
# |    value_loss           | 0.225       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | 9.47        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 23          |
# |    time_elapsed         | 2741        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.024804216 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.767      |
# |    explained_variance   | 0.198       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.07        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.147       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 9.53        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 24          |
# |    time_elapsed         | 2862        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.019270843 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.756      |
# |    explained_variance   | 0.176       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0398      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00619    |
# |    value_loss           | 0.189       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 9.64        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 25          |
# |    time_elapsed         | 2984        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.027376726 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.755      |
# |    explained_variance   | 0.208       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0256      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 0.152       |
# -----------------------------------------

# %% [markdown]
# #### Parking Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- original vehicle's count:** 0
# ###### **- vehicle's count:** 2

# %%
env = gym.make("parking-v0", render_mode='rgb_array', config={"vehicles_count": 2})
pprint.pprint(env.config)
# Out:
# {'action': {'type': 'ContinuousAction'},
#  'add_walls': True,
#  'centering_position': [0.5, 0.5],
#  'collision_reward': -5,
#  'controlled_vehicles': 1,
#  'duration': 100,
#  'manual_control': False,
#  'observation': {'features': ['x', 'y', 'vx', 'vy', 'cos_h', 'sin_h'],
#                  'normalize': False,
#                  'scales': [100, 100, 5, 5, 1, 1],
#                  'type': 'KinematicsGoal'},
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 5,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_weights': [1, 0.3, 0, 0, 0.02, 0.02],
#  'scaling': 7,
#  'screen_height': 300,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15,
#  'steering_range': 0.7853981633974483,
#  'success_goal_reward': 0.12,
#  'vehicles_count': 2}
# C:\Users\Caty\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.config to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.config` for environment variables or `env.get_wrapper_attr('config')` that will search the reminding wrappers.
#   logger.warn(

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MultiInputPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="parking_50_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("parking_50_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to parking_50_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 71.4     |
# |    ep_rew_mean     | -38.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 87       |
# |    iterations      | 1        |
# |    time_elapsed    | 23       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.3        |
# |    ep_rew_mean          | -43         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 2           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006184124 |
# |    clip_fraction        | 0.0549      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | -0.044      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.285       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00215    |
# |    std                  | 1.01        |
# |    value_loss           | 0.99        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 79.3         |
# |    ep_rew_mean          | -42.7        |
# |    success_rate         | 0.013        |
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 3            |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0068245167 |
# |    clip_fraction        | 0.0561       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | -0.0459      |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0825       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00306     |
# |    std                  | 1.02         |
# |    value_loss           | 0.364        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.1        |
# |    ep_rew_mean          | -41.2       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 4           |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008384406 |
# |    clip_fraction        | 0.0698      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | -0.529      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.103       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00661    |
# |    std                  | 1.02        |
# |    value_loss           | 0.447       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 71.2         |
# |    ep_rew_mean          | -38.7        |
# |    success_rate         | 0.01         |
# | time/                   |              |
# |    fps                  | 84           |
# |    iterations           | 5            |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0051231943 |
# |    clip_fraction        | 0.0575       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | -0.249       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.208        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00384     |
# |    std                  | 1.02         |
# |    value_loss           | 0.416        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 70.2         |
# |    ep_rew_mean          | -38.6        |
# |    success_rate         | 0.01         |
# | time/                   |              |
# |    fps                  | 84           |
# |    iterations           | 6            |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0059179254 |
# |    clip_fraction        | 0.0821       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0.0675       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.135        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00694     |
# |    std                  | 1.03         |
# |    value_loss           | 0.36         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 76.4       |
# |    ep_rew_mean          | -41.6      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 84         |
# |    iterations           | 7          |
# |    time_elapsed         | 169        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.00853639 |
# |    clip_fraction        | 0.0722     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.89      |
# |    explained_variance   | -0.0721    |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.125      |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00488   |
# |    std                  | 1.02       |
# |    value_loss           | 0.278      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 78.4         |
# |    ep_rew_mean          | -43          |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 85           |
# |    iterations           | 8            |
# |    time_elapsed         | 192          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0060778046 |
# |    clip_fraction        | 0.0533       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.115        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0879       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00417     |
# |    std                  | 1.02         |
# |    value_loss           | 0.245        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 81.5         |
# |    ep_rew_mean          | -44          |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 85           |
# |    iterations           | 9            |
# |    time_elapsed         | 216          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0059834984 |
# |    clip_fraction        | 0.0585       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | -0.026       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0583       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00265     |
# |    std                  | 1.02         |
# |    value_loss           | 0.2          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 88           |
# |    ep_rew_mean          | -46.8        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 84           |
# |    iterations           | 10           |
# |    time_elapsed         | 241          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0059236577 |
# |    clip_fraction        | 0.0523       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | 0.178        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0729       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00305     |
# |    std                  | 1.02         |
# |    value_loss           | 0.229        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.3        |
# |    ep_rew_mean          | -51.4       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 11          |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008016104 |
# |    clip_fraction        | 0.0815      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.592       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0349      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00673    |
# |    std                  | 1.02        |
# |    value_loss           | 0.107       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -54         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 12          |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009400383 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.88       |
# |    explained_variance   | 0.644       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.01        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00901    |
# |    std                  | 1.03        |
# |    value_loss           | 0.0844      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 112         |
# |    ep_rew_mean          | -57         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 13          |
# |    time_elapsed         | 313         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.012958093 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.544       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0676      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 1.03        |
# |    value_loss           | 0.106       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 129          |
# |    ep_rew_mean          | -63.3        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 84           |
# |    iterations           | 14           |
# |    time_elapsed         | 337          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0071949046 |
# |    clip_fraction        | 0.0856       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 0.454        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.00642      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00539     |
# |    std                  | 1.02         |
# |    value_loss           | 0.0516       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 137         |
# |    ep_rew_mean          | -65.6       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 15          |
# |    time_elapsed         | 362         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009608656 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.696       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0109      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00574    |
# |    std                  | 1.01        |
# |    value_loss           | 0.032       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | -70.7       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 16          |
# |    time_elapsed         | 387         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006493561 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.429       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0157      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00529    |
# |    std                  | 1.02        |
# |    value_loss           | 0.0847      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 164         |
# |    ep_rew_mean          | -76.1       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 17          |
# |    time_elapsed         | 411         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008527699 |
# |    clip_fraction        | 0.0926      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.504       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00215    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00759    |
# |    std                  | 0.994       |
# |    value_loss           | 0.0332      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 181        |
# |    ep_rew_mean          | -83.1      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 84         |
# |    iterations           | 18         |
# |    time_elapsed         | 435        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.01124254 |
# |    clip_fraction        | 0.109      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.81      |
# |    explained_variance   | 0.662      |
# |    learning_rate        | 0.0005     |
# |    loss                 | -0.00228   |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00663   |
# |    std                  | 0.988      |
# |    value_loss           | 0.0164     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 193         |
# |    ep_rew_mean          | -86.2       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 19          |
# |    time_elapsed         | 459         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007879686 |
# |    clip_fraction        | 0.0907      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.667       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00825     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00503    |
# |    std                  | 0.972       |
# |    value_loss           | 0.0141      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 202         |
# |    ep_rew_mean          | -90.2       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 20          |
# |    time_elapsed         | 484         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.018216852 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.829       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00894    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0159     |
# |    std                  | 0.975       |
# |    value_loss           | 0.0123      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 214         |
# |    ep_rew_mean          | -92.9       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 21          |
# |    time_elapsed         | 509         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009342408 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.559       |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00118    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00678    |
# |    std                  | 0.961       |
# |    value_loss           | 0.0172      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 227        |
# |    ep_rew_mean          | -99.3      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 84         |
# |    iterations           | 22         |
# |    time_elapsed         | 533        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.01953604 |
# |    clip_fraction        | 0.236      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.76      |
# |    explained_variance   | 0.781      |
# |    learning_rate        | 0.0005     |
# |    loss                 | -0.000249  |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0102    |
# |    std                  | 0.968      |
# |    value_loss           | 0.0161     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 245         |
# |    ep_rew_mean          | -105        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 23          |
# |    time_elapsed         | 558         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.015444326 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00768     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.949       |
# |    value_loss           | 0.00167     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 260         |
# |    ep_rew_mean          | -111        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 24          |
# |    time_elapsed         | 582         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009375767 |
# |    clip_fraction        | 0.0971      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.71       |
# |    explained_variance   | 0.449       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0103      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00435    |
# |    std                  | 0.944       |
# |    value_loss           | 0.03        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 270         |
# |    ep_rew_mean          | -114        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 25          |
# |    time_elapsed         | 606         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.015934478 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.71       |
# |    explained_variance   | 0.713       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0421      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.942       |
# |    value_loss           | 0.0194      |
# -----------------------------------------

# %% [markdown]
# #### Intersection Environment
# ###### **Defaul Settings**
# ###### **- algorithm:** PPO
# ###### **- timesteps:** 50 000
# ###### **- original vehicle's count:** 10
# ###### **- vehicle's count:** 15

# %%
# Personalized environment with a 50% increase in the number of vehicles
class CustomIntersectionEnv(IntersectionEnv):
    def _make_vehicles(self, n_vehicles: int = 10) -> None:
        """
        Create some new vehicles and add them to the road.
        """
        # Increase the number of vehicles by 50%
        n_vehicles = int(n_vehicles * 1.5)

        vehicle_type = utils.class_from_path(self.config["other_vehicles_type"])
        vehicle_type.DISTANCE_WANTED = 7  # Low jam distance
        vehicle_type.COMFORT_ACC_MAX = 6
        vehicle_type.COMFORT_ACC_MIN = -3

        # Random vehicles
        simulation_steps = 3
        for t in range(n_vehicles - 1):
            self._spawn_vehicle(np.linspace(0, 80, n_vehicles)[t])
        for _ in range(simulation_steps):
            [
                (
                    self.road.act(),
                    self.road.step(1 / self.config["simulation_frequency"]),
                )
                for _ in range(self.config["simulation_frequency"])
            ]

        # Ego-vehicle
        self._spawn_vehicle(
            60,
            spawn_probability=1,
            go_straight=True,
            position_deviation=0.1,
            speed_deviation=0,
        )

        # Incoming vehicle
        self.controlled_vehicles = []
        for ego_id in range(0, self.config["controlled_vehicles"]):
            ego_lane = self.road.network.get_lane(
                (f"o{ego_id % 4}", f"ir{ego_id % 4}", 0)
            )
            destination = self.config["destination"] or "o" + str(
                self.np_random.integers(1, 4)
            )
            ego_vehicle = self.action_type.vehicle_class(
                self.road,
                ego_lane.position(60 + 5 * self.np_random.normal(1), 0),
                speed=ego_lane.speed_limit,
                heading=ego_lane.heading_at(60),
            )
            try:
                ego_vehicle.plan_route_to(destination)
                ego_vehicle.speed_index = ego_vehicle.speed_to_index(
                    ego_lane.speed_limit
                )
                ego_vehicle.target_speed = ego_vehicle.index_to_speed(
                    ego_vehicle.speed_index
                )
            except AttributeError:
                pass

            self.road.vehicles.append(ego_vehicle)
            self.controlled_vehicles.append(ego_vehicle)
            for v in self.road.vehicles:  
                if (
                    v is not ego_vehicle
                    and np.linalg.norm(v.position - ego_vehicle.position) < 20
                ):
                    self.road.vehicles.remove(v)

# %%
env = CustomIntersectionEnv(render_mode='rgb_array')
pprint.pprint(env.config)
# Out:
# {'action': {'lateral': False,
#             'longitudinal': True,
#             'target_speeds': [0, 4.5, 9],
#             'type': 'DiscreteMetaAction'},
#  'arrived_reward': 1,
#  'centering_position': [0.5, 0.6],
#  'collision_reward': -5,
#  'controlled_vehicles': 1,
#  'destination': 'o1',
#  'duration': 13,
#  'high_speed_reward': 1,
#  'initial_vehicle_count': 10,
#  'manual_control': False,
#  'normalize_reward': False,
#  'observation': {'absolute': True,
#                  'features': ['presence',
#                               'x',
#                               'y',
#                               'vx',
#                               'vy',
#                               'cos_h',
#                               'sin_h'],
#                  'features_range': {'vx': [-20, 20],
#                                     'vy': [-20, 20],
#                                     'x': [-100, 100],
#                                     'y': [-100, 100]},
#                  'flatten': False,
#                  'observe_intentions': False,
#                  'type': 'Kinematics',
#                  'vehicles_count': 15},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [7.0, 9.0],
#  'scaling': 7.15,
#  'screen_height': 600,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15,
#  'spawn_probability': 0.6}

# %% [markdown]
# ##### Training the agent

# %%
model = PPO('MlpPolicy', env,
            policy_kwargs=dict(net_arch=[256, 256]),
            learning_rate=5e-4,
            n_steps=2048, 
            batch_size=64, 
            n_epochs=10,  
            gamma=0.8,
            gae_lambda=0.95, 
            clip_range=0.2, 
            verbose=1,
            tensorboard_log="intersection_50_ppo/")
timesteps = 50000
model.learn(total_timesteps=timesteps)
model.save("intersection_50_ppo/model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to intersection_50_ppo/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.63     |
# |    ep_rew_mean     | 1.15     |
# | time/              |          |
# |    fps             | 13       |
# |    iterations      | 1        |
# |    time_elapsed    | 150      |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.06        |
# |    ep_rew_mean          | 2.21        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 2           |
# |    time_elapsed         | 305         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.025327599 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.0451     |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.21        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0263     |
# |    value_loss           | 2.97        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.23       |
# |    ep_rew_mean          | 1.7        |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 3          |
# |    time_elapsed         | 451        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.04113724 |
# |    clip_fraction        | 0.277      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.138      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 1.39       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0282    |
# |    value_loss           | 3.42       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.02        |
# |    ep_rew_mean          | 3.02        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 4           |
# |    time_elapsed         | 605         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.021941131 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.946      |
# |    explained_variance   | 0.26        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.14        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0188     |
# |    value_loss           | 3.97        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.8         |
# |    ep_rew_mean          | 2.85        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 5           |
# |    time_elapsed         | 756         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.014685704 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.879      |
# |    explained_variance   | 0.263       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.44        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0187     |
# |    value_loss           | 4.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.36        |
# |    ep_rew_mean          | 3.01        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 6           |
# |    time_elapsed         | 902         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.020639172 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.819      |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 3.05        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 4.56        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.42        |
# |    ep_rew_mean          | 3.45        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 7           |
# |    time_elapsed         | 1046        |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.017216276 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.771      |
# |    explained_variance   | 0.206       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.62        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 4.71        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.03        |
# |    ep_rew_mean          | 2.73        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 8           |
# |    time_elapsed         | 1196        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.015722968 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.703      |
# |    explained_variance   | 0.208       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.57        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 4.79        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.96        |
# |    ep_rew_mean          | 2.43        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 9           |
# |    time_elapsed         | 1358        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.015616058 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.671      |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 3.19        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 4.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.6         |
# |    ep_rew_mean          | 3.04        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 10          |
# |    time_elapsed         | 1516        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.015574785 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.654      |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.93        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 5           |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.6         |
# |    ep_rew_mean          | 3.53        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 11          |
# |    time_elapsed         | 1672        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011050076 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.644      |
# |    explained_variance   | 0.2         |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.18        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00754    |
# |    value_loss           | 4.37        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.91        |
# |    ep_rew_mean          | 3.28        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 12          |
# |    time_elapsed         | 1834        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013541603 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.642      |
# |    explained_variance   | 0.185       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.28        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 4.65        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.19         |
# |    ep_rew_mean          | 3.88         |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 13           |
# |    time_elapsed         | 1993         |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0144972745 |
# |    clip_fraction        | 0.153        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.617       |
# |    explained_variance   | 0.205        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 2.32         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0118      |
# |    value_loss           | 4.1          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.74       |
# |    ep_rew_mean          | 3.23       |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 14         |
# |    time_elapsed         | 2147       |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.02709655 |
# |    clip_fraction        | 0.149      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.581     |
# |    explained_variance   | 0.203      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 1.98       |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.014     |
# |    value_loss           | 4.19       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.53        |
# |    ep_rew_mean          | 3.34        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 15          |
# |    time_elapsed         | 2304        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.015701087 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.593      |
# |    explained_variance   | 0.244       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.19        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 4.31        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.03        |
# |    ep_rew_mean          | 3.03        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 16          |
# |    time_elapsed         | 2457        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.016201971 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.527      |
# |    explained_variance   | 0.226       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.64        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 4.41        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 7.68      |
# |    ep_rew_mean          | 4.15      |
# | time/                   |           |
# |    fps                  | 13        |
# |    iterations           | 17        |
# |    time_elapsed         | 2612      |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.0173509 |
# |    clip_fraction        | 0.12      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.486    |
# |    explained_variance   | 0.246     |
# |    learning_rate        | 0.0005    |
# |    loss                 | 1.8       |
# |    n_updates            | 160       |
# |    policy_gradient_loss | -0.0118   |
# |    value_loss           | 4.58      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.34       |
# |    ep_rew_mean          | 3.51       |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 18         |
# |    time_elapsed         | 2762       |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.01496217 |
# |    clip_fraction        | 0.106      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.492     |
# |    explained_variance   | 0.209      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 1.54       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00895   |
# |    value_loss           | 4.18       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.39        |
# |    ep_rew_mean          | 3.2         |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 19          |
# |    time_elapsed         | 2920        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.014227979 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.502      |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 2.06        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00942    |
# |    value_loss           | 4.33        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.66        |
# |    ep_rew_mean          | 2.38        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 20          |
# |    time_elapsed         | 3078        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.026965171 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.505      |
# |    explained_variance   | 0.213       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.64        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 4.21        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.17       |
# |    ep_rew_mean          | 2.41       |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 21         |
# |    time_elapsed         | 3236       |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01752219 |
# |    clip_fraction        | 0.129      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.508     |
# |    explained_variance   | 0.233      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 2.37       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0123    |
# |    value_loss           | 4.23       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.37        |
# |    ep_rew_mean          | 3.79        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 22          |
# |    time_elapsed         | 3388        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.018063884 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.494      |
# |    explained_variance   | 0.26        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.79        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 3.89        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.32        |
# |    ep_rew_mean          | 3.54        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 23          |
# |    time_elapsed         | 3547        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.021327697 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.529      |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.54        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 4.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.56        |
# |    ep_rew_mean          | 3.83        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 24          |
# |    time_elapsed         | 3700        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.017814375 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.512      |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.97        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 4.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.18        |
# |    ep_rew_mean          | 2.44        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 25          |
# |    time_elapsed         | 3856        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.021936968 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.5        |
# |    explained_variance   | 0.275       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 1.26        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 3.62        |
# -----------------------------------------
